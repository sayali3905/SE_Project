# %%
import requests
import pandas as pd
import time
from datetime import datetime

def get_pr_counts(repo_owner, repo_name, headers):
    variables = {
        "owner": repo_owner,
        "name": repo_name
    }

    try:
        response = requests.post(
            'https://api.github.com/graphql',
            headers=headers,
            json={'query': query, 'variables': variables}
        )

        if response.status_code == 200:
            data = response.json().get('data', {}).get('repository', {})
            if data:
                open_prs = data['pullRequests']['totalCount']
                closed_prs = data['closedPullRequests']['totalCount']
                merged_prs = data['mergedPullRequests']['totalCount']
                return {
                    'open_prs': open_prs,
                    'closed_prs': closed_prs + merged_prs,
                    'total_prs': open_prs + closed_prs + merged_prs
                }
        return {'open_prs': 0, 'closed_prs': 0, 'total_prs': 0}
    except Exception as e:
        print(f"Error fetching PRs for {repo_owner}/{repo_name}: {e}")
        return {'open_prs': 0, 'closed_prs': 0, 'total_prs': 0}

def get_github_repos(language, headers):
    all_repos = []
    page = 1
    max_pages = 10

    while page <= max_pages:
        url = "https://api.github.com/search/repositories"
        params = {
            'q': f'language:{language}',
            'sort': 'stars',
            'order': 'desc',
            'per_page': 100,
            'page': page
        }

        response = requests.get(url, headers=headers, params=params)

        if response.status_code == 403:
            reset_time = int(response.headers.get('X-RateLimit-Reset', time.time() + 60))
            sleep_time = max(reset_time - time.time(), 0) + 1
            print(f"\nGitHub rate limit reached! Sleeping for {sleep_time:.0f} seconds before retrying...")
            time.sleep(sleep_time)
            continue

        if response.status_code != 200:
            print(f"Error fetching {language} repositories (page {page}): {response.status_code}")
            break

        data = response.json()
        items = data.get('items', [])

        if not items:
            break

        all_repos.extend(items)

        remaining_calls = int(response.headers.get('X-RateLimit-Remaining', 0))
        if remaining_calls < 2:
            reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
            sleep_time = max(reset_time - time.time(), 0) + 1
            print(f"\nRate limit reached. Sleeping for {sleep_time:.0f} seconds...")
            time.sleep(sleep_time)

        print(f"Fetched page {page} for {language} ({len(items)} repositories)")
        page += 1

    return all_repos

def get_repo_details(repo, headers):
    owner, name = repo['full_name'].split('/')
    pr_counts = get_pr_counts(owner, name, headers)
    time.sleep(1)

    return {
        'repo_name': repo['full_name'],
        'stars': repo['stargazers_count'],
        'issues': repo['open_issues_count'],
        'open_prs': pr_counts['open_prs'],
        'closed_prs': pr_counts['closed_prs'],
        'total_prs': pr_counts['total_prs'],
        'language': repo['language'],
        'is_fork': repo['fork'],
        'url': repo['html_url'],
        'size_mb': round(repo['size'] / 1024, 2)
    }

def main():
    github_token = "your_actual_token"  #put your github token here
    headers = {
        'Authorization': f'bearer {github_token}',
        'Accept': 'application/vnd.github.v3+json'
    }

    languages = ['Java', 'JavaScript', 'Python', 'PHP', 'C', 'C++', 'Ruby']

    all_repos_data = []

    for language in languages:
        print(f"\nFetching {language} repositories...")
        repos = get_github_repos(language, headers)
        print(f"Fetching PR data for {len(repos)} {language} repositories...")
        repos_data = [get_repo_details(repo, headers) for repo in repos]
        all_repos_data.extend(repos_data)
        print(f"Total {language} repositories collected: {len(repos)}")

    df = pd.DataFrame(all_repos_data)
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = f'github_repos_{timestamp}.csv'

    df.to_csv(filename, index=False)
    print(f"\nData saved to {filename}")
    print(f"Total repositories collected: {len(df)}")
    print("\nRepositories per language:")
    print(df['language'].value_counts())

    print("\nAverage stats per language:")
    stats = df.groupby('language').agg({
        'stars': 'mean',
        'issues': 'mean',
        'open_prs': 'mean',
        'closed_prs': 'mean',
        'total_prs': 'mean'
    }).round(2)
    print(stats)

    print("\nTop 5 repositories by stars:")
    columns = ['repo_name', 'language', 'stars', 'open_prs', 'closed_prs', 'total_prs']
    print(df.nlargest(5, 'stars')[columns])

if __name__ == "__main__":
    main()
# Out:
# Fetching Java repositories...
#
# GitHub rate limit reached! Sleeping for 16 seconds before retrying...
# Fetched page 1 for Java (100 repositories)
# Fetched page 2 for Java (100 repositories)
# Fetched page 3 for Java (100 repositories)
# Fetched page 4 for Java (100 repositories)
# Fetched page 5 for Java (100 repositories)
# Fetched page 6 for Java (100 repositories)
# Fetched page 7 for Java (100 repositories)
# Fetched page 8 for Java (100 repositories)
# Fetched page 9 for Java (100 repositories)
# Fetched page 10 for Java (100 repositories)
# Fetching PR data for 1000 Java repositories...
# Total Java repositories collected: 1000
#
# Fetching JavaScript repositories...
# Fetched page 1 for JavaScript (100 repositories)
# Fetched page 2 for JavaScript (100 repositories)
# Fetched page 3 for JavaScript (100 repositories)
# Fetched page 4 for JavaScript (100 repositories)
# Fetched page 5 for JavaScript (100 repositories)
# Fetched page 6 for JavaScript (100 repositories)
# Fetched page 7 for JavaScript (100 repositories)
# Fetched page 8 for JavaScript (100 repositories)
#
# GitHub rate limit reached! Sleeping for 37 seconds before retrying...
# Fetched page 9 for JavaScript (100 repositories)
# Fetched page 10 for JavaScript (100 repositories)
# Fetching PR data for 1000 JavaScript repositories...
# Total JavaScript repositories collected: 1000
#
# Fetching Python repositories...
# Fetched page 1 for Python (100 repositories)
# Fetched page 2 for Python (100 repositories)
# Fetched page 3 for Python (100 repositories)
# Fetched page 4 for Python (100 repositories)
# Fetched page 5 for Python (100 repositories)
# Fetched page 6 for Python (100 repositories)
# Fetched page 7 for Python (100 repositories)
# Fetched page 8 for Python (100 repositories)
# Fetched page 9 for Python (100 repositories)
# Fetched page 10 for Python (100 repositories)
# Fetching PR data for 1000 Python repositories...
# Total Python repositories collected: 1000
#
# Fetching PHP repositories...
# Fetched page 1 for PHP (100 repositories)
# Fetched page 2 for PHP (100 repositories)
# Fetched page 3 for PHP (100 repositories)
# Fetched page 4 for PHP (100 repositories)
# Fetched page 5 for PHP (100 repositories)
# Fetched page 6 for PHP (100 repositories)
# Fetched page 7 for PHP (100 repositories)
# Fetched page 8 for PHP (100 repositories)
# Fetched page 9 for PHP (100 repositories)
# Fetched page 10 for PHP (100 repositories)
# Fetching PR data for 1000 PHP repositories...
# Total PHP repositories collected: 1000
#
# Fetching C repositories...
# Fetched page 1 for C (100 repositories)
# Fetched page 2 for C (100 repositories)
# Fetched page 3 for C (100 repositories)
# Fetched page 4 for C (100 repositories)
# Fetched page 5 for C (100 repositories)
# Fetched page 6 for C (100 repositories)
# Fetched page 7 for C (100 repositories)
# Fetched page 8 for C (100 repositories)
# Fetched page 9 for C (100 repositories)
# Fetched page 10 for C (100 repositories)
# Fetching PR data for 1000 C repositories...
# Total C repositories collected: 1000
#
# Fetching C++ repositories...
# Fetched page 1 for C++ (100 repositories)
# Fetched page 2 for C++ (100 repositories)
# Fetched page 3 for C++ (100 repositories)
# Fetched page 4 for C++ (100 repositories)
# Fetched page 5 for C++ (100 repositories)
# Fetched page 6 for C++ (100 repositories)
# Fetched page 7 for C++ (100 repositories)
# Fetched page 8 for C++ (100 repositories)
# Fetched page 9 for C++ (100 repositories)
# Fetched page 10 for C++ (100 repositories)
# Fetching PR data for 1000 C++ repositories...
# Total C++ repositories collected: 1000
#
# Fetching Ruby repositories...
# Fetched page 1 for Ruby (100 repositories)
# Fetched page 2 for Ruby (100 repositories)
# Fetched page 3 for Ruby (100 repositories)
# Fetched page 4 for Ruby (100 repositories)
# Fetched page 5 for Ruby (100 repositories)
# Fetched page 6 for Ruby (100 repositories)
# Fetched page 7 for Ruby (100 repositories)
# Fetched page 8 for Ruby (100 repositories)
# Fetched page 9 for Ruby (100 repositories)
# Fetched page 10 for Ruby (100 repositories)
# Fetching PR data for 1000 Ruby repositories...
# Total Ruby repositories collected: 1000
#
# Data saved to github_repos_20250212_234546.csv
# Total repositories collected: 7000
#
# Repositories per language:
# language
# Java           1000
# JavaScript     1000
# Python         1000
# PHP            1000
# C              1000
# C++            1000
# Ruby            999
# Objective-C       1
# Name: count, dtype: int64
#
# Average stats per language:
#                 stars  issues  open_prs  closed_prs  total_prs
# language
# C             6256.33  182.48     23.51      836.07     859.58
# C++           8793.29  354.46     48.84     1949.82    1998.66
# Java          9155.84  232.04     31.22     1437.60    1468.82
# JavaScript   17365.72  256.96     31.80     1077.61    1109.41
# Objective-C   1650.00   29.00      0.00       58.00      58.00
# PHP           4393.50  107.00     15.27      884.96     900.23
# Python       18496.07  333.25     40.60     1750.62    1791.22
# Ruby          3290.40   66.49     12.52      751.88     764.40
#
# Top 5 repositories by stars:
#                              repo_name    language   stars  open_prs  \
# 2000           public-apis/public-apis      Python  327307       403
# 2001  donnemartin/system-design-primer      Python  288940       245
# 2002              vinta/awesome-python      Python  233709       424
# 1000                    facebook/react  JavaScript  232217       188
# 2003              TheAlgorithms/Python      Python  197235       285
#
#       closed_prs  total_prs
# 2000        2937       3340
# 2001         325        570
# 2002        1544       1968
# 1000       16656      16844
# 2003       10135      10420

# %%
import pandas as pd
from datetime import datetime

def filter_repositories(input_file):
    df = pd.read_csv(input_file)

    print(f"Total repositories before filtering: {len(df)}")

    filters = {
        'stars >= 100': df['stars'] >= 100,
        'total PRs >= 100': df['total_prs'] >= 100,
        'issues >= 100': df['issues'] >= 100,
        'size >= 10MB': df['size_mb'] >= 10,
        'not forked': ~df['is_fork']
    }

    print("\nImpact of individual filters:")
    for name, filter_condition in filters.items():
        count = len(df[filter_condition])
        percentage = (count / len(df)) * 100
        print(f"{name}: {count} repositories ({percentage:.2f}%)")

    for filter_condition in filters.values():
        df = df[filter_condition]

    print(f"\nRepositories meeting all criteria: {len(df)}")
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_file = f'github_repos_filtered_{timestamp}.csv'
    df.to_csv(output_file, index=False)
    print(f"\nFiltered results saved to: {output_file}")

    print("\nQualifying repositories per language:")
    print(df['language'].value_counts())

    print("\nAverage stats for qualifying repositories per language:")
    stats = df.groupby('language').agg({
        'stars': ['count', 'mean'],
        'issues': 'mean',
        'total_prs': 'mean',
        'size_mb': 'mean'
    }).round(2)
    print(stats)

    print("\nTop 5 qualifying repositories by stars:")
    columns = ['repo_name', 'language', 'stars', 'issues', 'total_prs', 'size_mb']
    print(df.nlargest(5, 'stars')[columns])

    return df

if __name__ == "__main__":
    input_file = "/content/github_repos_20250212_234546.csv"
    filtered_df = filter_repositories(input_file)
# Out:
# Total repositories before filtering: 7000
#
# Impact of individual filters:
# stars >= 100: 7000 repositories (100.00%)
# total PRs >= 100: 4566 repositories (65.23%)
# issues >= 100: 2957 repositories (42.24%)
# size >= 10MB: 3612 repositories (51.60%)
# not forked: 7000 repositories (100.00%)
#
# Repositories meeting all criteria: 1779
#
# Filtered results saved to: github_repos_filtered_20250213_001321.csv
#
# Qualifying repositories per language:
# language
# C++           412
# Python        336
# JavaScript    297
# Java          292
# C             242
# PHP           136
# Ruby           64
# Name: count, dtype: int64
#
# Average stats for qualifying repositories per language:
#            stars            issues total_prs size_mb
#            count      mean    mean      mean    mean
# language
# C            242   9296.49  469.59   2675.98  192.75
# C++          412  12448.05  725.60   4265.84  473.41
# Java         292  11855.92  583.13   3979.33  268.81
# JavaScript   297  23299.06  552.90   2765.48  271.35
# PHP          136   6806.51  549.04   3992.72  262.05
# Python       336  22845.96  648.57   4430.63  183.12
# Ruby          64   9179.16  412.67   4782.84  214.20
#
# Top 5 qualifying repositories by stars:
#                              repo_name    language   stars  issues  total_prs  \
# 2001  donnemartin/system-design-primer      Python  288940     476        570
# 1000                    facebook/react  JavaScript  232217     962      16844
# 2003              TheAlgorithms/Python      Python  197235     349      10420
# 1001    trekhleb/javascript-algorithms  JavaScript  190039     355        771
# 5000             tensorflow/tensorflow         C++  187918    6925      44989
#
#       size_mb
# 2001    10.96
# 1000   707.97
# 2003    14.72
# 1001    13.25
# 5000  1108.06
# <ipython-input-3-d14231e857b5>:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[filter_condition]
# <ipython-input-3-d14231e857b5>:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[filter_condition]
# <ipython-input-3-d14231e857b5>:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[filter_condition]

# %%
import pandas as pd
import requests
import time
from datetime import datetime

def check_travis_ci(repo_name, headers):
    owner, repo = repo_name.split('/')
    url = f"https://api.github.com/repos/{owner}/{repo}/contents/.travis.yml"

    try:
        response = requests.get(url, headers=headers)
        return response.status_code == 200
    except Exception as e:
        print(f"Error checking Travis CI for {repo_name}: {e}")
        return False

def analyze_travis_usage(input_file, github_token):
    df = pd.read_csv(input_file)
    print(f"Analyzing {len(df)} repositories for Travis CI usage...")
    headers = {
        'Authorization': f'token {github_token}',
        'Accept': 'application/vnd.github.v3+json'
    }

    travis_usage = []
    for index, row in df.iterrows():
        print(f"Checking {row['repo_name']} ({index + 1}/{len(df)})")
        has_travis = check_travis_ci(row['repo_name'], headers)
        travis_usage.append(has_travis)
        time.sleep(1)
    df['uses_travis'] = travis_usage

    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_file = f'github_repos_travis_{timestamp}.csv'

    df.to_csv(output_file, index=False)

    total_repos = len(df)
    travis_repos = sum(travis_usage)
    usage_percentage = (travis_repos / total_repos) * 100

    print("\nTravis CI Usage Statistics:")
    print(f"Total repositories analyzed: {total_repos}")
    print(f"Repositories using Travis CI: {travis_repos}")
    print(f"Usage percentage: {usage_percentage:.2f}%")

    print("\nTravis CI usage by language:")
    language_stats = df.groupby('language').agg({
        'uses_travis': ['count', 'sum']
    })
    language_stats['percentage'] = (language_stats['uses_travis']['sum'] /
                                  language_stats['uses_travis']['count'] * 100).round(2)
    print(language_stats)

    print("\nTop 5 repositories with Travis CI by stars:")
    travis_repos = df[df['uses_travis']].nlargest(5, 'stars')
    print(travis_repos[['repo_name', 'language', 'stars', 'total_prs']])

    print(f"\nResults saved to: {output_file}")

    return df

if __name__ == "__main__":
    input_file = "/content/github_repos_filtered_20250213_001321.csv"  
    github_token = "your_actual_token"

    df_with_travis = analyze_travis_usage(input_file, github_token)
# Out:
# Analyzing 1779 repositories for Travis CI usage...
# Checking iluwatar/java-design-patterns (1/1779)
# Checking spring-projects/spring-boot (2/1779)
# Checking elastic/elasticsearch (3/1779)
# Checking kdn251/interviews (4/1779)
# Checking spring-projects/spring-framework (5/1779)
# Checking NationalSecurityAgency/ghidra (6/1779)
# Checking google/guava (7/1779)
# Checking Stirling-Tools/Stirling-PDF (8/1779)
# Checking skylot/jadx (9/1779)
# Checking dbeaver/dbeaver (10/1779)
# Checking apache/dubbo (11/1779)
# Checking PhilJay/MPAndroidChart (12/1779)
# Checking alibaba/arthas (13/1779)
# Checking bumptech/glide (14/1779)
# Checking halo-dev/halo (15/1779)
# Checking netty/netty (16/1779)
# Checking Blankj/AndroidUtilCode (17/1779)
# Checking alibaba/easyexcel (18/1779)
# Checking TeamNewPipe/NewPipe (19/1779)
# Checking SeleniumHQ/selenium (20/1779)
# Checking alibaba/nacos (21/1779)
# Checking apache/kafka (22/1779)
# Checking apolloconfig/apollo (23/1779)
# Checking alibaba/canal (24/1779)
# Checking xuxueli/xxl-job (25/1779)
# Checking alibaba/spring-cloud-alibaba (26/1779)
# Checking alibaba/druid (27/1779)
# Checking alibaba/fastjson (28/1779)
# Checking DrKLO/Telegram (29/1779)
# Checking apache/incubator-seata (30/1779)
# Checking keycloak/keycloak (31/1779)
# Checking apache/flink (32/1779)
# Checking libgdx/libgdx (33/1779)
# Checking bazelbuild/bazel (34/1779)
# Checking redisson/redisson (35/1779)
# Checking google/gson (36/1779)
# Checking OpenAPITools/openapi-generator (37/1779)
# Checking google/ExoPlayer (38/1779)
# Checking apache/rocketmq (39/1779)
# Checking yuliskov/SmartTube (40/1779)
# Checking oracle/graal (41/1779)
# Checking openjdk/jdk (42/1779)
# Checking didi/DoKit (43/1779)
# Checking conductor-oss/conductor (44/1779)
# Checking apache/shardingsphere (45/1779)
# Checking mybatis/mybatis-3 (46/1779)
# Checking dataease/dataease (47/1779)
# Checking CodePhiliaX/Chat2DB (48/1779)
# Checking Baseflow/PhotoView (49/1779)
# Checking dianping/cat (50/1779)
# Checking kunal-kushwaha/DSA-Bootcamp-Java (51/1779)
# Checking thingsboard/thingsboard (52/1779)
# Checking williamfiset/Algorithms (53/1779)
# Checking JetBrains/intellij-community (54/1779)
# Checking antlr/antlr4 (55/1779)
# Checking Tencent/APIJSON (56/1779)
# Checking openzipkin/zipkin (57/1779)
# Checking facebook/fresco (58/1779)
# Checking nostra13/Android-Universal-Image-Loader (59/1779)
# Checking material-components/material-components-android (60/1779)
# Checking Grasscutters/Grasscutter (61/1779)
# Checking alibaba/DataX (62/1779)
# Checking prestodb/presto (63/1779)
# Checking kestra-io/kestra (64/1779)
# Checking mockito/mockito (65/1779)
# Checking apache/hadoop (66/1779)
# Checking questdb/questdb (67/1779)
# Checking alibaba/ARouter (68/1779)
# Checking apache/pulsar (69/1779)
# Checking eclipse-vertx/vert.x (70/1779)
# Checking elastic/logstash (71/1779)
# Checking arduino/Arduino (72/1779)
# Checking quarkusio/quarkus (73/1779)
# Checking supertokens/supertokens-core (74/1779)
# Checking GoogleContainerTools/jib (75/1779)
# Checking neo4j/neo4j (76/1779)
# Checking deeplearning4j/deeplearning4j (77/1779)
# Checking apache/druid (78/1779)
# Checking pinpoint-apm/pinpoint (79/1779)
# Checking apache/dolphinscheduler (80/1779)
# Checking apache/doris (81/1779)
# Checking zaproxy/zaproxy (82/1779)
# Checking projectlombok/lombok (83/1779)
# Checking Netflix/conductor (84/1779)
# Checking languagetool-org/languagetool (85/1779)
# Checking google/guice (86/1779)
# Checking Netflix/eureka (87/1779)
# Checking apache/zookeeper (88/1779)
# Checking cryptomator/cryptomator (89/1779)
# Checking redis/jedis (90/1779)
# Checking Yalantis/uCrop (91/1779)
# Checking Tencent/matrix (92/1779)
# Checking grpc/grpc-java (93/1779)
# Checking code4craft/webmagic (94/1779)
# Checking realm/realm-java (95/1779)
# Checking careercup/CtCI-6th-Edition (96/1779)
# Checking kekingcn/kkFileView (97/1779)
# Checking OpenRefine/OpenRefine (98/1779)
# Checking jfeinstein10/SlidingMenu (99/1779)
# Checking plantuml/plantuml (100/1779)
# Checking trinodb/trino (101/1779)
# Checking PaperMC/Paper (102/1779)
# Checking asLody/VirtualApp (103/1779)
# Checking datahub-project/datahub (104/1779)
# Checking provectus/kafka-ui (105/1779)
# Checking Activiti/Activiti (106/1779)
# Checking opensearch-project/OpenSearch (107/1779)
# Checking awsdocs/aws-doc-sdk-examples (108/1779)
# Checking LawnchairLauncher/lawnchair (109/1779)
# Checking stanfordnlp/CoreNLP (110/1779)
# Checking react-native-camera/react-native-camera (111/1779)
# Checking MyCATApache/Mycat-Server (112/1779)
# Checking StarRocks/starrocks (113/1779)
# Checking pockethub/PocketHub (114/1779)
# Checking microg/GmsCore (115/1779)
# Checking android/testing-samples (116/1779)
# Checking apache/cassandra (117/1779)
# Checking spring-projects/spring-security (118/1779)
# Checking java-native-access/jna (119/1779)
# Checking apache/jmeter (120/1779)
# Checking facebook/buck (121/1779)
# Checking airbnb/epoxy (122/1779)
# Checking junit-team/junit4 (123/1779)
# Checking apache/shenyu (124/1779)
# Checking flyway/flyway (125/1779)
# Checking checkstyle/checkstyle (126/1779)
# Checking roughike/BottomBar (127/1779)
# Checking apache/seatunnel (128/1779)
# Checking flowable/flowable-engine (129/1779)
# Checking apache/shardingsphere-elasticjob (130/1779)
# Checking testcontainers/testcontainers-java (131/1779)
# Checking apache/beam (132/1779)
# Checking TechEmpower/FrameworkBenchmarks (133/1779)
# Checking software-mansion/react-native-svg (134/1779)
# Checking gedoor/MyBookshelf (135/1779)
# Checking Graylog2/graylog2-server (136/1779)
# Checking cabaletta/baritone (137/1779)
# Checking google/closure-compiler (138/1779)
# Checking swagger-api/swagger-core (139/1779)
# Checking PowerJob/PowerJob (140/1779)
# Checking Qihoo360/RePlugin (141/1779)
# Checking HMCL-dev/HMCL (142/1779)
# Checking PojavLauncherTeam/PojavLauncher (143/1779)
# Checking mapstruct/mapstruct (144/1779)
# Checking MinecraftForge/MinecraftForge (145/1779)
# Checking didi/KnowStreaming (146/1779)
# Checking naman14/Timber (147/1779)
# Checking Alluxio/alluxio (148/1779)
# Checking google/error-prone (149/1779)
# Checking rest-assured/rest-assured (150/1779)
# Checking apache/iceberg (151/1779)
# Checking Angel-ML/angel (152/1779)
# Checking AntennaPod/AntennaPod (153/1779)
# Checking jeremylong/DependencyCheck (154/1779)
# Checking guardianproject/haven (155/1779)
# Checking junit-team/junit5 (156/1779)
# Checking processing/processing (157/1779)
# Checking wiremock/wiremock (158/1779)
# Checking apache/zeppelin (159/1779)
# Checking ArthurHub/Android-Image-Cropper (160/1779)
# Checking AsyncHttpClient/async-http-client (161/1779)
# Checking sshahine/JFoenix (162/1779)
# Checking jOOQ/jOOQ (163/1779)
# Checking joelittlejohn/jsonschema2pojo (164/1779)
# Checking hazelcast/hazelcast (165/1779)
# Checking Col-E/Recaf (166/1779)
# Checking micronaut-projects/micronaut-core (167/1779)
# Checking pig-mesh/pig (168/1779)
# Checking hibernate/hibernate-orm (169/1779)
# Checking exadel-inc/CompreFace (170/1779)
# Checking gephi/gephi (171/1779)
# Checking vespa-engine/vespa (172/1779)
# Checking apache/hertzbeat (173/1779)
# Checking springfox/springfox (174/1779)
# Checking robolectric/robolectric (175/1779)
# Checking k0shk0sh/FastHub (176/1779)
# Checking jpush/aurora-imui (177/1779)
# Checking WeiYe-Jing/datax-web (178/1779)
# Checking apache/iotdb (179/1779)
# Checking javaparser/javaparser (180/1779)
# Checking opengoofy/hippo4j (181/1779)
# Checking apache/hudi (182/1779)
# Checking apache/pinot (183/1779)
# Checking langchain4j/langchain4j (184/1779)
# Checking traccar/traccar (185/1779)
# Checking graphhopper/graphhopper (186/1779)
# Checking redis/lettuce (187/1779)
# Checking TeamAmaze/AmazeFileManager (188/1779)
# Checking JanusGraph/janusgraph (189/1779)
# Checking MuntashirAkon/AppManager (190/1779)
# Checking apache/hbase (191/1779)
# Checking logisim-evolution/logisim-evolution (192/1779)
# Checking thinkaurelius/titan (193/1779)
# Checking hyperledger-web3j/web3j (194/1779)
# Checking strimzi/strimzi-kafka-operator (195/1779)
# Checking CeuiLiSA/Pixiv-Shaft (196/1779)
# Checking bitcoinj/bitcoinj (197/1779)
# Checking OpenTSDB/opentsdb (198/1779)
# Checking remkop/picocli (199/1779)
# Checking brianfrankcooper/YCSB (200/1779)
# Checking natario1/CameraView (201/1779)
# Checking PhilippC/keepass2android (202/1779)
# Checking pmd/pmd (203/1779)
# Checking jankotek/mapdb (204/1779)
# Checking GeyserMC/Geyser (205/1779)
# Checking runelite/runelite (206/1779)
# Checking CellularPrivacy/Android-IMSI-Catcher-Detector (207/1779)
# Checking apache/ignite (208/1779)
# Checking liquibase/liquibase (209/1779)
# Checking line/armeria (210/1779)
# Checking osmandapp/OsmAnd (211/1779)
# Checking bisq-network/bisq (212/1779)
# Checking querydsl/querydsl (213/1779)
# Checking orientechnologies/orientdb (214/1779)
# Checking microsoft/typespec (215/1779)
# Checking rstudio/rstudio (216/1779)
# Checking killbill/killbill (217/1779)
# Checking apache/calcite (218/1779)
# Checking diffplug/spotless (219/1779)
# Checking pardom-zz/ActiveAndroid (220/1779)
# Checking mock-server/mockserver (221/1779)
# Checking firebase/FirebaseUI-Android (222/1779)
# Checking hneemann/Digital (223/1779)
# Checking zq2599/blog_demos (224/1779)
# Checking apache/rocketmq-externals (225/1779)
# Checking spring-cloud/spring-cloud-gateway (226/1779)
# Checking Suwayomi/Suwayomi-Server (227/1779)
# Checking go-lang-plugin-org/go-lang-idea-plugin (228/1779)
# Checking bytedeco/javacpp (229/1779)
# Checking micrometer-metrics/micrometer (230/1779)
# Checking azkaban/azkaban (231/1779)
# Checking oracle/opengrok (232/1779)
# Checking nextcloud/android (233/1779)
# Checking Meituan-Dianping/Robust (234/1779)
# Checking Docile-Alligator/Infinity-For-Reddit (235/1779)
# Checking allure-framework/allure2 (236/1779)
# Checking ant-media/Ant-Media-Server (237/1779)
# Checking deepjavalibrary/djl (238/1779)
# Checking Freeyourgadget/Gadgetbridge (239/1779)
# Checking h2database/h2database (240/1779)
# Checking pytorch/serve (241/1779)
# Checking jacoco/jacoco (242/1779)
# Checking dragonwell-project/dragonwell8 (243/1779)
# Checking flutter-webrtc/flutter-webrtc (244/1779)
# Checking codingapi/tx-lcn (245/1779)
# Checking crate/crate (246/1779)
# Checking jitsi/jitsi (247/1779)
# Checking camunda/camunda-bpm-platform (248/1779)
# Checking jboss-javassist/javassist (249/1779)
# Checking microsoft/malmo (250/1779)
# Checking jlegewie/zotfile (251/1779)
# Checking zendesk/maxwell (252/1779)
# Checking DTStack/chunjun (253/1779)
# Checking apache/dubbo-admin (254/1779)
# Checking apache/streampark (255/1779)
# Checking alibaba/fastjson2 (256/1779)
# Checking rovo89/XposedInstaller (257/1779)
# Checking knowm/XChange (258/1779)
# Checking jMonkeyEngine/jmonkeyengine (259/1779)
# Checking TGX-Android/Telegram-X (260/1779)
# Checking jetty/jetty.project (261/1779)
# Checking shuzijun/leetcode-editor (262/1779)
# Checking kermitt2/grobid (263/1779)
# Checking spring-projects/spring-ai (264/1779)
# Checking andOTP/andOTP (265/1779)
# Checking JabRef/jabref (266/1779)
# Checking syncthing/syncthing-android (267/1779)
# Checking LibrePDF/OpenPDF (268/1779)
# Checking MovingBlocks/Terasology (269/1779)
# Checking shopizer-ecommerce/shopizer (270/1779)
# Checking apache/incubator-heron (271/1779)
# Checking jtablesaw/tablesaw (272/1779)
# Checking helidon-io/helidon (273/1779)
# Checking spotbugs/spotbugs (274/1779)
# Checking dtinit/data-transfer-project (275/1779)
# Checking spockframework/spock (276/1779)
# Checking FasterXML/jackson-databind (277/1779)
# Checking iterate-ch/cyberduck (278/1779)
# Checking yacy/yacy_search_server (279/1779)
# Checking tchiotludo/akhq (280/1779)
# Checking camunda/camunda (281/1779)
# Checking fabric8io/kubernetes-client (282/1779)
# Checking immutables/immutables (283/1779)
# Checking Querz/mcaselector (284/1779)
# Checking apache/logging-log4j2 (285/1779)
# Checking openhab/openhab1-addons (286/1779)
# Checking IrisShaders/Iris (287/1779)
# Checking cSploit/android (288/1779)
# Checking AxonFramework/AxonFramework (289/1779)
# Checking eclipse-openj9/openj9 (290/1779)
# Checking apache/linkis (291/1779)
# Checking TNG/ArchUnit (292/1779)
# Checking facebook/react (293/1779)
# Checking trekhleb/javascript-algorithms (294/1779)
# Checking twbs/bootstrap (295/1779)
# Checking vercel/next.js (296/1779)
# Checking nodejs/node (297/1779)
# Checking axios/axios (298/1779)
# Checking mrdoob/three.js (299/1779)
# Checking facebook/create-react-app (300/1779)
# Checking microsoft/Web-Dev-For-Beginners (301/1779)
# Checking sveltejs/svelte (302/1779)
# Checking jaywcjlove/awesome-mac (303/1779)
# Checking FortAwesome/Font-Awesome (304/1779)
# Checking open-webui/open-webui (305/1779)
# Checking hakimel/reveal.js (306/1779)
# Checking chartjs/Chart.js (307/1779)
# Checking webpack/webpack (308/1779)
# Checking louislam/uptime-kuma (309/1779)
# Checking atom/atom (310/1779)
# Checking angular/angular.js (311/1779)
# Checking gatsbyjs/gatsby (312/1779)
# Checking scutan90/DeepLearning-500-questions (313/1779)
# Checking Semantic-Org/Semantic-UI (314/1779)
# Checking juliangarnier/anime (315/1779)
# Checking prettier/prettier (316/1779)
# Checking mozilla/pdf.js (317/1779)
# Checking chinese-poetry/chinese-poetry (318/1779)
# Checking marktext/marktext (319/1779)
# Checking TryGhost/Ghost (320/1779)
# Checking moment/moment (321/1779)
# Checking cypress-io/cypress (322/1779)
# Checking agalwood/Motrix (323/1779)
# Checking serverless/serverless (324/1779)
# Checking meteor/meteor (325/1779)
# Checking Asabeneh/30-Days-Of-JavaScript (326/1779)
# Checking parcel-bundler/parcel (327/1779)
# Checking bigskysoftware/htmx (328/1779)
# Checking Leaflet/Leaflet (329/1779)
# Checking Unitech/pm2 (330/1779)
# Checking yarnpkg/yarn (331/1779)
# Checking microsoft/monaco-editor (332/1779)
# Checking nolimits4web/swiper (333/1779)
# Checking nwjs/nw.js (334/1779)
# Checking dcloudio/uni-app (335/1779)
# Checking Dogfalo/materialize (336/1779)
# Checking videojs/video.js (337/1779)
# Checking preactjs/preact (338/1779)
# Checking Mintplex-Labs/anything-llm (339/1779)
# Checking Kong/insomnia (340/1779)
# Checking alvarotrigo/fullPage.js (341/1779)
# Checking ToolJet/ToolJet (342/1779)
# Checking atlassian/react-beautiful-dnd (343/1779)
# Checking adobe/brackets (344/1779)
# Checking usebruno/bruno (345/1779)
# Checking airbnb/lottie-web (346/1779)
# Checking gchq/CyberChef (347/1779)
# Checking lovell/sharp (348/1779)
# Checking vuejs/vue-cli (349/1779)
# Checking parallax/jsPDF (350/1779)
# Checking fabricjs/fabric.js (351/1779)
# Checking docsifyjs/docsify (352/1779)
# Checking tastejs/todomvc (353/1779)
# Checking GoogleChrome/lighthouse (354/1779)
# Checking vuejs/vuex (355/1779)
# Checking sampotts/plyr (356/1779)
# Checking zadam/trilium (357/1779)
# Checking HeyPuter/puter (358/1779)
# Checking YMFE/yapi (359/1779)
# Checking Automattic/mongoose (360/1779)
# Checking codemirror/codemirror5 (361/1779)
# Checking swagger-api/swagger-ui (362/1779)
# Checking ajaxorg/ace (363/1779)
# Checking Asabeneh/30-Days-Of-React (364/1779)
# Checking quasarframework/quasar (365/1779)
# Checking select2/select2 (366/1779)
# Checking Modernizr/Modernizr (367/1779)
# Checking rollup/rollup (368/1779)
# Checking feathericons/feather (369/1779)
# Checking nylas/nylas-mail (370/1779)
# Checking NginxProxyManager/nginx-proxy-manager (371/1779)
# Checking dimsemenov/PhotoSwipe (372/1779)
# Checking goldfire/howler.js (373/1779)
# Checking badges/shields (374/1779)
# Checking zen-browser/desktop (375/1779)
# Checking highlightjs/highlight.js (376/1779)
# Checking responsively-org/responsively-app (377/1779)
# Checking balderdashy/sails (378/1779)
# Checking mochajs/mocha (379/1779)
# Checking vuejs/vuepress (380/1779)
# Checking facebookarchive/draft-js (381/1779)
# Checking emberjs/ember.js (382/1779)
# Checking rahuldkjain/github-profile-readme-generator (383/1779)
# Checking songquanpeng/one-api (384/1779)
# Checking processing/p5.js (385/1779)
# Checking benweet/stackedit (386/1779)
# Checking simple-icons/simple-icons (387/1779)
# Checking necolas/react-native-web (388/1779)
# Checking pugjs/pug (389/1779)
# Checking parse-community/parse-server (390/1779)
# Checking react-grid-layout/react-grid-layout (391/1779)
# Checking jsdom/jsdom (392/1779)
# Checking HumanSignal/label-studio (393/1779)
# Checking petkaantonov/bluebird (394/1779)
# Checking node-red/node-red (395/1779)
# Checking handsontable/handsontable (396/1779)
# Checking copy/v86 (397/1779)
# Checking SortableJS/Vue.Draggable (398/1779)
# Checking ethereumbook/ethereumbook (399/1779)
# Checking blackmatrix7/ios_rule_script (400/1779)
# Checking terrastruct/d2 (401/1779)
# Checking wekan/wekan (402/1779)
# Checking facebookexperimental/Recoil (403/1779)
# Checking knex/knex (404/1779)
# Checking Reactive-Extensions/RxJS (405/1779)
# Checking FredKSchott/snowpack (406/1779)
# Checking appium/appium (407/1779)
# Checking sveltejs/kit (408/1779)
# Checking vuejs/vue-router (409/1779)
# Checking tabler/tabler-icons (410/1779)
# Checking KaTeX/KaTeX (411/1779)
# Checking HelloZeroNet/ZeroNet (412/1779)
# Checking brave/brave-browser (413/1779)
# Checking amark/gun (414/1779)
# Checking framework7io/framework7 (415/1779)
# Checking yjs/yjs (416/1779)
# Checking decaporg/decap-cms (417/1779)
# Checking youzan/vant-weapp (418/1779)
# Checking emotion-js/emotion (419/1779)
# Checking plotly/plotly.js (420/1779)
# Checking liabru/matter-js (421/1779)
# Checking pouchdb/pouchdb (422/1779)
# Checking BoostIO/BoostNote-Legacy (423/1779)
# Checking less/less.js (424/1779)
# Checking aframevr/aframe (425/1779)
# Checking gildas-lormeau/SingleFile (426/1779)
# Checking angular/material (427/1779)
# Checking jonasschmedtmann/complete-javascript-course (428/1779)
# Checking dream-num/Luckysheet (429/1779)
# Checking yabwe/medium-editor (430/1779)
# Checking DIYgod/DPlayer (431/1779)
# Checking moment/luxon (432/1779)
# Checking ai-shifu/ChatALL (433/1779)
# Checking diegomura/react-pdf (434/1779)
# Checking gpujs/gpu.js (435/1779)
# Checking jsdoc/jsdoc (436/1779)
# Checking ampproject/amphtml (437/1779)
# Checking overleaf/overleaf (438/1779)
# Checking paperjs/paper.js (439/1779)
# Checking apexcharts/apexcharts.js (440/1779)
# Checking keystonejs/keystone-classic (441/1779)
# Checking josdejong/mathjs (442/1779)
# Checking bootstrap-vue/bootstrap-vue (443/1779)
# Checking NodeBB/NodeBB (444/1779)
# Checking FreeTubeApp/FreeTube (445/1779)
# Checking facebookarchive/prepack (446/1779)
# Checking exceljs/exceljs (447/1779)
# Checking lucide-icons/lucide (448/1779)
# Checking google/WebFundamentals (449/1779)
# Checking zalmoxisus/redux-devtools-extension (450/1779)
# Checking openstf/stf (451/1779)
# Checking CesiumGS/cesium (452/1779)
# Checking Semantic-Org/Semantic-UI-React (453/1779)
# Checking codesandbox/codesandbox-client (454/1779)
# Checking sql-js/sql.js (455/1779)
# Checking mdbootstrap/TW-Elements (456/1779)
# Checking requirejs/requirejs (457/1779)
# Checking huggingface/transformers.js (458/1779)
# Checking 4ian/GDevelop (459/1779)
# Checking mholt/PapaParse (460/1779)
# Checking rabbitmq/rabbitmq-server (461/1779)
# Checking HabitRPG/habitica (462/1779)
# Checking dexie/Dexie.js (463/1779)
# Checking PrismJS/prism (464/1779)
# Checking reactioncommerce/reaction (465/1779)
# Checking star7th/showdoc (466/1779)
# Checking react-dates/react-dates (467/1779)
# Checking docker/kitematic (468/1779)
# Checking BrowserSync/browser-sync (469/1779)
# Checking nasa/openmct (470/1779)
# Checking atomiks/tippyjs (471/1779)
# Checking karma-runner/karma (472/1779)
# Checking nightwatchjs/nightwatch (473/1779)
# Checking NetEase/pomelo (474/1779)
# Checking bpampuch/pdfmake (475/1779)
# Checking electerm/electerm (476/1779)
# Checking wenzhixin/bootstrap-table (477/1779)
# Checking josdejong/jsoneditor (478/1779)
# Checking marcotcr/lime (479/1779)
# Checking openlayers/openlayers (480/1779)
# Checking cockpit-project/cockpit (481/1779)
# Checking spencermountain/compromise (482/1779)
# Checking serverless/examples (483/1779)
# Checking chjj/blessed (484/1779)
# Checking piskelapp/piskel (485/1779)
# Checking jxnblk/mdx-deck (486/1779)
# Checking vega/vega (487/1779)
# Checking wix/Detox (488/1779)
# Checking pot-app/pot-desktop (489/1779)
# Checking jquery/jquery-ui (490/1779)
# Checking stylelint/stylelint (491/1779)
# Checking jaredpalmer/razzle (492/1779)
# Checking SillyTavern/SillyTavern (493/1779)
# Checking zotero/zotero (494/1779)
# Checking mickael-kerjean/filestash (495/1779)
# Checking withspectrum/spectrum (496/1779)
# Checking WordPress/gutenberg (497/1779)
# Checking clauderic/react-sortable-hoc (498/1779)
# Checking Nozbe/WatermelonDB (499/1779)
# Checking TheOdinProject/curriculum (500/1779)
# Checking FredrikNoren/ungit (501/1779)
# Checking VickScarlet/lifeRestart (502/1779)
# Checking foliojs/pdfkit (503/1779)
# Checking protobufjs/protobuf.js (504/1779)
# Checking ziahamza/webui-aria2 (505/1779)
# Checking playcanvas/engine (506/1779)
# Checking Stuk/jszip (507/1779)
# Checking ckeditor/ckeditor5 (508/1779)
# Checking easydiffusion/easydiffusion (509/1779)
# Checking sdelements/lets-chat (510/1779)
# Checking streamaserver/streama (511/1779)
# Checking projectdiscovery/nuclei-templates (512/1779)
# Checking jquery-archive/jquery-mobile (513/1779)
# Checking mailcow/mailcow-dockerized (514/1779)
# Checking microsoft/Windows-universal-samples (515/1779)
# Checking vercel/ncc (516/1779)
# Checking eduardolundgren/tracking.js (517/1779)
# Checking hackmdio/codimd (518/1779)
# Checking c3js/c3 (519/1779)
# Checking PipedreamHQ/pipedream (520/1779)
# Checking typekit/webfontloader (521/1779)
# Checking chakra-core/ChakraCore (522/1779)
# Checking evolus/pencil (523/1779)
# Checking didi/chameleon (524/1779)
# Checking swagger-api/swagger-editor (525/1779)
# Checking jshint/jshint (526/1779)
# Checking NUKnightLab/TimelineJS (527/1779)
# Checking bpmn-io/bpmn-js (528/1779)
# Checking terser/terser (529/1779)
# Checking uber/react-vis (530/1779)
# Checking facebookarchive/react-360 (531/1779)
# Checking beautifier/js-beautify (532/1779)
# Checking npm/cli (533/1779)
# Checking bigbluebutton/bigbluebutton (534/1779)
# Checking flutterchina/flutter-in-action (535/1779)
# Checking pmndrs/drei (536/1779)
# Checking react-toolbox/react-toolbox (537/1779)
# Checking plankanban/planka (538/1779)
# Checking tangly1024/NotionNext (539/1779)
# Checking litten/hexo-theme-yilia (540/1779)
# Checking grommet/grommet (541/1779)
# Checking WebKit/WebKit (542/1779)
# Checking seajs/seajs (543/1779)
# Checking MarshallOfSound/Google-Play-Music-Desktop-Player-UNOFFICIAL- (544/1779)
# Checking automatisch/automatisch (545/1779)
# Checking mediaelement/mediaelement (546/1779)
# Checking artilleryio/artillery (547/1779)
# Checking TiddlyWiki/TiddlyWiki5 (548/1779)
# Checking FineUploader/fine-uploader (549/1779)
# Checking google/traceur-compiler (550/1779)
# Checking minbrowser/min (551/1779)
# Checking CreateJS/EaselJS (552/1779)
# Checking jquense/react-big-calendar (553/1779)
# Checking carbon-design-system/carbon (554/1779)
# Checking codecombat/codecombat (555/1779)
# Checking zhukov/webogram (556/1779)
# Checking VulcanJS/Vulcan (557/1779)
# Checking brave/browser-laptop (558/1779)
# Checking antvis/F2 (559/1779)
# Checking styled-system/styled-system (560/1779)
# Checking danialfarid/ng-file-upload (561/1779)
# Checking almende/vis (562/1779)
# Checking facebookarchive/nuclide (563/1779)
# Checking enquirer/enquirer (564/1779)
# Checking amsul/pickadate.js (565/1779)
# Checking fex-team/webuploader (566/1779)
# Checking advplyr/audiobookshelf (567/1779)
# Checking isomorphic-git/isomorphic-git (568/1779)
# Checking dataarts/dat.gui (569/1779)
# Checking twbs/icons (570/1779)
# Checking ethereum/mist (571/1779)
# Checking doublespeakgames/adarkroom (572/1779)
# Checking dc-js/dc.js (573/1779)
# Checking DIYgod/APlayer (574/1779)
# Checking Vincit/objection.js (575/1779)
# Checking kazupon/vue-i18n (576/1779)
# Checking novus/nvd3 (577/1779)
# Checking bitwiseshiftleft/sjcl (578/1779)
# Checking jbaysolutions/vue-grid-layout (579/1779)
# Checking nhn/tui.image-editor (580/1779)
# Checking grocy/grocy (581/1779)
# Checking jagenjo/litegraph.js (582/1779)
# Checking AlaSQL/alasql (583/1779)
# Checking iamcco/markdown-preview.nvim (584/1779)
# Checking jsfiddle/togetherjs (585/1779)
# Checking olifolkerd/tabulator (586/1779)
# Checking idurar/idurar-erp-crm (587/1779)
# Checking garris/BackstopJS (588/1779)
# Checking apollographql/react-apollo (589/1779)
# Checking donnemartin/system-design-primer (590/1779)
# Checking TheAlgorithms/Python (591/1779)
# Checking Significant-Gravitas/AutoGPT (592/1779)
# Checking AUTOMATIC1111/stable-diffusion-webui (593/1779)
# Checking huggingface/transformers (594/1779)
# Checking ytdl-org/youtube-dl (595/1779)
# Checking yt-dlp/yt-dlp (596/1779)
# Checking django/django (597/1779)
# Checking fastapi/fastapi (598/1779)
# Checking tensorflow/models (599/1779)
# Checking home-assistant/core (600/1779)
# Checking 3b1b/manim (601/1779)
# Checking binary-husky/gpt_academic (602/1779)
# Checking comfyanonymous/ComfyUI (603/1779)
# Checking d2l-ai/d2l-zh (604/1779)
# Checking python/cpython (605/1779)
# Checking ansible/ansible (606/1779)
# Checking keras-team/keras (607/1779)
# Checking sherlock-project/sherlock (608/1779)
# Checking scikit-learn/scikit-learn (609/1779)
# Checking OpenInterpreter/open-interpreter (610/1779)
# Checking localstack/localstack (611/1779)
# Checking scrapy/scrapy (612/1779)
# Checking ageitgey/face_recognition (613/1779)
# Checking CorentinJ/Real-Time-Voice-Cloning (614/1779)
# Checking psf/requests (615/1779)
# Checking ultralytics/yolov5 (616/1779)
# Checking commaai/openpilot (617/1779)
# Checking Textualize/rich (618/1779)
# Checking langflow-ai/langflow (619/1779)
# Checking All-Hands-AI/OpenHands (620/1779)
# Checking pandas-dev/pandas (621/1779)
# Checking lllyasviel/Fooocus (622/1779)
# Checking oobabooga/text-generation-webui (623/1779)
# Checking RVC-Boss/GPT-SoVITS (624/1779)
# Checking mingrammer/diagrams (625/1779)
# Checking hiyouga/LLaMA-Factory (626/1779)
# Checking getsentry/sentry (627/1779)
# Checking microsoft/autogen (628/1779)
# Checking hpcaitech/ColossalAI (629/1779)
# Checking run-llama/llama_index (630/1779)
# Checking apache/airflow (631/1779)
# Checking mitmproxy/mitmproxy (632/1779)
# Checking lm-sys/FastChat (633/1779)
# Checking vllm-project/vllm (634/1779)
# Checking streamlit/streamlit (635/1779)
# Checking LAION-AI/Open-Assistant (636/1779)
# Checking deepspeedai/DeepSpeed (637/1779)
# Checking ultralytics/ultralytics (638/1779)
# Checking gradio-app/gradio (639/1779)
# Checking ray-project/ray (640/1779)
# Checking infiniflow/ragflow (641/1779)
# Checking chenfei-wu/TaskMatrix (642/1779)
# Checking ccxt/ccxt (643/1779)
# Checking testerSunshine/12306 (644/1779)
# Checking fxsjy/jieba (645/1779)
# Checking XX-net/XX-Net (646/1779)
# Checking python-poetry/poetry (647/1779)
# Checking geekcomputers/Python (648/1779)
# Checking Pythagora-io/gpt-pilot (649/1779)
# Checking certbot/certbot (650/1779)
# Checking jax-ml/jax (651/1779)
# Checking facebookresearch/fairseq (652/1779)
# Checking explosion/spaCy (653/1779)
# Checking open-mmlab/mmdetection (654/1779)
# Checking ManimCommunity/manim (655/1779)
# Checking Lightning-AI/pytorch-lightning (656/1779)
# Checking numpy/numpy (657/1779)
# Checking encode/django-rest-framework (658/1779)
# Checking tinygrad/tinygrad (659/1779)
# Checking nicolargo/glances (660/1779)
# Checking huggingface/diffusers (661/1779)
# Checking StevenBlack/hosts (662/1779)
# Checking Textualize/textual (663/1779)
# Checking mindsdb/mindsdb (664/1779)
# Checking Aider-AI/aider (665/1779)
# Checking RVC-Project/Retrieval-based-Voice-Conversion-WebUI (666/1779)
# Checking getredash/redash (667/1779)
# Checking microsoft/cascadia-code (668/1779)
# Checking crewAIInc/crewAI (669/1779)
# Checking celery/celery (670/1779)
# Checking JaidedAI/EasyOCR (671/1779)
# Checking Stability-AI/generative-models (672/1779)
# Checking pypa/pipenv (673/1779)
# Checking matterport/Mask_RCNN (674/1779)
# Checking d2l-ai/d2l-en (675/1779)
# Checking roboflow/supervision (676/1779)
# Checking mem0ai/mem0 (677/1779)
# Checking deepinsight/insightface (678/1779)
# Checking PostHog/posthog (679/1779)
# Checking Genesis-Embodied-AI/Genesis (680/1779)
# Checking frappe/erpnext (681/1779)
# Checking HumanSignal/labelImg (682/1779)
# Checking ArchiveBox/ArchiveBox (683/1779)
# Checking pytorch/examples (684/1779)
# Checking exo-explore/exo (685/1779)
# Checking pydantic/pydantic (686/1779)
# Checking microsoft/graphrag (687/1779)
# Checking zulip/zulip (688/1779)
# Checking plotly/dash (689/1779)
# Checking pyg-team/pytorch_geometric (690/1779)
# Checking tornadoweb/tornado (691/1779)
# Checking stanfordnlp/dspy (692/1779)
# Checking harry0703/MoneyPrinterTurbo (693/1779)
# Checking reflex-dev/reflex (694/1779)
# Checking haotian-liu/LLaVA (695/1779)
# Checking ungoogled-software/ungoogled-chromium (696/1779)
# Checking saleor/saleor (697/1779)
# Checking Cinnamon/kotaemon (698/1779)
# Checking microsoft/unilm (699/1779)
# Checking matplotlib/matplotlib (700/1779)
# Checking DS4SD/docling (701/1779)
# Checking VikParuchuri/marker (702/1779)
# Checking mlc-ai/mlc-llm (703/1779)
# Checking recommenders-team/recommenders (704/1779)
# Checking huggingface/datasets (705/1779)
# Checking mlflow/mlflow (706/1779)
# Checking RasaHQ/rasa (707/1779)
# Checking magenta/magenta (708/1779)
# Checking deepset-ai/haystack (709/1779)
# Checking python/mypy (710/1779)
# Checking facebook/prophet (711/1779)
# Checking wagtail/wagtail (712/1779)
# Checking onnx/onnx (713/1779)
# Checking PrefectHQ/prefect (714/1779)
# Checking spotify/luigi (715/1779)
# Checking quantopian/zipline (716/1779)
# Checking kivy/kivy (717/1779)
# Checking Avaiga/taipy (718/1779)
# Checking ocrmypdf/OCRmyPDF (719/1779)
# Checking BerriAI/litellm (720/1779)
# Checking Mikubill/sd-webui-controlnet (721/1779)
# Checking airbytehq/airbyte (722/1779)
# Checking apple/ml-stable-diffusion (723/1779)
# Checking w-okada/voice-changer (724/1779)
# Checking InstaPy/InstaPy (725/1779)
# Checking iperov/DeepFaceLab (726/1779)
# Checking reddit-archive/reddit (727/1779)
# Checking netbox-community/netbox (728/1779)
# Checking Byaidu/PDFMathTranslate (729/1779)
# Checking plotly/plotly.py (730/1779)
# Checking pytorch/vision (731/1779)
# Checking microsoft/qlib (732/1779)
# Checking ipython/ipython (733/1779)
# Checking VikParuchuri/surya (734/1779)
# Checking searxng/searxng (735/1779)
# Checking UKPLab/sentence-transformers (736/1779)
# Checking ranger/ranger (737/1779)
# Checking TransformerOptimus/SuperAGI (738/1779)
# Checking piskvorky/gensim (739/1779)
# Checking tensorflow/tensor2tensor (740/1779)
# Checking aws/aws-cli (741/1779)
# Checking aio-libs/aiohttp (742/1779)
# Checking networkx/networkx (743/1779)
# Checking Rapptz/discord.py (744/1779)
# Checking fabric/fabric (745/1779)
# Checking goauthentik/authentik (746/1779)
# Checking apprenticeharper/DeDRM_tools (747/1779)
# Checking soxoj/maigret (748/1779)
# Checking albumentations-team/albumentations (749/1779)
# Checking eosphoros-ai/DB-GPT (750/1779)
# Checking aleju/imgaug (751/1779)
# Checking codelucas/newspaper (752/1779)
# Checking saltstack/salt (753/1779)
# Checking ansible/awx (754/1779)
# Checking iterative/dvc (755/1779)
# Checking microsoft/nni (756/1779)
# Checking SYSTRAN/faster-whisper (757/1779)
# Checking flairNLP/flair (758/1779)
# Checking ivy-llc/ivy (759/1779)
# Checking wkentaro/labelme (760/1779)
# Checking lss233/chatgpt-mirai-qq-bot (761/1779)
# Checking nltk/nltk (762/1779)
# Checking m-bain/whisperX (763/1779)
# Checking dmlc/dgl (764/1779)
# Checking smicallef/spiderfoot (765/1779)
# Checking wifiphisher/wifiphisher (766/1779)
# Checking PySimpleGUI/PySimpleGUI (767/1779)
# Checking searx/searx (768/1779)
# Checking edgedb/edgedb (769/1779)
# Checking scipy/scipy (770/1779)
# Checking sympy/sympy (771/1779)
# Checking fail2ban/fail2ban (772/1779)
# Checking beetbox/beets (773/1779)
# Checking google-deepmind/alphafold (774/1779)
# Checking cvat-ai/cvat (775/1779)
# Checking ethereum/EIPs (776/1779)
# Checking NVIDIA/NeMo (777/1779)
# Checking PaddlePaddle/PaddleDetection (778/1779)
# Checking dask/dask (779/1779)
# Checking SFTtech/openage (780/1779)
# Checking mwaskom/seaborn (781/1779)
# Checking PaddlePaddle/PaddleHub (782/1779)
# Checking mikf/gallery-dl (783/1779)
# Checking ydataai/ydata-profiling (784/1779)
# Checking pyodide/pyodide (785/1779)
# Checking pytube/pytube (786/1779)
# Checking jina-ai/clip-as-service (787/1779)
# Checking python-pillow/Pillow (788/1779)
# Checking dagster-io/dagster (789/1779)
# Checking Nuitka/Nuitka (790/1779)
# Checking netease-youdao/QAnything (791/1779)
# Checking plasma-umass/scalene (792/1779)
# Checking pytest-dev/pytest (793/1779)
# Checking Gallopsled/pwntools (794/1779)
# Checking PaddlePaddle/PaddleNLP (795/1779)
# Checking flet-dev/flet (796/1779)
# Checking pyinstaller/pyinstaller (797/1779)
# Checking apache/tvm (798/1779)
# Checking TomSchimansky/CustomTkinter (799/1779)
# Checking OWASP/owasp-mastg (800/1779)
# Checking PKU-YuanGroup/Open-Sora-Plan (801/1779)
# Checking meolu/walle-web (802/1779)
# Checking matrix-org/synapse (803/1779)
# Checking ShishirPatil/gorilla (804/1779)
# Checking HKUDS/LightRAG (805/1779)
# Checking h2oai/h2ogpt (806/1779)
# Checking onyx-dot-app/onyx (807/1779)
# Checking borgbackup/borg (808/1779)
# Checking PaddlePaddle/PaddleSpeech (809/1779)
# Checking trustedsec/social-engineer-toolkit (810/1779)
# Checking NVIDIA/Megatron-LM (811/1779)
# Checking evilsocket/opensnitch (812/1779)
# Checking prowler-cloud/prowler (813/1779)
# Checking secdev/scapy (814/1779)
# Checking Chia-Network/chia-blockchain (815/1779)
# Checking dottxt-ai/outlines (816/1779)
# Checking openai/spinningup (817/1779)
# Checking giampaolo/psutil (818/1779)
# Checking statsmodels/statsmodels (819/1779)
# Checking marimo-team/marimo (820/1779)
# Checking dbt-labs/dbt-core (821/1779)
# Checking budtmo/docker-android (822/1779)
# Checking django-cms/django-cms (823/1779)
# Checking amueller/word_cloud (824/1779)
# Checking robotframework/robotframework (825/1779)
# Checking kornia/kornia (826/1779)
# Checking numba/numba (827/1779)
# Checking kedro-org/kedro (828/1779)
# Checking bmaltais/kohya_ss (829/1779)
# Checking fossasia/visdom (830/1779)
# Checking qutebrowser/qutebrowser (831/1779)
# Checking sqlalchemy/sqlalchemy (832/1779)
# Checking modin-project/modin (833/1779)
# Checking microsoft/promptflow (834/1779)
# Checking Theano/Theano (835/1779)
# Checking cupy/cupy (836/1779)
# Checking nerfstudio-project/nerfstudio (837/1779)
# Checking EpistasisLab/tpot (838/1779)
# Checking cython/cython (839/1779)
# Checking doccano/doccano (840/1779)
# Checking huggingface/text-generation-inference (841/1779)
# Checking lllyasviel/stable-diffusion-webui-forge (842/1779)
# Checking hummingbot/hummingbot (843/1779)
# Checking pypa/pip (844/1779)
# Checking vega/altair (845/1779)
# Checking wandb/wandb (846/1779)
# Checking sgl-project/sglang (847/1779)
# Checking scrapinghub/portia (848/1779)
# Checking speechbrain/speechbrain (849/1779)
# Checking keephq/keep (850/1779)
# Checking keras-team/autokeras (851/1779)
# Checking jiaaro/pydub (852/1779)
# Checking voxel51/fiftyone (853/1779)
# Checking facebookresearch/hydra (854/1779)
# Checking facebookresearch/pytorch3d (855/1779)
# Checking facebookresearch/xformers (856/1779)
# Checking huggingface/lerobot (857/1779)
# Checking langchain-ai/langgraph (858/1779)
# Checking voicepaw/so-vits-svc-fork (859/1779)
# Checking pymc-devs/pymc (860/1779)
# Checking yzhao062/pyod (861/1779)
# Checking clips/pattern (862/1779)
# Checking espnet/espnet (863/1779)
# Checking triton-inference-server/server (864/1779)
# Checking canonical/microk8s (865/1779)
# Checking pyro-ppl/pyro (866/1779)
# Checking Uberi/speech_recognition (867/1779)
# Checking n1nj4sec/pupy (868/1779)
# Checking sqlfluff/sqlfluff (869/1779)
# Checking NVIDIA/apex (870/1779)
# Checking open-mmlab/mmsegmentation (871/1779)
# Checking xonsh/xonsh (872/1779)
# Checking Netflix/metaflow (873/1779)
# Checking spyder-ide/spyder (874/1779)
# Checking ltdrdata/ComfyUI-Manager (875/1779)
# Checking conan-io/conan (876/1779)
# Checking kivy/python-for-android (877/1779)
# Checking open-mmlab/Amphion (878/1779)
# Checking FlagOpen/FlagEmbedding (879/1779)
# Checking OctoPrint/OctoPrint (880/1779)
# Checking AirtestProject/Airtest (881/1779)
# Checking yutiansut/QUANTAXIS (882/1779)
# Checking autogluon/autogluon (883/1779)
# Checking lutris/lutris (884/1779)
# Checking vaexio/vaex (885/1779)
# Checking unit8co/darts (886/1779)
# Checking mopidy/mopidy (887/1779)
# Checking sktime/sktime (888/1779)
# Checking thu-ml/tianshou (889/1779)
# Checking google/trax (890/1779)
# Checking mage-ai/mage-ai (891/1779)
# Checking platformio/platformio-core (892/1779)
# Checking explodinggradients/ragas (893/1779)
# Checking readthedocs/readthedocs.org (894/1779)
# Checking pwndbg/pwndbg (895/1779)
# Checking modelscope/FunASR (896/1779)
# Checking googleapis/google-api-python-client (897/1779)
# Checking PaddlePaddle/PaddleGAN (898/1779)
# Checking frappe/frappe (899/1779)
# Checking jupyterhub/jupyterhub (900/1779)
# Checking blacklanternsecurity/bbot (901/1779)
# Checking EleutherAI/lm-evaluation-harness (902/1779)
# Checking angr/angr (903/1779)
# Checking automl/auto-sklearn (904/1779)
# Checking spesmilo/electrum (905/1779)
# Checking jxxghp/MoviePilot (906/1779)
# Checking lmcinnes/umap (907/1779)
# Checking icloud-photos-downloader/icloud_photos_downloader (908/1779)
# Checking openedx/edx-platform (909/1779)
# Checking volatilityfoundation/volatility (910/1779)
# Checking Kozea/WeasyPrint (911/1779)
# Checking bridgecrewio/checkov (912/1779)
# Checking eriklindernoren/PyTorch-YOLOv3 (913/1779)
# Checking bentoml/BentoML (914/1779)
# Checking py-why/dowhy (915/1779)
# Checking LmeSzinc/AzurLaneAutoScript (916/1779)
# Checking EstrellaXD/Auto_Bangumi (917/1779)
# Checking meta-llama/llama-stack (918/1779)
# Checking lbryio/lbry-sdk (919/1779)
# Checking PyGithub/PyGithub (920/1779)
# Checking skypilot-org/skypilot (921/1779)
# Checking intel/ipex-llm (922/1779)
# Checking MagicStack/asyncpg (923/1779)
# Checking LibrePhotos/librephotos (924/1779)
# Checking HIPS/autograd (925/1779)
# Checking coollabsio/coolify (926/1779)
# Checking symfony/symfony (927/1779)
# Checking composer/composer (928/1779)
# Checking nextcloud/server (929/1779)
# Checking monicahq/monica (930/1779)
# Checking filamentphp/filament (931/1779)
# Checking matomo-org/matomo (932/1779)
# Checking sebastianbergmann/phpunit (933/1779)
# Checking firefly-iii/firefly-iii (934/1779)
# Checking BookStackApp/BookStack (935/1779)
# Checking getgrav/grav (936/1779)
# Checking yiisoft/yii2 (937/1779)
# Checking PHPOffice/PhpSpreadsheet (938/1779)
# Checking phpstan/phpstan (939/1779)
# Checking PHP-CS-Fixer/PHP-CS-Fixer (940/1779)
# Checking librespeed/speedtest (941/1779)
# Checking thedevdojo/voyager (942/1779)
# Checking magento/magento2 (943/1779)
# Checking snipe/snipe-it (944/1779)
# Checking typecho/typecho (945/1779)
# Checking docker/labs (946/1779)
# Checking PHPOffice/PHPExcel (947/1779)
# Checking z-song/laravel-admin (948/1779)
# Checking wallabag/wallabag (949/1779)
# Checking phalcon/cphalcon (950/1779)
# Checking FreshRSS/FreshRSS (951/1779)
# Checking squizlabs/PHP_CodeSniffer (952/1779)
# Checking dompdf/dompdf (953/1779)
# Checking mockery/mockery (954/1779)
# Checking doctrine/orm (955/1779)
# Checking woocommerce/woocommerce (956/1779)
# Checking doctrine/dbal (957/1779)
# Checking kanboard/kanboard (958/1779)
# Checking invoiceninja/invoiceninja (959/1779)
# Checking owncloud/core (960/1779)
# Checking PrestaShop/PrestaShop (961/1779)
# Checking Sylius/Sylius (962/1779)
# Checking crater-invoice-inc/crater (963/1779)
# Checking top-think/think (964/1779)
# Checking RSS-Bridge/rss-bridge (965/1779)
# Checking mautic/mautic (966/1779)
# Checking phpmyadmin/phpmyadmin (967/1779)
# Checking PHPOffice/PHPWord (968/1779)
# Checking pterodactyl/panel (969/1779)
# Checking the-benchmarker/web-frameworks (970/1779)
# Checking PrivateBin/PrivateBin (971/1779)
# Checking elementor/elementor (972/1779)
# Checking humhub/humhub (973/1779)
# Checking pixelfed/pixelfed (974/1779)
# Checking hyperf/hyperf (975/1779)
# Checking roundcube/roundcubemail (976/1779)
# Checking Dolibarr/dolibarr (977/1779)
# Checking vimeo/psalm (978/1779)
# Checking phan/phan (979/1779)
# Checking MISP/MISP (980/1779)
# Checking pagekit/pagekit (981/1779)
# Checking phpseclib/phpseclib (982/1779)
# Checking ZoneMinder/zoneminder (983/1779)
# Checking aonez/Keka (984/1779)
# Checking Leantime/leantime (985/1779)
# Checking cydrobolt/polr (986/1779)
# Checking wp-cli/wp-cli (987/1779)
# Checking PHP-FFMpeg/PHP-FFMpeg (988/1779)
# Checking joomla/joomla-cms (989/1779)
# Checking Codeception/Codeception (990/1779)
# Checking salesagility/SuiteCRM (991/1779)
# Checking Qloapps/QloApps (992/1779)
# Checking v2board/v2board (993/1779)
# Checking glpi-project/glpi (994/1779)
# Checking orchidsoftware/platform (995/1779)
# Checking joypixels/emojione (996/1779)
# Checking mpdf/mpdf (997/1779)
# Checking tecnickcom/TCPDF (998/1779)
# Checking statamic/cms (999/1779)
# Checking dokuwiki/dokuwiki (1000/1779)
# Checking php-debugbar/php-debugbar (1001/1779)
# Checking phpDocumentor/phpDocumentor (1002/1779)
# Checking RainLoop/rainloop-webmail (1003/1779)
# Checking EasyCorp/EasyAdminBundle (1004/1779)
# Checking Attendize/Attendize (1005/1779)
# Checking librenms/librenms (1006/1779)
# Checking jqhph/dcat-admin (1007/1779)
# Checking area17/twill (1008/1779)
# Checking wp-graphql/wp-graphql (1009/1779)
# Checking orvice/ss-panel (1010/1779)
# Checking ampache/ampache (1011/1779)
# Checking opnsense/core (1012/1779)
# Checking LycheeOrg/Lychee (1013/1779)
# Checking opensourcepos/opensourcepos (1014/1779)
# Checking kimai/kimai (1015/1779)
# Checking alextselegidis/easyappointments (1016/1779)
# Checking pimcore/pimcore (1017/1779)
# Checking booksbyus/zguide (1018/1779)
# Checking nuwave/lighthouse (1019/1779)
# Checking Piwigo/Piwigo (1020/1779)
# Checking osTicket/osTicket (1021/1779)
# Checking zephir-lang/zephir (1022/1779)
# Checking craftcms/cms (1023/1779)
# Checking pmmp/PocketMine-MP (1024/1779)
# Checking ThinkUpLLC/ThinkUp (1025/1779)
# Checking openemr/openemr (1026/1779)
# Checking outroll/vesta (1027/1779)
# Checking shopware/shopware (1028/1779)
# Checking changeweb/Unifiedtransform (1029/1779)
# Checking top-think/framework (1030/1779)
# Checking consolidation/robo (1031/1779)
# Checking WordPress/wordpress-develop (1032/1779)
# Checking InvoicePlane/InvoicePlane (1033/1779)
# Checking phoronix-test-suite/phoronix-test-suite (1034/1779)
# Checking Open-Web-Analytics/Open-Web-Analytics (1035/1779)
# Checking api-platform/core (1036/1779)
# Checking smalot/pdfparser (1037/1779)
# Checking drush-ops/drush (1038/1779)
# Checking phpipam/phpipam (1039/1779)
# Checking ruflin/Elastica (1040/1779)
# Checking nelmio/NelmioApiDocBundle (1041/1779)
# Checking symfony/symfony-docs (1042/1779)
# Checking slimkit/plus (1043/1779)
# Checking BOINC/boinc (1044/1779)
# Checking infection/infection (1045/1779)
# Checking HDInnovations/UNIT3D-Community-Edition (1046/1779)
# Checking LiveHelperChat/livehelperchat (1047/1779)
# Checking humanmade/S3-Uploads (1048/1779)
# Checking TGMPA/TGM-Plugin-Activation (1049/1779)
# Checking Kunena/Kunena-Forum (1050/1779)
# Checking spipu/html2pdf (1051/1779)
# Checking nilsteampassnet/TeamPass (1052/1779)
# Checking Cacti/cacti (1053/1779)
# Checking johnbillion/query-monitor (1054/1779)
# Checking Automattic/jetpack (1055/1779)
# Checking sabre-io/dav (1056/1779)
# Checking henrywhitaker3/Speedtest-Tracker (1057/1779)
# Checking hashtopolis/server (1058/1779)
# Checking phpactor/phpactor (1059/1779)
# Checking projectsend/projectsend (1060/1779)
# Checking MiczFlor/RPi-Jukebox-RFID (1061/1779)
# Checking torvalds/linux (1062/1779)
# Checking netdata/netdata (1063/1779)
# Checking redis/redis (1064/1779)
# Checking ventoy/Ventoy (1065/1779)
# Checking obsproject/obs-studio (1066/1779)
# Checking git/git (1067/1779)
# Checking php/php-src (1068/1779)
# Checking wg/wrk (1069/1779)
# Checking coolsnowwolf/lede (1070/1779)
# Checking mpv-player/mpv (1071/1779)
# Checking openssl/openssl (1072/1779)
# Checking nginx/nginx (1073/1779)
# Checking libuv/libuv (1074/1779)
# Checking facebook/zstd (1075/1779)
# Checking taosdata/TDengine (1076/1779)
# Checking hashcat/hashcat (1077/1779)
# Checking openwrt/openwrt (1078/1779)
# Checking radareorg/radare2 (1079/1779)
# Checking iovisor/bcc (1080/1779)
# Checking micropython/micropython (1081/1779)
# Checking jart/cosmopolitan (1082/1779)
# Checking valkey-io/valkey (1083/1779)
# Checking qmk/qmk_firmware (1084/1779)
# Checking HandBrake/HandBrake (1085/1779)
# Checking DarkFlippers/unleashed-firmware (1086/1779)
# Checking timescale/timescaledb (1087/1779)
# Checking lvgl/lvgl (1088/1779)
# Checking NVIDIA/open-gpu-kernel-modules (1089/1779)
# Checking ffmpegwasm/ffmpeg.wasm (1090/1779)
# Checking reactos/reactos (1091/1779)
# Checking swaywm/sway (1092/1779)
# Checking espressif/esp-idf (1093/1779)
# Checking sandboxie-plus/Sandboxie (1094/1779)
# Checking sumatrapdfreader/sumatrapdf (1095/1779)
# Checking SpacehuhnTech/esp8266_deauther (1096/1779)
# Checking systemd/systemd (1097/1779)
# Checking vurtun/nuklear (1098/1779)
# Checking tursodatabase/libsql (1099/1779)
# Checking flipperdevices/flipperzero-firmware (1100/1779)
# Checking glfw/glfw (1101/1779)
# Checking audacity/audacity (1102/1779)
# Checking alibaba/tengine (1103/1779)
# Checking ImageMagick/ImageMagick (1104/1779)
# Checking haiwen/seafile (1105/1779)
# Checking SoftEtherVPN/SoftEtherVPN (1106/1779)
# Checking raspberrypi/linux (1107/1779)
# Checking zephyrproject-rtos/zephyr (1108/1779)
# Checking openresty/lua-nginx-module (1109/1779)
# Checking winsiderss/systeminformer (1110/1779)
# Checking OpenVPN/openvpn (1111/1779)
# Checking libsdl-org/SDL (1112/1779)
# Checking libevent/libevent (1113/1779)
# Checking FreeRDP/FreeRDP (1114/1779)
# Checking citusdata/citus (1115/1779)
# Checking h2o/h2o (1116/1779)
# Checking openzfs/zfs (1117/1779)
# Checking libretro/RetroArch (1118/1779)
# Checking RT-Thread/rt-thread (1119/1779)
# Checking openwall/john (1120/1779)
# Checking nmap/nmap (1121/1779)
# Checking fogleman/Craft (1122/1779)
# Checking darktable-org/darktable (1123/1779)
# Checking phpredis/phpredis (1124/1779)
# Checking Klipper3d/klipper (1125/1779)
# Checking libgit2/libgit2 (1126/1779)
# Checking jemalloc/jemalloc (1127/1779)
# Checking i3/i3 (1128/1779)
# Checking Immediate-Mode-UI/Nuklear (1129/1779)
# Checking Tencent/xLua (1130/1779)
# Checking eclipse-mosquitto/mosquitto (1131/1779)
# Checking yugabyte/yugabyte-db (1132/1779)
# Checking xmrig/xmrig (1133/1779)
# Checking betaflight/betaflight (1134/1779)
# Checking AppImage/AppImageKit (1135/1779)
# Checking irungentoo/toxcore (1136/1779)
# Checking pocoproject/poco (1137/1779)
# Checking VirusTotal/yara (1138/1779)
# Checking mattn/go-sqlite3 (1139/1779)
# Checking unicorn-engine/unicorn (1140/1779)
# Checking capstone-engine/capstone (1141/1779)
# Checking floooh/sokol (1142/1779)
# Checking pygame/pygame (1143/1779)
# Checking nodemcu/nodemcu-firmware (1144/1779)
# Checking AdAway/AdAway (1145/1779)
# Checking ahrm/sioyek (1146/1779)
# Checking mit-pdos/xv6-riscv (1147/1779)
# Checking Ralim/IronOS (1148/1779)
# Checking veracrypt/VeraCrypt (1149/1779)
# Checking esnet/iperf (1150/1779)
# Checking microsoft/Windows-driver-samples (1151/1779)
# Checking jerryscript-project/jerryscript (1152/1779)
# Checking flightlessmango/MangoHud (1153/1779)
# Checking fontforge/fontforge (1154/1779)
# Checking universal-ctags/ctags (1155/1779)
# Checking henrypp/simplewall (1156/1779)
# Checking pwn20wndstuff/Undecimus (1157/1779)
# Checking TelegramMessenger/Telegram-iOS (1158/1779)
# Checking fluent/fluent-bit (1159/1779)
# Checking microsoft/WinObjC (1160/1779)
# Checking Provenance-Emu/Provenance (1161/1779)
# Checking netblue30/firejail (1162/1779)
# Checking mgba-emu/mgba (1163/1779)
# Checking neutrinolabs/xrdp (1164/1779)
# Checking ponylang/ponyc (1165/1779)
# Checking Meituan-Dianping/Logan (1166/1779)
# Checking aircrack-ng/aircrack-ng (1167/1779)
# Checking Mbed-TLS/mbedtls (1168/1779)
# Checking pawelsalawa/sqlitestudio (1169/1779)
# Checking RediSearch/RediSearch (1170/1779)
# Checking kbengine/kbengine (1171/1779)
# Checking nginx/unit (1172/1779)
# Checking axboe/fio (1173/1779)
# Checking RIOT-OS/RIOT (1174/1779)
# Checking CameraKit/camerakit-android (1175/1779)
# Checking olikraus/u8g2 (1176/1779)
# Checking guanzhi/GmSSL (1177/1779)
# Checking mruby/mruby (1178/1779)
# Checking swiftlang/swift-corelibs-foundation (1179/1779)
# Checking hathach/tinyusb (1180/1779)
# Checking cjdelisle/cjdns (1181/1779)
# Checking nesbox/TIC-80 (1182/1779)
# Checking bytecodealliance/wasm-micro-runtime (1183/1779)
# Checking uber/h3 (1184/1779)
# Checking warmcat/libwebsockets (1185/1779)
# Checking tianocore/edk2 (1186/1779)
# Checking gluster/glusterfs (1187/1779)
# Checking seL4/seL4 (1188/1779)
# Checking lxc/lxc (1189/1779)
# Checking XProger/OpenLara (1190/1779)
# Checking Cisco-Talos/clamav (1191/1779)
# Checking ARMmbed/mbed-os (1192/1779)
# Checking moonlight-stream/moonlight-android (1193/1779)
# Checking espeak-ng/espeak-ng (1194/1779)
# Checking ossec/ossec-hids (1195/1779)
# Checking aws/s2n-tls (1196/1779)
# Checking flatpak/flatpak (1197/1779)
# Checking u-boot/u-boot (1198/1779)
# Checking ptitSeb/box64 (1199/1779)
# Checking gali8/Tesseract-OCR-iOS (1200/1779)
# Checking microsoft/msquic (1201/1779)
# Checking openvenues/libpostal (1202/1779)
# Checking cloudius-systems/osv (1203/1779)
# Checking BasedHardware/omi (1204/1779)
# ...
# Checking hoffstadt/DearPyGui (1408/1779)
# Checking arangodb/arangodb (1409/1779)
# Checking OpenGenus/cosmos (1410/1779)
# Checking NixOS/nix (1411/1779)
# Checking dolphin-emu/dolphin (1412/1779)
# Checking bulletphysics/bullet3 (1413/1779)
# Checking facebook/watchman (1414/1779)
# Checking transmission/transmission (1415/1779)
# Checking musescore/MuseScore (1416/1779)
# Checking PCSX2/pcsx2 (1417/1779)
# Checking vnotex/vnote (1418/1779)
# Checking xournalpp/xournalpp (1419/1779)
# Checking carla-simulator/carla (1420/1779)
# Checking moonlight-stream/moonlight-qt (1421/1779)
# Checking TheCherno/Hazel (1422/1779)
# Checking capnproto/capnproto (1423/1779)
# Checking isl-org/Open3D (1424/1779)
# Checking ggml-org/ggml (1425/1779)
# Checking hrydgard/ppsspp (1426/1779)
# Checking Snapchat/KeyDB (1427/1779)
# Checking wazuh/wazuh (1428/1779)
# Checking ArduPilot/ardupilot (1429/1779)
# Checking mapeditor/tiled (1430/1779)
# Checking JoeyDeVries/LearnOpenGL (1431/1779)
# Checking EOSIO/eos (1432/1779)
# Checking assimp/assimp (1433/1779)
# Checking apple/turicreate (1434/1779)
# Checking NVIDIA/TensorRT (1435/1779)
# Checking luanti-org/luanti (1436/1779)
# Checking vesoft-inc/nebula (1437/1779)
# Checking CleverRaven/Cataclysm-DDA (1438/1779)
# Checking sonic-pi-net/sonic-pi (1439/1779)
# Checking qgis/QGIS (1440/1779)
# Checking wolfpld/tracy (1441/1779)
# Checking Z3Prover/z3 (1442/1779)
# Checking SFML/SFML (1443/1779)
# Checking organicmaps/organicmaps (1444/1779)
# Checking microsoft/STL (1445/1779)
# Checking PointCloudLibrary/pcl (1446/1779)
# Checking nasa/fprime (1447/1779)
# Checking mawww/kakoune (1448/1779)
# Checking facebook/hermes (1449/1779)
# Checking openframeworks/openFrameworks (1450/1779)
# Checking redpanda-data/redpanda (1451/1779)
# Checking zeromq/libzmq (1452/1779)
# Checking TrinityCore/TrinityCore (1453/1779)
# Checking raulmur/ORB_SLAM2 (1454/1779)
# Checking opencv/opencv_contrib (1455/1779)
# Checking manticoresoftware/manticoresearch (1456/1779)
# Checking rr-debugger/rr (1457/1779)
# Checking NVIDIA/TensorRT-LLM (1458/1779)
# Checking Studio3T/robomongo (1459/1779)
# Checking monero-project/monero (1460/1779)
# Checking hluk/CopyQ (1461/1779)
# Checking WasmEdge/WasmEdge (1462/1779)
# Checking esphome/esphome (1463/1779)
# Checking oceanbase/oceanbase (1464/1779)
# Checking bpftrace/bpftrace (1465/1779)
# Checking PX4/PX4-Autopilot (1466/1779)
# Checking finos/perspective (1467/1779)
# Checking mamedev/mame (1468/1779)
# Checking Maximus5/ConEmu (1469/1779)
# Checking rapidsai/cudf (1470/1779)
# Checking SoftFever/OrcaSlicer (1471/1779)
# Checking scylladb/seastar (1472/1779)
# Checking VowpalWabbit/vowpal_wabbit (1473/1779)
# Checking owasp-modsecurity/ModSecurity (1474/1779)
# Checking sass/node-sass (1475/1779)
# Checking xenia-project/xenia (1476/1779)
# Checking LMMS/lmms (1477/1779)
# Checking tstack/lnav (1478/1779)
# Checking cocos/cocos-engine (1479/1779)
# Checking diasurgical/DevilutionX (1480/1779)
# Checking olive-editor/olive (1481/1779)
# Checking catboost/catboost (1482/1779)
# Checking Stellarium/stellarium (1483/1779)
# Checking colmap/colmap (1484/1779)
# Checking avast/retdec (1485/1779)
# Checking microsoft/cpprestsdk (1486/1779)
# Checking canonical/multipass (1487/1779)
# Checking o3de/o3de (1488/1779)
# Checking prusa3d/PrusaSlicer (1489/1779)
# Checking draios/sysdig (1490/1779)
# Checking openvinotoolkit/openvino (1491/1779)
# Checking IntelRealSense/librealsense (1492/1779)
# Checking project-chip/connectedhomeip (1493/1779)
# Checking cemu-project/Cemu (1494/1779)
# Checking visualfc/liteide (1495/1779)
# Checking neutralinojs/neutralinojs (1496/1779)
# Checking Squirrel/Squirrel.Windows (1497/1779)
# Checking openscad/openscad (1498/1779)
# Checking mamba-org/mamba (1499/1779)
# Checking WebAssembly/wabt (1500/1779)
# Checking juce-framework/JUCE (1501/1779)
# Checking wwmm/easyeffects (1502/1779)
# Checking WinMerge/winmerge (1503/1779)
# Checking UZ-SLAMLab/ORB_SLAM3 (1504/1779)
# Checking Oneflow-Inc/oneflow (1505/1779)
# Checking justcallmekoko/ESP32Marauder (1506/1779)
# Checking azerothcore/azerothcore-wotlk (1507/1779)
# Checking tenacityteam/tenacity-legacy (1508/1779)
# Checking FastLED/FastLED (1509/1779)
# Checking OpenTTD/OpenTTD (1510/1779)
# Checking zeek/zeek (1511/1779)
# Checking google/draco (1512/1779)
# Checking mumble-voip/mumble (1513/1779)
# Checking Project-OSRM/osrm-backend (1514/1779)
# Checking microsoft/microsoft-ui-xaml (1515/1779)
# Checking jomjol/AI-on-the-edge-device (1516/1779)
# Checking amnezia-vpn/amnezia-client (1517/1779)
# Checking cloudflare/workerd (1518/1779)
# Checking interpretml/interpret (1519/1779)
# Checking PixarAnimationStudios/OpenUSD (1520/1779)
# Checking endless-sky/endless-sky (1521/1779)
# Checking PrismLauncher/PrismLauncher (1522/1779)
# Checking wxWidgets/wxWidgets (1523/1779)
# Checking tensorflow/serving (1524/1779)
# Checking ValveSoftware/openvr (1525/1779)
# Checking NVIDIA/cutlass (1526/1779)
# Checking sysown/proxysql (1527/1779)
# Checking goldendict/goldendict (1528/1779)
# Checking NVIDIA/FasterTransformer (1529/1779)
# Checking danmar/cppcheck (1530/1779)
# Checking ethereum-mining/ethminer (1531/1779)
# Checking halide/Halide (1532/1779)
# Checking firebase/firebase-ios-sdk (1533/1779)
# Checking uxlfoundation/oneTBB (1534/1779)
# Checking swig/swig (1535/1779)
# Checking tiny-dnn/tiny-dnn (1536/1779)
# Checking openMVG/openMVG (1537/1779)
# Checking MariaDB/server (1538/1779)
# Checking doxygen/doxygen (1539/1779)
# Checking pixie-io/pixie (1540/1779)
# Checking wesnoth/wesnoth (1541/1779)
# Checking hsutter/cppfront (1542/1779)
# Checking supercollider/supercollider (1543/1779)
# Checking cisco/openh264 (1544/1779)
# Checking cvxpy/cvxpy (1545/1779)
# Checking ledger/ledger (1546/1779)
# Checking TigerVNC/tigervnc (1547/1779)
# Checking arvidn/libtorrent (1548/1779)
# Checking cinder/Cinder (1549/1779)
# Checking rizonesoft/Notepad3 (1550/1779)
# Checking flashlight/flashlight (1551/1779)
# Checking gnuradio/gnuradio (1552/1779)
# Checking NVIDIA/DALI (1553/1779)
# Checking Tencent/puerts (1554/1779)
# Checking CGAL/cgal (1555/1779)
# Checking mhammond/pywin32 (1556/1779)
# Checking Tencent/libpag (1557/1779)
# Checking chriskohlhoff/asio (1558/1779)
# Checking cuberite/cuberite (1559/1779)
# Checking OSGeo/gdal (1560/1779)
# Checking input-leap/input-leap (1561/1779)
# Checking mixxxdj/mixxx (1562/1779)
# Checking phusion/passenger (1563/1779)
# Checking zcash/zcash (1564/1779)
# Checking justadudewhohacks/opencv4nodejs (1565/1779)
# Checking cnr-isti-vclab/meshlab (1566/1779)
# Checking rime/weasel (1567/1779)
# Checking microsoft/SPTAG (1568/1779)
# Checking pbek/QOwnNotes (1569/1779)
# Checking NatronGitHub/Natron (1570/1779)
# Checking qTox/qTox (1571/1779)
# Checking XRPLF/rippled (1572/1779)
# Checking MegEngine/MegEngine (1573/1779)
# Checking vcmi/vcmi (1574/1779)
# Checking nghttp2/nghttp2 (1575/1779)
# Checking LibreCAD/LibreCAD (1576/1779)
# Checking GothenburgBitFactory/taskwarrior (1577/1779)
# Checking libigl/libigl (1578/1779)
# Checking defold/defold (1579/1779)
# Checking valhalla/valhalla (1580/1779)
# Checking panda3d/panda3d (1581/1779)
# Checking opentoonz/opentoonz (1582/1779)
# Checking supertuxkart/stk-code (1583/1779)
# Checking arrayfire/arrayfire (1584/1779)
# Checking facontidavide/PlotJuggler (1585/1779)
# Checking mapsme/omim (1586/1779)
# Checking plaidml/plaidml (1587/1779)
# Checking Tencent/TNN (1588/1779)
# Checking boostorg/beast (1589/1779)
# Checking OAID/Tengine (1590/1779)
# Checking rapidsai/cuml (1591/1779)
# Checking MultiMC/Launcher (1592/1779)
# Checking mapbox/mapbox-gl-native (1593/1779)
# Checking peterbraden/node-opencv (1594/1779)
# Checking ThePhD/sol2 (1595/1779)
# Checking apache/incubator-pagespeed-ngx (1596/1779)
# Checking sass/libsass (1597/1779)
# Checking harfbuzz/harfbuzz (1598/1779)
# Checking clangen/musikcube (1599/1779)
# Checking USCiLab/cereal (1600/1779)
# Checking kripken/ammo.js (1601/1779)
# Checking luau-lang/luau (1602/1779)
# Checking BespokeSynth/BespokeSynth (1603/1779)
# Checking ericniebler/range-v3 (1604/1779)
# Checking Vita3K/Vita3K (1605/1779)
# Checking fritzing/fritzing-app (1606/1779)
# Checking ydb-platform/ydb (1607/1779)
# Checking OGRECave/ogre (1608/1779)
# Checking wang-bin/QtAV (1609/1779)
# Checking meshtastic/firmware (1610/1779)
# Checking BrowserWorks/Waterfox (1611/1779)
# Checking ethereum/aleth (1612/1779)
# Checking opentrack/opentrack (1613/1779)
# Checking microsoft/WindowsAppSDK (1614/1779)
# Checking nuttyartist/notes (1615/1779)
# Checking ValveSoftware/source-sdk-2013 (1616/1779)
# Checking clementine-player/Clementine (1617/1779)
# Checking abumq/easyloggingpp (1618/1779)
# Checking hzeller/rpi-rgb-led-matrix (1619/1779)
# Checking pqrs-org/Karabiner-archived (1620/1779)
# Checking leejet/stable-diffusion.cpp (1621/1779)
# Checking zhuzichu520/FluentUI (1622/1779)
# Checking PowerDNS/pdns (1623/1779)
# Checking google/oboe (1624/1779)
# Checking lightvector/KataGo (1625/1779)
# Checking qpdf/qpdf (1626/1779)
# Checking FLIF-hub/FLIF (1627/1779)
# Checking mapnik/mapnik (1628/1779)
# Checking apache/kvrocks (1629/1779)
# Checking oneapi-src/oneDNN (1630/1779)
# Checking CloudCompare/CloudCompare (1631/1779)
# Checking citizenfx/fivem (1632/1779)
# Checking root-project/cling (1633/1779)
# Checking YosysHQ/yosys (1634/1779)
# Checking zufuliu/notepad4 (1635/1779)
# Checking facebookincubator/velox (1636/1779)
# Checking srsran/srsRAN_4G (1637/1779)
# Checking OpenNMT/CTranslate2 (1638/1779)
# Checking openthread/openthread (1639/1779)
# Checking shader-slang/slang (1640/1779)
# Checking rime/librime (1641/1779)
# Checking domoticz/domoticz (1642/1779)
# Checking giuspen/cherrytree (1643/1779)
# Checking nanocurrency/nano-node (1644/1779)
# Checking melonDS-emu/melonDS (1645/1779)
# Checking mavlink/qgroundcontrol (1646/1779)
# Checking ton-blockchain/ton (1647/1779)
# Checking RobotLocomotion/drake (1648/1779)
# Checking visualboyadvance-m/visualboyadvance-m (1649/1779)
# Checking cyberbotics/webots (1650/1779)
# Checking xtensor-stack/xtensor (1651/1779)
# Checking clab/dynet (1652/1779)
# Checking danielkrupinski/Osiris (1653/1779)
# Checking armory3d/armortools (1654/1779)
# Checking slic3r/Slic3r (1655/1779)
# Checking DS-Homebrew/TWiLightMenu (1656/1779)
# Checking ztxz16/fastllm (1657/1779)
# Checking PurpleI2P/i2pd (1658/1779)
# Checking alibaba/GraphScope (1659/1779)
# Checking GarageGames/Torque3D (1660/1779)
# Checking letscontrolit/ESPEasy (1661/1779)
# Checking solvespace/solvespace (1662/1779)
# Checking openscenegraph/OpenSceneGraph (1663/1779)
# Checking Warzone2100/warzone2100 (1664/1779)
# Checking AtomicGameEngine/AtomicGameEngine (1665/1779)
# Checking pytorch/glow (1666/1779)
# Checking facebook/mcrouter (1667/1779)
# Checking bytedance/lightseq (1668/1779)
# Checking Haivision/srt (1669/1779)
# Checking pgmodeler/pgmodeler (1670/1779)
# Checking homenc/HElib (1671/1779)
# Checking microsoft/DirectXShaderCompiler (1672/1779)
# Checking f3d-app/f3d (1673/1779)
# Checking KhronosGroup/glslang (1674/1779)
# Checking Kitt-AI/snowboy (1675/1779)
# Checking jupyter-xeus/xeus-cling (1676/1779)
# Checking nextcloud/desktop (1677/1779)
# Checking newsboat/newsboat (1678/1779)
# Checking OpenXRay/xray-16 (1679/1779)
# Checking lynckia/licode (1680/1779)
# Checking PaddlePaddle/FastDeploy (1681/1779)
# Checking RawTherapee/RawTherapee (1682/1779)
# Checking microsoft/service-fabric (1683/1779)
# Checking shogun-toolbox/shogun (1684/1779)
# Checking xoseperez/espurna (1685/1779)
# Checking tpoechtrager/osxcross (1686/1779)
# Checking tomahawk-player/tomahawk (1687/1779)
# Checking iree-org/iree (1688/1779)
# Checking introlab/rtabmap (1689/1779)
# Checking rathena/rathena (1690/1779)
# Checking heavyai/heavydb (1691/1779)
# Checking MTG/essentia (1692/1779)
# Checking steveicarus/iverilog (1693/1779)
# Checking openxla/xla (1694/1779)
# Checking texstudio-org/texstudio (1695/1779)
# Checking uncrustify/uncrustify (1696/1779)
# Checking ros-navigation/navigation2 (1697/1779)
# Checking baidu/bfs (1698/1779)
# Checking ihhub/fheroes2 (1699/1779)
# Checking AcademySoftwareFoundation/openvdb (1700/1779)
# Checking randombit/botan (1701/1779)
# Checking libjxl/libjxl (1702/1779)
# Checking mbasso/asm-dom (1703/1779)
# Checking Zylann/godot_voxel (1704/1779)
# Checking 20tab/UnrealEnginePython (1705/1779)
# Checking mapbox/tippecanoe (1706/1779)
# Checking root-project/root (1707/1779)
# Checking facebookresearch/habitat-sim (1708/1779)
# Checking BinomialLLC/basis_universal (1709/1779)
# Checking snes9xgit/snes9x (1710/1779)
# Checking node-webrtc/node-webrtc (1711/1779)
# Checking borglab/gtsam (1712/1779)
# Checking ANYbotics/grid_map (1713/1779)
# Checking verilator/verilator (1714/1779)
# Checking AntiMicroX/antimicrox (1715/1779)
# Checking rails/rails (1716/1779)
# Checking jekyll/jekyll (1717/1779)
# Checking mastodon/mastodon (1718/1779)
# Checking fastlane/fastlane (1719/1779)
# Checking freeCodeCamp/devdocs (1720/1779)
# Checking rapid7/metasploit-framework (1721/1779)
# Checking hashicorp/vagrant (1722/1779)
# Checking ruby/ruby (1723/1779)
# Checking chatwoot/chatwoot (1724/1779)
# Checking forem/forem (1725/1779)
# Checking CocoaPods/CocoaPods (1726/1779)
# Checking spree/spree (1727/1779)
# Checking diaspora/diaspora (1728/1779)
# Checking fluent/fluentd (1729/1779)
# Checking rubocop/rubocop (1730/1779)
# Checking github-linguist/linguist (1731/1779)
# Checking imathis/octopress (1732/1779)
# Checking railsadminteam/rails_admin (1733/1779)
# Checking chef/chef (1734/1779)
# Checking presidentbeef/brakeman (1735/1779)
# Checking instructure/canvas-lms (1736/1779)
# Checking solidusio/solidus (1737/1779)
# Checking asciidoctor/asciidoctor (1738/1779)
# Checking dependabot/dependabot-core (1739/1779)
# Checking opal/opal (1740/1779)
# Checking zammad/zammad (1741/1779)
# Checking activemerchant/active_merchant (1742/1779)
# Checking Freika/dawarich (1743/1779)
# Checking mongodb/mongoid (1744/1779)
# Checking jruby/jruby (1745/1779)
# Checking rubygems/rubygems (1746/1779)
# Checking sorbet/sorbet (1747/1779)
# Checking feedbin/feedbin (1748/1779)
# Checking grosser/parallel_tests (1749/1779)
# Checking citation-style-language/styles (1750/1779)
# Checking oracle/truffleruby (1751/1779)
# Checking SUSE/Portus (1752/1779)
# Checking inspec/inspec (1753/1779)
# Checking googleapis/google-api-ruby-client (1754/1779)
# Checking bensheldon/good_job (1755/1779)
# Checking helpyio/helpy (1756/1779)
# Checking danbooru/danbooru (1757/1779)
# Checking openstreetmap/openstreetmap-website (1758/1779)
# Checking pglombardo/PasswordPusher (1759/1779)
# Checking NREL/api-umbrella (1760/1779)
# Checking TrestleAdmin/trestle (1761/1779)
# Checking castwide/solargraph (1762/1779)
# Checking calabash/calabash-ios (1763/1779)
# Checking Shopify/ruby-lsp (1764/1779)
# Checking openjournals/joss (1765/1779)
# Checking openfarmcc/OpenFarm (1766/1779)
# Checking avo-hq/avo (1767/1779)
# Checking decidim/decidim (1768/1779)
# Checking consuldemocracy/consuldemocracy (1769/1779)
# Checking codetriage/CodeTriage (1770/1779)
# Checking neo4jrb/activegraph (1771/1779)
# Checking github-education-resources/classroom (1772/1779)
# Checking ManageIQ/manageiq (1773/1779)
# Checking coreinfrastructure/best-practices-badge (1774/1779)
# Checking newrelic/newrelic-ruby-agent (1775/1779)
# Checking TracksApp/tracks (1776/1779)
# Checking openfoodfoundation/openfoodnetwork (1777/1779)
# Checking librariesio/libraries.io (1778/1779)
# Checking manyfold3d/manyfold (1779/1779)
#
# Travis CI Usage Statistics:
# Total repositories analyzed: 1779
# Repositories using Travis CI: 246
# Usage percentage: 13.83%
#
# Travis CI usage by language:
#            uses_travis     percentage
#                  count sum
# language
# C                  242  41      16.94
# C++                412  52      12.62
# Java               292  39      13.36
# JavaScript         297  66      22.22
# PHP                136  19      13.97
# Python             336  24       7.14
# Ruby                64   5       7.81
#
# Top 5 repositories with Travis CI by stars:
#                          repo_name    language  stars  total_prs
# 302         jaywcjlove/awesome-mac  JavaScript  79550       1091
# 317  chinese-poetry/chinese-poetry  JavaScript  48682        167
# 320                  moment/moment  JavaScript  48065       2085
# 322                agalwood/Motrix  JavaScript  46639        280
# 324                  meteor/meteor  JavaScript  44546       4189
#
# Results saved to: github_repos_travis_20250213_004917.csv

# %%
import pandas as pd

def filter_travis_repositories(input_file):
    df = pd.read_csv(input_file)
    travis_repos = df[df['uses_travis'] == True]
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_file = f'travis_repositories_{timestamp}.csv'
    travis_repos.to_csv(output_file, index=False)
    print(f"Filtered repositories with Travis CI saved to: {output_file}")
    return travis_repos

if __name__ == "__main__":
    input_file = "/content/github_repos_travis_20250213_004917.csv"
    travis_repos_df = filter_travis_repositories(input_file)
# Out:
# Filtered repositories with Travis CI saved to: travis_repositories_20250213_005251.csv

# %%
import os
import requests
import pandas as pd
from git import Repo
from datetime import datetime
import time

TRAVIS_TOKEN = "your_actual_token"   #put travisCI token here

HEADERS = {
    "Travis-API-Version": "3",
    "Authorization": f"token {TRAVIS_TOKEN}"
}

TRAVIS_API_URL = "https://api.travis-ci.com/repo/{owner}%2F{repo}/builds?limit=1"

CLONE_DIR = "cloned_repos"
os.makedirs(CLONE_DIR, exist_ok=True)

def get_first_travis_commit(repo_path):
    try:
        repo = Repo(repo_path)
        commits = list(repo.iter_commits(paths=".travis.yml"))
        if commits:
            return datetime.utcfromtimestamp(commits[-1].committed_date).strftime('%Y-%m-%d %H:%M:%S')
    except Exception as e:
        print(f"Error retrieving first .travis.yml commit for {repo_path}: {e}")
    return None

def get_last_build_timestamp(owner, repo):
    url = TRAVIS_API_URL.format(owner=owner, repo=repo)
    response = requests.get(url, headers=HEADERS)
    print(f"Checking Travis CI for {owner}/{repo} - Status Code: {response.status_code}")
    if response.status_code == 200:
        builds = response.json().get("builds", [])
        if builds:
            return builds[0].get("finished_at")
        return "No builds found"
    elif response.status_code == 403:
        return "Access forbidden"
    elif response.status_code == 404:
        return "Not Found"
    else:
        return f"Error: {response.status_code}"

def process_repositories(csv_file, output_file, start=0, end=123):
    df = pd.read_csv(csv_file).iloc[start:end]
    df["travis_start_date"] = None
    df["travis_end_date"] = None
    df["travis_duration_days"] = None

    for index, row in df.iterrows():
        repo_url = row["url"]
        repo_name = row["repo_name"]
        owner = repo_url.split("/")[-2]
        repo = repo_url.split("/")[-1]
        print(f"Processing {owner}/{repo}...")

        repo_path = os.path.join(CLONE_DIR, repo)

        if not os.path.exists(repo_path):
            print(f"Cloning {repo_url}...")
            try:
                Repo.clone_from(repo_url, repo_path)
            except Exception as e:
                print(f"Failed to clone {repo_url}: {e}")
                continue

        start_date = get_first_travis_commit(repo_path)
        end_date = get_last_build_timestamp(owner, repo)

        df.at[index, "travis_start_date"] = start_date
        df.at[index, "travis_end_date"] = end_date

        if start_date and end_date and end_date not in ["No builds found", "Not Found", "Access forbidden"]:
            try:
                start_dt = datetime.strptime(start_date, "%Y-%m-%d %H:%M:%S")
                end_dt = datetime.strptime(end_date, "%Y-%m-%dT%H:%M:%SZ")
                duration_days = (end_dt - start_dt).days
            except ValueError:
                duration_days = None
        else:
            duration_days = None

        df.at[index, "travis_duration_days"] = duration_days

        print(f"Processed {repo}: Start={start_date}, End={end_date}, Duration={duration_days}")

        time.sleep(5)

    df.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")

input_csv = "/content/travis_repositories_20250213_005251.csv"
output_csv = "repositories_with_travis_data_1.csv"

process_repositories(input_csv, output_csv, start=0, end=123)
# Out:
# Processing alibaba/nacos...
# Cloning https://github.com/alibaba/nacos...
# Checking Travis CI for alibaba/nacos - Status Code: 200
# Processed nacos: Start=2018-07-20 16:27:23, End=2021-06-17T12:23:37Z, Duration=1062
# Processing alibaba/canal...
# Cloning https://github.com/alibaba/canal...
# Checking Travis CI for alibaba/canal - Status Code: 200
# Processed canal: Start=2019-03-21 08:16:31, End=2021-06-17T09:44:23Z, Duration=819
# Processing alibaba/druid...
# Cloning https://github.com/alibaba/druid...
# Checking Travis CI for alibaba/druid - Status Code: 404
# Processed druid: Start=2016-04-22 09:49:14, End=Not Found, Duration=None
# Processing alibaba/fastjson...
# Cloning https://github.com/alibaba/fastjson...
# Checking Travis CI for alibaba/fastjson - Status Code: 404
# Processed fastjson: Start=2016-04-16 06:01:01, End=Not Found, Duration=None
# Processing apache/incubator-seata...
# Cloning https://github.com/apache/incubator-seata...
# Checking Travis CI for apache/incubator-seata - Status Code: 404
# Processed incubator-seata: Start=2019-01-11 07:16:22, End=Not Found, Duration=None
# Processing OpenAPITools/openapi-generator...
# Cloning https://github.com/OpenAPITools/openapi-generator...
# Checking Travis CI for OpenAPITools/openapi-generator - Status Code: 200
# Processed openapi-generator: Start=2014-02-05 17:08:14, End=2025-02-14T18:42:49Z, Duration=4027
# Processing dianping/cat...
# Cloning https://github.com/dianping/cat...
# Checking Travis CI for dianping/cat - Status Code: 404
# Processed cat: Start=2013-10-18 02:04:44, End=Not Found, Duration=None
# Processing nostra13/Android-Universal-Image-Loader...
# Cloning https://github.com/nostra13/Android-Universal-Image-Loader...
# Checking Travis CI for nostra13/Android-Universal-Image-Loader - Status Code: 404
# Processed Android-Universal-Image-Loader: Start=2013-03-31 10:08:05, End=Not Found, Duration=None
# Processing code4craft/webmagic...
# Cloning https://github.com/code4craft/webmagic...
# Checking Travis CI for code4craft/webmagic - Status Code: 404
# Processed webmagic: Start=2013-06-17 03:14:44, End=Not Found, Duration=None
# Processing stanfordnlp/CoreNLP...
# Cloning https://github.com/stanfordnlp/CoreNLP...
# Checking Travis CI for stanfordnlp/CoreNLP - Status Code: 404
# Processed CoreNLP: Start=2017-01-08 01:47:20, End=Not Found, Duration=None
# Processing MyCATApache/Mycat-Server...
# Cloning https://github.com/MyCATApache/Mycat-Server...
# Checking Travis CI for MyCATApache/Mycat-Server - Status Code: 404
# Processed Mycat-Server: Start=2015-05-29 09:37:26, End=Not Found, Duration=None
# Processing pockethub/PocketHub...
# Cloning https://github.com/pockethub/PocketHub...
# Checking Travis CI for pockethub/PocketHub - Status Code: 200
# Processed PocketHub: Start=2012-11-15 19:01:32, End=2020-10-01T10:20:12Z, Duration=2876
# Processing java-native-access/jna...
# Cloning https://github.com/java-native-access/jna...
# Checking Travis CI for java-native-access/jna - Status Code: 200
# Processed jna: Start=2014-06-25 20:27:17, End=2023-01-30T15:32:30Z, Duration=3140
# Processing checkstyle/checkstyle...
# Cloning https://github.com/checkstyle/checkstyle...
# Checking Travis CI for checkstyle/checkstyle - Status Code: 200
# Processed checkstyle: Start=2013-09-10 14:33:22, End=2024-02-03T23:59:32Z, Duration=3798
# Processing roughike/BottomBar...
# Cloning https://github.com/roughike/BottomBar...
# Checking Travis CI for roughike/BottomBar - Status Code: 404
# Processed BottomBar: Start=2016-08-20 12:32:18, End=Not Found, Duration=None
# Processing naman14/Timber...
# Cloning https://github.com/naman14/Timber...
# Checking Travis CI for naman14/Timber - Status Code: 404
# Processed Timber: Start=2016-01-04 04:24:32, End=Not Found, Duration=None
# Processing rest-assured/rest-assured...
# Cloning https://github.com/rest-assured/rest-assured...
# Checking Travis CI for rest-assured/rest-assured - Status Code: 200
# Processed rest-assured: Start=2014-05-16 16:38:15, End=2021-05-12T00:31:06Z, Duration=2552
# Processing Angel-ML/angel...
# Cloning https://github.com/Angel-ML/angel...
# Checking Travis CI for Angel-ML/angel - Status Code: 404
# Processed angel: Start=2017-06-27 03:39:29, End=Not Found, Duration=None
# Processing guardianproject/haven...
# Cloning https://github.com/guardianproject/haven...
# Checking Travis CI for guardianproject/haven - Status Code: 404
# Processed haven: Start=2017-12-20 18:26:54, End=Not Found, Duration=None
# Processing ArthurHub/Android-Image-Cropper...
# Cloning https://github.com/ArthurHub/Android-Image-Cropper...
# Checking Travis CI for ArthurHub/Android-Image-Cropper - Status Code: 404
# Processed Android-Image-Cropper: Start=2015-12-30 13:45:07, End=Not Found, Duration=None
# Processing jOOQ/jOOQ...
# Cloning https://github.com/jOOQ/jOOQ...
# Checking Travis CI for jOOQ/jOOQ - Status Code: 404
# Processed jOOQ: Start=2013-07-04 13:29:08, End=Not Found, Duration=None
# Processing brianfrankcooper/YCSB...
# Cloning https://github.com/brianfrankcooper/YCSB...
# Checking Travis CI for brianfrankcooper/YCSB - Status Code: 404
# Processed YCSB: Start=2014-03-16 07:26:19, End=Not Found, Duration=None
# Processing jankotek/mapdb...
# Cloning https://github.com/jankotek/mapdb...
# Checking Travis CI for jankotek/mapdb - Status Code: 404
# Processed mapdb: Start=2014-05-13 16:52:34, End=Not Found, Duration=None
# Processing CellularPrivacy/Android-IMSI-Catcher-Detector...
# Cloning https://github.com/CellularPrivacy/Android-IMSI-Catcher-Detector...
# Checking Travis CI for CellularPrivacy/Android-IMSI-Catcher-Detector - Status Code: 404
# Processed Android-IMSI-Catcher-Detector: Start=2014-10-04 05:09:17, End=Not Found, Duration=None
# Processing bisq-network/bisq...
# Cloning https://github.com/bisq-network/bisq...
# Checking Travis CI for bisq-network/bisq - Status Code: 200
# Processed bisq: Start=2014-09-29 07:28:11, End=2021-05-31T13:40:29Z, Duration=2436
# Processing pardom-zz/ActiveAndroid...
# Cloning https://github.com/pardom-zz/ActiveAndroid...
# Checking Travis CI for pardom-zz/ActiveAndroid - Status Code: 404
# Processed ActiveAndroid: Start=2013-07-19 14:43:40, End=Not Found, Duration=None
# Processing hneemann/Digital...
# Cloning https://github.com/hneemann/Digital...
# Checking Travis CI for hneemann/Digital - Status Code: 200
# Processed Digital: Start=2016-06-28 13:31:24, End=2023-10-13T13:53:23Z, Duration=2663
# Processing apache/rocketmq-externals...
# Cloning https://github.com/apache/rocketmq-externals...
# Checking Travis CI for apache/rocketmq-externals - Status Code: 200
# Processed rocketmq-externals: Start=2017-02-04 02:16:44, End=2022-12-08T04:36:31Z, Duration=2133
# Processing bytedeco/javacpp...
# Cloning https://github.com/bytedeco/javacpp...
# Checking Travis CI for bytedeco/javacpp - Status Code: 200
# Processed javacpp: Start=2017-04-10 11:28:02, End=2021-06-12T15:05:42Z, Duration=1524
# Processing azkaban/azkaban...
# Cloning https://github.com/azkaban/azkaban...
# Checking Travis CI for azkaban/azkaban - Status Code: 200
# Processed azkaban: Start=2014-02-04 23:33:57, End=2023-08-29T19:03:35Z, Duration=3492
# Processing ant-media/Ant-Media-Server...
# Cloning https://github.com/ant-media/Ant-Media-Server...
# Checking Travis CI for ant-media/Ant-Media-Server - Status Code: 200
# Processed Ant-Media-Server: Start=2016-02-12 17:47:48, End=2024-07-01T05:40:24Z, Duration=3061
# Processing codingapi/tx-lcn...
# Cloning https://github.com/codingapi/tx-lcn...
# Checking Travis CI for codingapi/tx-lcn - Status Code: 200
# Processed tx-lcn: Start=2020-01-06 15:37:55, End=No builds found, Duration=None
# Processing microsoft/malmo...
# Cloning https://github.com/microsoft/malmo...
# Checking Travis CI for microsoft/malmo - Status Code: 200
# Processed malmo: Start=2016-05-24 15:43:09, End=No builds found, Duration=None
# Processing jlegewie/zotfile...
# Cloning https://github.com/jlegewie/zotfile...
# Checking Travis CI for jlegewie/zotfile - Status Code: 404
# Processed zotfile: Start=2017-10-01 19:09:20, End=Not Found, Duration=None
# Processing andOTP/andOTP...
# Cloning https://github.com/andOTP/andOTP...
# Checking Travis CI for andOTP/andOTP - Status Code: 404
# Processed andOTP: Start=2015-11-23 21:24:18, End=Not Found, Duration=None
# Processing apache/incubator-heron...
# Cloning https://github.com/apache/incubator-heron...
# Checking Travis CI for apache/incubator-heron - Status Code: 200
# Processed incubator-heron: Start=2015-12-21 06:38:59, End=2023-02-14T12:50:29Z, Duration=2612
# Processing jtablesaw/tablesaw...
# Cloning https://github.com/jtablesaw/tablesaw...
# Checking Travis CI for jtablesaw/tablesaw - Status Code: 404
# Processed tablesaw: Start=2017-08-10 22:33:49, End=Not Found, Duration=None
# Processing dtinit/data-transfer-project...
# Cloning https://github.com/dtinit/data-transfer-project...
# Checking Travis CI for dtinit/data-transfer-project - Status Code: 404
# Processed data-transfer-project: Start=2018-01-10 20:37:26, End=Not Found, Duration=None
# Processing openhab/openhab1-addons...
# Cloning https://github.com/openhab/openhab1-addons...
# Checking Travis CI for openhab/openhab1-addons - Status Code: 200
# Processed openhab1-addons: Start=2015-05-13 09:32:34, End=2020-11-03T12:28:53Z, Duration=2001
# Processing jaywcjlove/awesome-mac...
# Cloning https://github.com/jaywcjlove/awesome-mac...
# Checking Travis CI for jaywcjlove/awesome-mac - Status Code: 200
# Processed awesome-mac: Start=2018-01-12 12:50:34, End=No builds found, Duration=None
# Processing chinese-poetry/chinese-poetry...
# Cloning https://github.com/chinese-poetry/chinese-poetry...
# Checking Travis CI for chinese-poetry/chinese-poetry - Status Code: 200
# Processed chinese-poetry: Start=2017-05-26 01:48:13, End=2022-11-14T06:32:18Z, Duration=1998
# Processing moment/moment...
# Cloning https://github.com/moment/moment...
# Checking Travis CI for moment/moment - Status Code: 200
# Processed moment: Start=2012-04-26 22:45:04, End=2022-01-24T12:12:47Z, Duration=3559
# Processing agalwood/Motrix...
# Cloning https://github.com/agalwood/Motrix...
# Checking Travis CI for agalwood/Motrix - Status Code: 200
# Processed Motrix: Start=2018-12-19 04:04:06, End=2020-05-14T16:11:52Z, Duration=512
# Processing meteor/meteor...
# Cloning https://github.com/meteor/meteor...
# Checking Travis CI for meteor/meteor - Status Code: 200
# Processed meteor: Start=2016-05-11 00:32:46, End=2025-02-14T17:47:18Z, Duration=3201
# Processing Dogfalo/materialize...
# Cloning https://github.com/Dogfalo/materialize...
# Checking Travis CI for Dogfalo/materialize - Status Code: 200
# Processed materialize: Start=2015-07-03 23:13:14, End=2022-10-14T08:44:05Z, Duration=2659
# Processing adobe/brackets...
# Cloning https://github.com/adobe/brackets...
# Checking Travis CI for adobe/brackets - Status Code: 200
# Processed brackets: Start=2013-01-24 18:45:28, End=No builds found, Duration=None
# Processing tastejs/todomvc...
# Cloning https://github.com/tastejs/todomvc...
# Checking Travis CI for tastejs/todomvc - Status Code: 200
# Processed todomvc: Start=2014-08-20 12:18:14, End=No builds found, Duration=None
# Processing nylas/nylas-mail...
# Cloning https://github.com/nylas/nylas-mail...
# Checking Travis CI for nylas/nylas-mail - Status Code: 200
# Processed nylas-mail: Start=2015-10-05 21:59:43, End=No builds found, Duration=None
# Processing balderdashy/sails...
# Cloning https://github.com/balderdashy/sails...
# Checking Travis CI for balderdashy/sails - Status Code: 200
# Processed sails: Start=2013-04-01 19:58:32, End=2024-12-20T22:38:27Z, Duration=4281
# Processing rahuldkjain/github-profile-readme-generator...
# Cloning https://github.com/rahuldkjain/github-profile-readme-generator...
# Checking Travis CI for rahuldkjain/github-profile-readme-generator - Status Code: 200
# Processed github-profile-readme-generator: Start=2020-10-25 13:21:22, End=2022-04-16T12:34:11Z, Duration=537
# Processing benweet/stackedit...
# Cloning https://github.com/benweet/stackedit...
# Checking Travis CI for benweet/stackedit - Status Code: 200
# Processed stackedit: Start=2018-02-11 12:32:16, End=2022-10-30T13:15:21Z, Duration=1722
# Processing react-grid-layout/react-grid-layout...
# Cloning https://github.com/react-grid-layout/react-grid-layout...
# Checking Travis CI for react-grid-layout/react-grid-layout - Status Code: 200
# Processed react-grid-layout: Start=2016-12-19 17:40:48, End=No builds found, Duration=None
# Processing petkaantonov/bluebird...
# Cloning https://github.com/petkaantonov/bluebird...
# Checking Travis CI for petkaantonov/bluebird - Status Code: 404
# Processed bluebird: Start=2013-10-30 08:00:49, End=Not Found, Duration=None
# Processing ethereumbook/ethereumbook...
# Cloning https://github.com/ethereumbook/ethereumbook...
# Checking Travis CI for ethereumbook/ethereumbook - Status Code: 404
# Processed ethereumbook: Start=2018-03-23 03:37:26, End=Not Found, Duration=None
# Processing wekan/wekan...
# Cloning https://github.com/wekan/wekan...
# Checking Travis CI for wekan/wekan - Status Code: 404
# Processed wekan: Start=2015-05-12 17:33:50, End=Not Found, Duration=None
# Processing Reactive-Extensions/RxJS...
# Cloning https://github.com/Reactive-Extensions/RxJS...
# Checking Travis CI for Reactive-Extensions/RxJS - Status Code: 404
# Processed RxJS: Start=2013-04-04 20:50:20, End=Not Found, Duration=None
# Processing HelloZeroNet/ZeroNet...
# Cloning https://github.com/HelloZeroNet/ZeroNet...
# Checking Travis CI for HelloZeroNet/ZeroNet - Status Code: 404
# Processed ZeroNet: Start=2015-09-20 10:30:32, End=Not Found, Duration=None
# Processing amark/gun...
# Cloning https://github.com/amark/gun...
# Checking Travis CI for amark/gun - Status Code: 404
# Processed gun: Start=2014-09-13 02:40:42, End=Not Found, Duration=None
# Processing framework7io/framework7...
# Cloning https://github.com/framework7io/framework7...
# Checking Travis CI for framework7io/framework7 - Status Code: 404
# Processed framework7: Start=2014-03-24 16:13:31, End=Not Found, Duration=None
# Processing BoostIO/BoostNote-Legacy...
# Cloning https://github.com/BoostIO/BoostNote-Legacy...
# Checking Travis CI for BoostIO/BoostNote-Legacy - Status Code: 404
# Processed BoostNote-Legacy: Start=2017-01-11 14:10:09, End=Not Found, Duration=None
# Processing yabwe/medium-editor...
# Cloning https://github.com/yabwe/medium-editor...
# Checking Travis CI for yabwe/medium-editor - Status Code: 404
# Processed medium-editor: Start=2013-06-04 02:42:28, End=Not Found, Duration=None
# Processing DIYgod/DPlayer...
# Cloning https://github.com/DIYgod/DPlayer...
# Checking Travis CI for DIYgod/DPlayer - Status Code: 404
# Processed DPlayer: Start=2016-05-03 14:11:47, End=Not Found, Duration=None
# Processing paperjs/paper.js...
# Cloning https://github.com/paperjs/paper.js...
# Checking Travis CI for paperjs/paper.js - Status Code: 200
# Processed paper.js: Start=2015-12-02 04:44:29, End=No builds found, Duration=None
# Processing apexcharts/apexcharts.js...
# Cloning https://github.com/apexcharts/apexcharts.js...
# Checking Travis CI for apexcharts/apexcharts.js - Status Code: 200
# Processed apexcharts.js: Start=2018-08-03 19:29:53, End=2021-09-09T10:24:58Z, Duration=1132
# Processing keystonejs/keystone-classic...
# Cloning https://github.com/keystonejs/keystone-classic...
# Checking Travis CI for keystonejs/keystone-classic - Status Code: 404
# Processed keystone-classic: Start=2014-05-19 01:58:59, End=Not Found, Duration=None
# Processing zalmoxisus/redux-devtools-extension...
# Cloning https://github.com/zalmoxisus/redux-devtools-extension...
# Checking Travis CI for zalmoxisus/redux-devtools-extension - Status Code: 404
# Processed redux-devtools-extension: Start=2016-06-30 09:09:03, End=Not Found, Duration=None
# Processing openstf/stf...
# Cloning https://github.com/openstf/stf...
# Checking Travis CI for openstf/stf - Status Code: 404
# Processed stf: Start=2015-07-14 12:46:29, End=Not Found, Duration=None
# Processing requirejs/requirejs...
# Cloning https://github.com/requirejs/requirejs...
# Checking Travis CI for requirejs/requirejs - Status Code: 404
# Processed requirejs: Start=2015-04-14 20:52:58, End=Not Found, Duration=None
# Processing 4ian/GDevelop...
# Cloning https://github.com/4ian/GDevelop...
# Checking Travis CI for 4ian/GDevelop - Status Code: 200
# Processed GDevelop: Start=2014-07-30 20:11:29, End=2025-02-14T18:34:09Z, Duration=3851
# Processing react-dates/react-dates...
# Cloning https://github.com/react-dates/react-dates...
# Checking Travis CI for react-dates/react-dates - Status Code: 200
# Processed react-dates: Start=2016-08-18 00:21:08, End=No builds found, Duration=None
# Processing docker/kitematic...
# Cloning https://github.com/docker/kitematic...
# Checking Travis CI for docker/kitematic - Status Code: 404
# Processed kitematic: Start=2015-02-10 05:29:40, End=Not Found, Duration=None
# Processing BrowserSync/browser-sync...
# Cloning https://github.com/BrowserSync/browser-sync...
# Checking Travis CI for BrowserSync/browser-sync - Status Code: 404
# Processed browser-sync: Start=2013-10-03 20:51:51, End=Not Found, Duration=None
# Processing NetEase/pomelo...
# Cloning https://github.com/NetEase/pomelo...
# Checking Travis CI for NetEase/pomelo - Status Code: 200
# Processed pomelo: Start=2014-05-28 03:03:03, End=No builds found, Duration=None
# Processing marcotcr/lime...
# Cloning https://github.com/marcotcr/lime...
# Checking Travis CI for marcotcr/lime - Status Code: 404
# Processed lime: Start=2016-08-19 20:11:27, End=Not Found, Duration=None
# Processing serverless/examples...
# Cloning https://github.com/serverless/examples...
# Checking Travis CI for serverless/examples - Status Code: 200
# Processed examples: Start=2016-11-14 16:33:58, End=No builds found, Duration=None
# Processing piskelapp/piskel...
# Cloning https://github.com/piskelapp/piskel...
# Checking Travis CI for piskelapp/piskel - Status Code: 404
# Processed piskel: Start=2012-09-10 22:14:38, End=Not Found, Duration=None
# Processing clauderic/react-sortable-hoc...
# Cloning https://github.com/clauderic/react-sortable-hoc...
# Checking Travis CI for clauderic/react-sortable-hoc - Status Code: 404
# Processed react-sortable-hoc: Start=2016-10-28 02:36:29, End=Not Found, Duration=None
# Processing Stuk/jszip...
# Cloning https://github.com/Stuk/jszip...
# Checking Travis CI for Stuk/jszip - Status Code: 200
# Processed jszip: Start=2013-10-11 07:13:11, End=No builds found, Duration=None
# Processing sdelements/lets-chat...
# Cloning https://github.com/sdelements/lets-chat...
# Checking Travis CI for sdelements/lets-chat - Status Code: 200
# Processed lets-chat: Start=2015-05-20 20:24:41, End=No builds found, Duration=None
# Processing streamaserver/streama...
# Cloning https://github.com/streamaserver/streama...
# Checking Travis CI for streamaserver/streama - Status Code: 404
# Processed streama: Start=2015-08-01 20:28:47, End=Not Found, Duration=None
# Processing jquery-archive/jquery-mobile...
# Cloning https://github.com/jquery-archive/jquery-mobile...
# Checking Travis CI for jquery-archive/jquery-mobile - Status Code: 404
# Processed jquery-mobile: Start=2013-01-26 08:10:21, End=Not Found, Duration=None
# Processing eduardolundgren/tracking.js...
# Cloning https://github.com/eduardolundgren/tracking.js...
# Checking Travis CI for eduardolundgren/tracking.js - Status Code: 404
# Processed tracking.js: Start=2014-07-04 23:16:50, End=Not Found, Duration=None
# Processing c3js/c3...
# Cloning https://github.com/c3js/c3...
# Checking Travis CI for c3js/c3 - Status Code: 404
# Processed c3: Start=2013-11-14 13:14:36, End=Not Found, Duration=None
# Processing typekit/webfontloader...
# Cloning https://github.com/typekit/webfontloader...
# Checking Travis CI for typekit/webfontloader - Status Code: 404
# Processed webfontloader: Start=2013-07-19 08:44:22, End=Not Found, Duration=None
# Processing evolus/pencil...
# Cloning https://github.com/evolus/pencil...
# Checking Travis CI for evolus/pencil - Status Code: 404
# Processed pencil: Start=2015-12-07 11:03:06, End=Not Found, Duration=None
# Processing didi/chameleon...
# Cloning https://github.com/didi/chameleon...
# Checking Travis CI for didi/chameleon - Status Code: 404
# Processed chameleon: Start=2019-01-18 14:34:32, End=Not Found, Duration=None
# Processing uber/react-vis...
# Cloning https://github.com/uber/react-vis...
# Checking Travis CI for uber/react-vis - Status Code: 200
# Processed react-vis: Start=2016-03-31 03:00:49, End=No builds found, Duration=None
# Processing react-toolbox/react-toolbox...
# Cloning https://github.com/react-toolbox/react-toolbox...
# Checking Travis CI for react-toolbox/react-toolbox - Status Code: 404
# Processed react-toolbox: Start=2015-07-25 17:05:30, End=Not Found, Duration=None
# Processing seajs/seajs...
# Cloning https://github.com/seajs/seajs...
# Checking Travis CI for seajs/seajs - Status Code: 404
# Processed seajs: Start=2012-11-14 17:55:29, End=Not Found, Duration=None
# Processing mediaelement/mediaelement...
# Cloning https://github.com/mediaelement/mediaelement...
# Checking Travis CI for mediaelement/mediaelement - Status Code: 404
# Processed mediaelement: Start=2017-01-14 06:17:39, End=Not Found, Duration=None
# Processing FineUploader/fine-uploader...
# Cloning https://github.com/FineUploader/fine-uploader...
# Checking Travis CI for FineUploader/fine-uploader - Status Code: 404
# Processed fine-uploader: Start=2013-05-28 21:24:29, End=Not Found, Duration=None
# Processing google/traceur-compiler...
# Cloning https://github.com/google/traceur-compiler...
# Checking Travis CI for google/traceur-compiler - Status Code: 200
# Processed traceur-compiler: Start=2013-04-18 22:00:49, End=No builds found, Duration=None
# Processing codecombat/codecombat...
# Cloning https://github.com/codecombat/codecombat...
# Checking Travis CI for codecombat/codecombat - Status Code: 404
# Processed codecombat: Start=2014-01-12 19:10:36, End=Not Found, Duration=None
# Processing brave/browser-laptop...
# Cloning https://github.com/brave/browser-laptop...
# Checking Travis CI for brave/browser-laptop - Status Code: 200
# Processed browser-laptop: Start=2015-11-30 21:24:13, End=No builds found, Duration=None
# Processing antvis/F2...
# Cloning https://github.com/antvis/F2...
# Checking Travis CI for antvis/F2 - Status Code: 200
# Processed F2: Start=2017-09-26 06:06:07, End=No builds found, Duration=None
# Processing almende/vis...
# Cloning https://github.com/almende/vis...
# Checking Travis CI for almende/vis - Status Code: 404
# Processed vis: Start=2017-01-07 13:46:55, End=Not Found, Duration=None
# Processing amsul/pickadate.js...
# Cloning https://github.com/amsul/pickadate.js...
# Checking Travis CI for amsul/pickadate.js - Status Code: 404
# Processed pickadate.js: Start=2013-04-01 02:38:11, End=Not Found, Duration=None
# Processing fex-team/webuploader...
# Cloning https://github.com/fex-team/webuploader...
# Checking Travis CI for fex-team/webuploader - Status Code: 404
# Processed webuploader: Start=2014-03-03 11:02:59, End=Not Found, Duration=None
# Processing ethereum/mist...
# Cloning https://github.com/ethereum/mist...
# Checking Travis CI for ethereum/mist - Status Code: 404
# Processed mist: Start=2016-06-06 08:24:51, End=Not Found, Duration=None
# Processing dc-js/dc.js...
# Cloning https://github.com/dc-js/dc.js...
# Checking Travis CI for dc-js/dc.js - Status Code: 404
# Processed dc.js: Start=2012-12-04 21:26:08, End=Not Found, Duration=None
# Processing DIYgod/APlayer...
# Cloning https://github.com/DIYgod/APlayer...
# Checking Travis CI for DIYgod/APlayer - Status Code: 404
# Processed APlayer: Start=2015-12-01 15:16:41, End=Not Found, Duration=None
# Processing novus/nvd3...
# Cloning https://github.com/novus/nvd3...
# Checking Travis CI for novus/nvd3 - Status Code: 404
# Processed nvd3: Start=2015-02-06 15:16:35, End=Not Found, Duration=None
# Processing bitwiseshiftleft/sjcl...
# Cloning https://github.com/bitwiseshiftleft/sjcl...
# Checking Travis CI for bitwiseshiftleft/sjcl - Status Code: 404
# Processed sjcl: Start=2013-10-13 04:14:53, End=Not Found, Duration=None
# Processing jsfiddle/togetherjs...
# Cloning https://github.com/jsfiddle/togetherjs...
# Checking Travis CI for jsfiddle/togetherjs - Status Code: 200
# Processed togetherjs: Start=2014-08-26 21:28:52, End=No builds found, Duration=None
# Processing garris/BackstopJS...
# Cloning https://github.com/garris/BackstopJS...
# Checking Travis CI for garris/BackstopJS - Status Code: 404
# Processed BackstopJS: Start=2015-01-28 22:42:48, End=Not Found, Duration=None
# Processing ccxt/ccxt...
# Cloning https://github.com/ccxt/ccxt...
# Checking Travis CI for ccxt/ccxt - Status Code: 200
# Processed ccxt: Start=2017-07-03 17:12:58, End=2025-02-05T21:38:02Z, Duration=2774
# Processing facebook/prophet...
# Cloning https://github.com/facebook/prophet...
# Checking Travis CI for facebook/prophet - Status Code: 200
# Processed prophet: Start=2017-07-04 15:47:14, End=2021-01-07T20:24:43Z, Duration=1283
# Processing quantopian/zipline...
# Cloning https://github.com/quantopian/zipline...
# Checking Travis CI for quantopian/zipline - Status Code: 200
# Processed zipline: Start=2012-10-19 17:44:42, End=No builds found, Duration=None
# Processing reddit-archive/reddit...
# Cloning https://github.com/reddit-archive/reddit...
# Checking Travis CI for reddit-archive/reddit - Status Code: 404
# Processed reddit: Start=2016-01-14 23:50:47, End=Not Found, Duration=None
# Processing tensorflow/tensor2tensor...
# Cloning https://github.com/tensorflow/tensor2tensor...
# Checking Travis CI for tensorflow/tensor2tensor - Status Code: 200
# Processed tensor2tensor: Start=2017-09-10 18:21:19, End=No builds found, Duration=None
# Processing aleju/imgaug...
# Cloning https://github.com/aleju/imgaug...
# Checking Travis CI for aleju/imgaug - Status Code: 200
# Processed imgaug: Start=2017-08-14 23:39:36, End=No builds found, Duration=None
# Processing codelucas/newspaper...
# Cloning https://github.com/codelucas/newspaper...
# Checking Travis CI for codelucas/newspaper - Status Code: 404
# Processed newspaper: Start=2016-01-15 08:27:41, End=Not Found, Duration=None
# Processing wifiphisher/wifiphisher...
# Cloning https://github.com/wifiphisher/wifiphisher...
# Checking Travis CI for wifiphisher/wifiphisher - Status Code: 200
# Processed wifiphisher: Start=2016-12-28 11:43:16, End=No builds found, Duration=None
# Processing PaddlePaddle/PaddleDetection...
# Cloning https://github.com/PaddlePaddle/PaddleDetection...
# Checking Travis CI for PaddlePaddle/PaddleDetection - Status Code: 200
# Processed PaddleDetection: Start=2019-10-29 06:42:19, End=No builds found, Duration=None
# Processing PaddlePaddle/PaddleHub...
# Cloning https://github.com/PaddlePaddle/PaddleHub...
# Checking Travis CI for PaddlePaddle/PaddleHub - Status Code: 200
# Processed PaddleHub: Start=2019-01-04 07:18:35, End=No builds found, Duration=None
# Processing meolu/walle-web...
# Cloning https://github.com/meolu/walle-web...
# Checking Travis CI for meolu/walle-web - Status Code: 404
# Processed walle-web: Start=2015-10-11 05:56:12, End=Not Found, Duration=None
# Processing PaddlePaddle/PaddleSpeech...
# Cloning https://github.com/PaddlePaddle/PaddleSpeech...
# Checking Travis CI for PaddlePaddle/PaddleSpeech - Status Code: 200
# Processed PaddleSpeech: Start=2017-11-14 13:34:47, End=No builds found, Duration=None
# Processing secdev/scapy...
# Cloning https://github.com/secdev/scapy...
# Checking Travis CI for secdev/scapy - Status Code: 200
# Processed scapy: Start=2016-01-12 10:39:05, End=2021-05-21T13:10:17Z, Duration=1956
# Processing openai/spinningup...
# Cloning https://github.com/openai/spinningup...
# Checking Travis CI for openai/spinningup - Status Code: 404
# Processed spinningup: Start=2018-11-08 16:05:59, End=Not Found, Duration=None
# Processing Theano/Theano...
# Cloning https://github.com/Theano/Theano...
# Checking Travis CI for Theano/Theano - Status Code: 404
# Processed Theano: Start=2012-08-02 20:03:48, End=Not Found, Duration=None
# Processing EpistasisLab/tpot...
# Cloning https://github.com/EpistasisLab/tpot...
# Checking Travis CI for EpistasisLab/tpot - Status Code: 200
# Processed tpot: Start=2015-11-13 17:19:21, End=2021-03-17T21:53:44Z, Duration=1951
# Processing scrapinghub/portia...
# Cloning https://github.com/scrapinghub/portia...
# Checking Travis CI for scrapinghub/portia - Status Code: 200
# Processed portia: Start=2015-02-19 10:25:14, End=No builds found, Duration=None
# Processing jiaaro/pydub...
# Cloning https://github.com/jiaaro/pydub...
# Checking Travis CI for jiaaro/pydub - Status Code: 404
# Processed pydub: Start=2012-05-30 15:10:31, End=Not Found, Duration=None
# Results saved to repositories_with_travis_data_1.csv

# %%
import os
import requests
import pandas as pd
from git import Repo
from datetime import datetime
import time

TRAVIS_TOKEN = "your_actual_token"

HEADERS = {
    "Travis-API-Version": "3",
    "Authorization": f"token {TRAVIS_TOKEN}"
}

TRAVIS_API_URL = "https://api.travis-ci.com/repo/{owner}%2F{repo}/builds?limit=1"

CLONE_DIR = "cloned_repos"
os.makedirs(CLONE_DIR, exist_ok=True)

def get_first_travis_commit(repo_path):
    try:
        repo = Repo(repo_path)
        commits = list(repo.iter_commits(paths=".travis.yml"))
        if commits:
            return datetime.utcfromtimestamp(commits[-1].committed_date).strftime('%Y-%m-%d %H:%M:%S')
    except Exception as e:
        print(f"Error retrieving first .travis.yml commit for {repo_path}: {e}")
    return None

def get_last_build_timestamp(owner, repo):
    url = TRAVIS_API_URL.format(owner=owner, repo=repo)
    response = requests.get(url, headers=HEADERS)
    print(f"Checking Travis CI for {owner}/{repo} - Status Code: {response.status_code}")
    if response.status_code == 200:
        builds = response.json().get("builds", [])
        if builds:
            return builds[0].get("finished_at")
        return "No builds found"
    elif response.status_code == 403:
        return "Access forbidden"
    elif response.status_code == 404:
        return "Not Found"
    else:
        return f"Error: {response.status_code}"

def process_repositories(csv_file, output_file, start=0, end=None):
    df = pd.read_csv(csv_file)
    if end:
        df = df.iloc[start:end]
    df["travis_start_date"] = None
    df["travis_end_date"] = None
    df["travis_duration_days"] = None

    for index, row in df.iterrows():
        repo_url = row["url"]
        repo_name = row["repo_name"]
        owner = repo_url.split("/")[-2]
        repo = repo_url.split("/")[-1]
        print(f"Processing {owner}/{repo}...")
        repo_path = os.path.join(CLONE_DIR, repo)

        if not os.path.exists(repo_path):
            print(f"Cloning {repo_url}...")
            try:
                Repo.clone_from(repo_url, repo_path)
            except Exception as e:
                print(f"Failed to clone {repo_url}: {e}")
                continue
        start_date = get_first_travis_commit(repo_path)
        end_date = get_last_build_timestamp(owner, repo)

        df.at[index, "travis_start_date"] = start_date
        df.at[index, "travis_end_date"] = end_date

        if start_date and end_date and end_date not in ["No builds found", "Not Found", "Access forbidden"]:
            try:
                start_dt = datetime.strptime(start_date, "%Y-%m-%d %H:%M:%S")
                end_dt = datetime.strptime(end_date, "%Y-%m-%dT%H:%M:%SZ")
                duration_days = (end_dt - start_dt).days
            except ValueError:
                duration_days = None
        else:
            duration_days = None

        df.at[index, "travis_duration_days"] = duration_days

        print(f"Processed {repo}: Start={start_date}, End={end_date}, Duration={duration_days}")
        time.sleep(5)

    df.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")

input_csv = "/content/travis_repositories_20250213_005251.csv"
output_csv = "repositories_with_travis_data_2.csv"

process_repositories(input_csv, output_csv, start=123, end=183)
# Out:
# Processing clips/pattern...
# Cloning https://github.com/clips/pattern...
# Checking Travis CI for clips/pattern - Status Code: 404
# Processed pattern: Start=2017-06-04 17:27:08, End=Not Found, Duration=None
# Processing n1nj4sec/pupy...
# Cloning https://github.com/n1nj4sec/pupy...
# Checking Travis CI for n1nj4sec/pupy - Status Code: 404
# Processed pupy: Start=2017-03-11 07:16:43, End=Not Found, Duration=None
# Processing AirtestProject/Airtest...
# Cloning https://github.com/AirtestProject/Airtest...
# Checking Travis CI for AirtestProject/Airtest - Status Code: 404
# Processed Airtest: Start=2018-03-29 16:02:01, End=Not Found, Duration=None
# Processing vaexio/vaex...
# Cloning https://github.com/vaexio/vaex...
# Checking Travis CI for vaexio/vaex - Status Code: 404
# Processed vaex: Start=2015-10-20 18:57:02, End=Not Found, Duration=None
# Processing google/trax...
# Cloning https://github.com/google/trax...
# Checking Travis CI for google/trax - Status Code: 200
# Processed trax: Start=2020-04-25 06:03:27, End=No builds found, Duration=None
# Processing lmcinnes/umap...
# Cloning https://github.com/lmcinnes/umap...
# Checking Travis CI for lmcinnes/umap - Status Code: 200
# Processed umap: Start=2017-11-27 03:02:18, End=2021-07-26T16:20:00Z, Duration=1337
# Processing getgrav/grav...
# Cloning https://github.com/getgrav/grav...
# Checking Travis CI for getgrav/grav - Status Code: 404
# Processed grav: Start=2015-06-17 06:06:57, End=Not Found, Duration=None
# Processing PHPOffice/PHPExcel...
# Cloning https://github.com/PHPOffice/PHPExcel...
# Checking Travis CI for PHPOffice/PHPExcel - Status Code: 200
# Processed PHPExcel: Start=2012-11-23 10:51:34, End=No builds found, Duration=None
# Processing z-song/laravel-admin...
# Cloning https://github.com/z-song/laravel-admin...
# Checking Travis CI for z-song/laravel-admin - Status Code: 404
# Processed laravel-admin: Start=2016-08-05 08:40:31, End=Not Found, Duration=None
# Processing top-think/think...
# Cloning https://github.com/top-think/think...
# Checking Travis CI for top-think/think - Status Code: 200
# Processed think: Start=2015-12-15 15:52:27, End=No builds found, Duration=None
# Processing hyperf/hyperf...
# Cloning https://github.com/hyperf/hyperf...
# Checking Travis CI for hyperf/hyperf - Status Code: 200
# Processed hyperf: Start=2019-06-24 05:10:41, End=No builds found, Duration=None
# Processing Dolibarr/dolibarr...
# Cloning https://github.com/Dolibarr/dolibarr...
# Checking Travis CI for Dolibarr/dolibarr - Status Code: 200
# Processed dolibarr: Start=2013-09-08 21:38:55, End=2025-02-14T23:34:48Z, Duration=4177
# Processing pagekit/pagekit...
# Cloning https://github.com/pagekit/pagekit...
# Checking Travis CI for pagekit/pagekit - Status Code: 404
# Processed pagekit: Start=2015-04-07 19:21:00, End=Not Found, Duration=None
# Processing cydrobolt/polr...
# Cloning https://github.com/cydrobolt/polr...
# Checking Travis CI for cydrobolt/polr - Status Code: 404
# Processed polr: Start=2014-12-28 21:03:46, End=Not Found, Duration=None
# Processing salesagility/SuiteCRM...
# Cloning https://github.com/salesagility/SuiteCRM...
# Checking Travis CI for salesagility/SuiteCRM - Status Code: 200
# Processed SuiteCRM: Start=2016-03-24 09:31:40, End=2023-11-14T11:06:57Z, Duration=2791
# Processing Qloapps/QloApps...
# Cloning https://github.com/Qloapps/QloApps...
# Checking Travis CI for Qloapps/QloApps - Status Code: 404
# Processed QloApps: Start=2018-10-19 09:36:08, End=Not Found, Duration=None
# Processing joypixels/emojione...
# Cloning https://github.com/joypixels/emojione...
# Checking Travis CI for joypixels/emojione - Status Code: 404
# Processed emojione: Start=2015-04-29 10:54:09, End=Not Found, Duration=None
# Processing orvice/ss-panel...
# Cloning https://github.com/orvice/ss-panel...
# Checking Travis CI for orvice/ss-panel - Status Code: 404
# Processed ss-panel: Start=2015-10-12 13:04:41, End=Not Found, Duration=None
# Processing opensourcepos/opensourcepos...
# Cloning https://github.com/opensourcepos/opensourcepos...
# Checking Travis CI for opensourcepos/opensourcepos - Status Code: 200
# Processed opensourcepos: Start=2015-04-06 13:13:36, End=None, Duration=None
# Processing booksbyus/zguide...
# Cloning https://github.com/booksbyus/zguide...
# Checking Travis CI for booksbyus/zguide - Status Code: 404
# Processed zguide: Start=2016-09-07 17:04:57, End=Not Found, Duration=None
# Processing ThinkUpLLC/ThinkUp...
# Cloning https://github.com/ThinkUpLLC/ThinkUp...
# Checking Travis CI for ThinkUpLLC/ThinkUp - Status Code: 404
# Processed ThinkUp: Start=2012-04-20 22:14:13, End=Not Found, Duration=None
# Processing changeweb/Unifiedtransform...
# Cloning https://github.com/changeweb/Unifiedtransform...
# Checking Travis CI for changeweb/Unifiedtransform - Status Code: 200
# Processed Unifiedtransform: Start=2019-04-23 08:43:56, End=2023-01-17T04:46:06Z, Duration=1364
# Processing slimkit/plus...
# Cloning https://github.com/slimkit/plus...
# Checking Travis CI for slimkit/plus - Status Code: 200
# Processed plus: Start=2016-12-29 06:30:14, End=No builds found, Duration=None
# Processing humanmade/S3-Uploads...
# Cloning https://github.com/humanmade/S3-Uploads...
# Checking Travis CI for humanmade/S3-Uploads - Status Code: 200
# Processed S3-Uploads: Start=2015-06-01 21:43:39, End=2025-02-12T14:24:36Z, Duration=3543
# Processing TGMPA/TGM-Plugin-Activation...
# Cloning https://github.com/TGMPA/TGM-Plugin-Activation...
# Checking Travis CI for TGMPA/TGM-Plugin-Activation - Status Code: 200
# Processed TGM-Plugin-Activation: Start=2015-04-22 08:14:03, End=No builds found, Duration=None
# Processing hashcat/hashcat...
# Cloning https://github.com/hashcat/hashcat...
# Checking Travis CI for hashcat/hashcat - Status Code: 404
# Processed hashcat: Start=2016-05-14 19:22:48, End=Not Found, Duration=None
# Processing iovisor/bcc...
# Cloning https://github.com/iovisor/bcc...
# Checking Travis CI for iovisor/bcc - Status Code: 404
# Processed bcc: Start=2017-03-04 19:07:56, End=Not Found, Duration=None
# Processing vurtun/nuklear...
# Cloning https://github.com/vurtun/nuklear...
# Checking Travis CI for vurtun/nuklear - Status Code: 404
# Processed nuklear: Start=2016-04-19 19:20:13, End=Not Found, Duration=None
# Processing haiwen/seafile...
# Cloning https://github.com/haiwen/seafile...
# Checking Travis CI for haiwen/seafile - Status Code: 200
# Processed seafile: Start=2014-06-17 02:51:03, End=No builds found, Duration=None
# Processing SoftEtherVPN/SoftEtherVPN...
# Cloning https://github.com/SoftEtherVPN/SoftEtherVPN...
# Checking Travis CI for SoftEtherVPN/SoftEtherVPN - Status Code: 200
# Processed SoftEtherVPN: Start=2017-12-03 19:47:31, End=2021-05-09T12:58:33Z, Duration=1252
# Processing openresty/lua-nginx-module...
# Cloning https://github.com/openresty/lua-nginx-module...
# Checking Travis CI for openresty/lua-nginx-module - Status Code: 200
# Processed lua-nginx-module: Start=2016-05-15 07:18:25, End=2025-02-13T09:37:30Z, Duration=3196
# Processing libretro/RetroArch...
# Cloning https://github.com/libretro/RetroArch...

# %%
import os
import requests
import pandas as pd
from git import Repo
from datetime import datetime
import time

TRAVIS_TOKEN = "your_actual_token"

HEADERS = {
    "Travis-API-Version": "3",
    "Authorization": f"token {TRAVIS_TOKEN}"
}

TRAVIS_API_URL = "https://api.travis-ci.com/repo/{owner}%2F{repo}/builds?limit=1"

CLONE_DIR = "cloned_repos"
os.makedirs(CLONE_DIR, exist_ok=True)

def get_first_travis_commit(repo_path):
    try:
        repo = Repo(repo_path)
        commits = list(repo.iter_commits(paths=".travis.yml"))
        if commits:
            return datetime.utcfromtimestamp(commits[-1].committed_date).strftime('%Y-%m-%d %H:%M:%S')
    except Exception as e:
        print(f"Error retrieving first .travis.yml commit for {repo_path}: {e}")
    return None

def get_last_build_timestamp(owner, repo):
    url = TRAVIS_API_URL.format(owner=owner, repo=repo)
    response = requests.get(url, headers=HEADERS)
    print(f"Checking Travis CI for {owner}/{repo} - Status Code: {response.status_code}")

    if response.status_code == 200:
        builds = response.json().get("builds", [])
        if builds:
            return builds[0].get("finished_at")
        return "No builds found"
    elif response.status_code == 403:
        return "Access forbidden"
    elif response.status_code == 404:
        return "Not Found"
    else:
        return f"Error: {response.status_code}"

def process_repositories(csv_file, output_file, start=0, end=None):
    df = pd.read_csv(csv_file)
    if end:
        df = df.iloc[start:end]
    df["travis_start_date"] = None
    df["travis_end_date"] = None
    df["travis_duration_days"] = None

    for index, row in df.iterrows():
        repo_url = row["url"]
        repo_name = row["repo_name"]
        owner = repo_url.split("/")[-2]
        repo = repo_url.split("/")[-1]
        print(f"Processing {owner}/{repo}...")
        repo_path = os.path.join(CLONE_DIR, repo)

        if not os.path.exists(repo_path):
            print(f"Cloning {repo_url}...")
            try:
                Repo.clone_from(repo_url, repo_path)
            except Exception as e:
                print(f"Failed to clone {repo_url}: {e}")
                continue

        start_date = get_first_travis_commit(repo_path)
        end_date = get_last_build_timestamp(owner, repo)

        df.at[index, "travis_start_date"] = start_date
        df.at[index, "travis_end_date"] = end_date

        if start_date and end_date and end_date not in ["No builds found", "Not Found", "Access forbidden"]:
            try:
                start_dt = datetime.strptime(start_date, "%Y-%m-%d %H:%M:%S")
                end_dt = datetime.strptime(end_date, "%Y-%m-%dT%H:%M:%SZ")
                duration_days = (end_dt - start_dt).days
            except ValueError:
                duration_days = None
        else:
            duration_days = None

        df.at[index, "travis_duration_days"] = duration_days
        print(f"Processed {repo}: Start={start_date}, End={end_date}, Duration={duration_days}")
        time.sleep(5)
    df.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")

input_csv = "/content/travis_repositories_20250213_005251.csv"
output_csv = "repositories_with_travis_data_3.csv"

process_repositories(input_csv, output_csv, start=200, end=246)
# Out:
# Processing openframeworks/openFrameworks...
# Cloning https://github.com/openframeworks/openFrameworks...
# Checking Travis CI for openframeworks/openFrameworks - Status Code: 200
# Processed openFrameworks: Start=2015-01-12 19:51:26, End=No builds found, Duration=None
# Processing zeromq/libzmq...
# Cloning https://github.com/zeromq/libzmq...
# Checking Travis CI for zeromq/libzmq - Status Code: 200
# Processed libzmq: Start=2013-05-21 07:32:13, End=2021-08-26T17:53:56Z, Duration=3019
# Processing opencv/opencv_contrib...
# Cloning https://github.com/opencv/opencv_contrib...
# Checking Travis CI for opencv/opencv_contrib - Status Code: 404
# Processed opencv_contrib: Start=2014-03-20 19:07:29, End=Not Found, Duration=None
# Processing Studio3T/robomongo...
# Cloning https://github.com/Studio3T/robomongo...
# Checking Travis CI for Studio3T/robomongo - Status Code: 404
# Processed robomongo: Start=2019-01-02 07:21:30, End=Not Found, Duration=None
# Processing mamedev/mame...
# Cloning https://github.com/mamedev/mame...
# Checking Travis CI for mamedev/mame - Status Code: 404
# Processed mame: Start=2015-07-10 14:41:37, End=Not Found, Duration=None
# Processing avast/retdec...
# Cloning https://github.com/avast/retdec...
# Checking Travis CI for avast/retdec - Status Code: 200
# Processed retdec: Start=2018-01-26 15:09:07, End=No builds found, Duration=None
# Processing justcallmekoko/ESP32Marauder...
# Cloning https://github.com/justcallmekoko/ESP32Marauder...
# Checking Travis CI for justcallmekoko/ESP32Marauder - Status Code: 200
# Processed ESP32Marauder: Start=2020-01-31 15:30:22, End=2021-05-21T01:45:25Z, Duration=475
# Processing goldendict/goldendict...
# Cloning https://github.com/goldendict/goldendict...
# Checking Travis CI for goldendict/goldendict - Status Code: 404
# Processed goldendict: Start=2019-01-03 22:44:00, End=Not Found, Duration=None
# Processing ethereum-mining/ethminer...
# Cloning https://github.com/ethereum-mining/ethminer...
# Checking Travis CI for ethereum-mining/ethminer - Status Code: 404
# Processed ethminer: Start=2017-04-23 14:03:01, End=Not Found, Duration=None
# Processing tiny-dnn/tiny-dnn...
# Cloning https://github.com/tiny-dnn/tiny-dnn...
# Checking Travis CI for tiny-dnn/tiny-dnn - Status Code: 404
# Processed tiny-dnn: Start=2016-02-04 11:38:04, End=Not Found, Duration=None
# Processing cisco/openh264...
# Cloning https://github.com/cisco/openh264...
# Checking Travis CI for cisco/openh264 - Status Code: 200
# Processed openh264: Start=2013-12-13 16:59:52, End=No builds found, Duration=None
# Processing OSGeo/gdal...
# Cloning https://github.com/OSGeo/gdal...
# Checking Travis CI for OSGeo/gdal - Status Code: 200
# Processed gdal: Start=2012-10-06 23:32:07, End=2024-08-26T13:06:28Z, Duration=4341
# Processing justadudewhohacks/opencv4nodejs...
# Cloning https://github.com/justadudewhohacks/opencv4nodejs...
# Checking Travis CI for justadudewhohacks/opencv4nodejs - Status Code: 200
# Processed opencv4nodejs: Start=2017-08-26 05:37:31, End=No builds found, Duration=None
# Processing vcmi/vcmi...
# Cloning https://github.com/vcmi/vcmi...
# Checking Travis CI for vcmi/vcmi - Status Code: 404
# Processed vcmi: Start=2014-07-12 13:35:55, End=Not Found, Duration=None
# Processing opentoonz/opentoonz...
# Cloning https://github.com/opentoonz/opentoonz...
# Checking Travis CI for opentoonz/opentoonz - Status Code: 404
# Processed opentoonz: Start=2016-04-25 13:14:06, End=Not Found, Duration=None
# Processing Tencent/TNN...
# Cloning https://github.com/Tencent/TNN...
# Checking Travis CI for Tencent/TNN - Status Code: 200
# Processed TNN: Start=2020-07-06 06:41:21, End=2021-12-07T08:29:48Z, Duration=519
# Processing peterbraden/node-opencv...
# Cloning https://github.com/peterbraden/node-opencv...
# Checking Travis CI for peterbraden/node-opencv - Status Code: 404
# Processed node-opencv: Start=2012-01-20 00:29:24, End=Not Found, Duration=None
# Processing apache/incubator-pagespeed-ngx...
# Cloning https://github.com/apache/incubator-pagespeed-ngx...
# Checking Travis CI for apache/incubator-pagespeed-ngx - Status Code: 200
# Processed incubator-pagespeed-ngx: Start=2016-05-02 20:14:16, End=2022-06-30T19:20:41Z, Duration=2249
# Processing USCiLab/cereal...
# Cloning https://github.com/USCiLab/cereal...
# Checking Travis CI for USCiLab/cereal - Status Code: 200
# Processed cereal: Start=2014-03-12 00:02:36, End=2021-06-22T12:03:22Z, Duration=2659
# Processing wang-bin/QtAV...
# Cloning https://github.com/wang-bin/QtAV...
# Checking Travis CI for wang-bin/QtAV - Status Code: 404
# Processed QtAV: Start=2014-06-30 05:42:54, End=Not Found, Duration=None
# Processing ethereum/aleth...
# Cloning https://github.com/ethereum/aleth...
# Checking Travis CI for ethereum/aleth - Status Code: 404
# Processed aleth: Start=2016-08-12 13:20:59, End=Not Found, Duration=None
# Processing abumq/easyloggingpp...
# Cloning https://github.com/abumq/easyloggingpp...
# Checking Travis CI for abumq/easyloggingpp - Status Code: 404
# Processed easyloggingpp: Start=2013-08-15 13:36:10, End=Not Found, Duration=None
# Processing pqrs-org/Karabiner-archived...
# Cloning https://github.com/pqrs-org/Karabiner-archived...
# Checking Travis CI for pqrs-org/Karabiner-archived - Status Code: 404
# Processed Karabiner-archived: Start=2016-01-03 00:32:51, End=Not Found, Duration=None
# Processing FLIF-hub/FLIF...
# Cloning https://github.com/FLIF-hub/FLIF...
# Checking Travis CI for FLIF-hub/FLIF - Status Code: 404
# Processed FLIF: Start=2015-10-03 21:25:11, End=Not Found, Duration=None
# Processing root-project/cling...
# Cloning https://github.com/root-project/cling...
# Checking Travis CI for root-project/cling - Status Code: 200
# Processed cling: Start=2014-09-25 18:31:01, End=No builds found, Duration=None
# Processing domoticz/domoticz...
# Cloning https://github.com/domoticz/domoticz...
# Checking Travis CI for domoticz/domoticz - Status Code: 200
# Processed domoticz: Start=2015-10-08 06:50:15, End=No builds found, Duration=None
# Processing giuspen/cherrytree...
# Cloning https://github.com/giuspen/cherrytree...
# Checking Travis CI for giuspen/cherrytree - Status Code: 200
# Processed cherrytree: Start=2020-04-20 08:52:26, End=2020-11-21T16:55:52Z, Duration=215
# Processing visualboyadvance-m/visualboyadvance-m...
# Cloning https://github.com/visualboyadvance-m/visualboyadvance-m...
# Checking Travis CI for visualboyadvance-m/visualboyadvance-m - Status Code: 200
# Processed visualboyadvance-m: Start=2018-06-27 02:15:22, End=2021-05-12T18:18:22Z, Duration=1050
# Processing clab/dynet...
# Cloning https://github.com/clab/dynet...
# Checking Travis CI for clab/dynet - Status Code: 404
# Processed dynet: Start=2015-10-23 02:37:48, End=Not Found, Duration=None
# Processing slic3r/Slic3r...
# Cloning https://github.com/slic3r/Slic3r...
# Checking Travis CI for slic3r/Slic3r - Status Code: 200
# Processed Slic3r: Start=2013-09-19 08:42:49, End=2023-09-16T07:30:26Z, Duration=3648
# Processing GarageGames/Torque3D...
# Cloning https://github.com/GarageGames/Torque3D...
# Checking Travis CI for GarageGames/Torque3D - Status Code: 200
# Processed Torque3D: Start=2018-07-09 20:17:48, End=2020-07-01T00:09:57Z, Duration=722
# Processing openscenegraph/OpenSceneGraph...
# Cloning https://github.com/openscenegraph/OpenSceneGraph...
# Checking Travis CI for openscenegraph/OpenSceneGraph - Status Code: 404
# Processed OpenSceneGraph: Start=2016-06-03 11:41:19, End=Not Found, Duration=None
# Processing AtomicGameEngine/AtomicGameEngine...
# Cloning https://github.com/AtomicGameEngine/AtomicGameEngine...
# Checking Travis CI for AtomicGameEngine/AtomicGameEngine - Status Code: 404
# Processed AtomicGameEngine: Start=2017-11-20 12:20:19, End=Not Found, Duration=None
# Processing Haivision/srt...
# Cloning https://github.com/Haivision/srt...
# Checking Travis CI for Haivision/srt - Status Code: 200
# Processed srt: Start=2017-06-23 22:51:40, End=2025-02-14T16:00:49Z, Duration=2792
# Processing Kitt-AI/snowboy...
# Cloning https://github.com/Kitt-AI/snowboy...
# Checking Travis CI for Kitt-AI/snowboy - Status Code: 404
# Processed snowboy: Start=2016-09-20 00:24:46, End=Not Found, Duration=None
# Processing MTG/essentia...
# Cloning https://github.com/MTG/essentia...
# Checking Travis CI for MTG/essentia - Status Code: 404
# Processed essentia: Start=2018-05-17 18:21:12, End=Not Found, Duration=None
# Processing uncrustify/uncrustify...
# Cloning https://github.com/uncrustify/uncrustify...
# Checking Travis CI for uncrustify/uncrustify - Status Code: 200
# Processed uncrustify: Start=2016-03-15 17:45:29, End=No builds found, Duration=None
# Processing baidu/bfs...
# Cloning https://github.com/baidu/bfs...
# Checking Travis CI for baidu/bfs - Status Code: 404
# Processed bfs: Start=2014-12-21 09:12:10, End=Not Found, Duration=None
# Processing mbasso/asm-dom...
# Cloning https://github.com/mbasso/asm-dom...
# Checking Travis CI for mbasso/asm-dom - Status Code: 404
# Processed asm-dom: Start=2017-02-25 19:00:29, End=Not Found, Duration=None
# Processing mapbox/tippecanoe...
# Cloning https://github.com/mapbox/tippecanoe...
# Checking Travis CI for mapbox/tippecanoe - Status Code: 200
# Processed tippecanoe: Start=2015-12-20 23:09:35, End=No builds found, Duration=None
# Processing root-project/root...
# Cloning https://github.com/root-project/root...
# Checking Travis CI for root-project/root - Status Code: 200
# Processed root: Start=2017-03-11 11:52:02, End=No builds found, Duration=None
# Processing ruby/ruby...
# Cloning https://github.com/ruby/ruby...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-82cff58c2c25> in <cell line: 0>()
#     119 output_csv = "repositories_with_travis_data_3.csv"
#     120
# --> 121 process_repositories(input_csv, output_csv, start=200, end=246)
#
# <ipython-input-4-82cff58c2c25> in process_repositories(csv_file, output_file, start, end)
#      78             print(f"Cloning {repo_url}...")
#      79             try:
# ---> 80                 Repo.clone_from(repo_url, repo_path)
#      81             except Exception as e:
#      82                 print(f"Failed to clone {repo_url}: {e}")
#
# /usr/local/lib/python3.11/dist-packages/git/repo/base.py in clone_from(cls, url, to_path, progress, env, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1539         if env is not None:
#    1540             git.update_environment(**env)
# -> 1541         return cls._clone(
#    1542             git,
#    1543             url,
#
# /usr/local/lib/python3.11/dist-packages/git/repo/base.py in _clone(cls, git, url, path, odb_default_type, progress, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1405             )
#    1406         else:
# -> 1407             (stdout, stderr) = proc.communicate()
#    1408             cmdline = getattr(proc, "args", "")
#    1409             cmdline = remove_password_if_present(cmdline)
#
# /usr/lib/python3.11/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.11/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
import pandas as pd

file_1 = "repositories_with_travis_data_1-123.csv"
file_2 = "repositories_with_travis_data_123-140.csv"
file_3 = "repositories_with_travis_data_140-150.csv"
file_4 = "repositories_with_travis_data_150-183.csv"
file_5 = "repositories_with_travis_data_183-246.csv"

df1 = pd.read_csv(file_1)
df2 = pd.read_csv(file_2)
df3 = pd.read_csv(file_3)
df4 = pd.read_csv(file_4)
df5 = pd.read_csv(file_5)

combined_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
combined_df.to_csv("combined_repositories_with_travis_data.csv", index=False)

print("Combined CSV saved as 'combined_repositories_with_travis_data.csv'")
# Out:
# Combined CSV saved as 'combined_repositories_with_travis_data.csv'

# %%
import pandas as pd

csv_path = "/content/combined_repositories_with_travis_data.csv"
df = pd.read_csv(csv_path)

filtered_df = df[df["travis_duration_days"] > 0]

filtered_df.to_csv("filtered_file.csv", index=False)

print("Filtered data saved successfully!")
# Out:
# Filtered data saved successfully!

# %%
import pandas as pd

csv_path = "/content/combined_repositories_with_travis_data.csv"
df = pd.read_csv(csv_path)
filtered_df = df[df["travis_duration_days"] > 0]

filtered_df.to_csv("filtered_file.csv", index=False)

print("Filtered data saved successfully!")
print("Total rows:", len(filtered_df))
print("Total rows:", filtered_df.shape[0])
# Out:
# Filtered data saved successfully!
# Total rows: 70
# Total rows: 70
