# %%
import os
import git

def repo_clone(github_url, local_path):
    if os.path.exists(local_path):
        print(f"Local repo path already exists at {local_path}")
        repo = git.Repo(local_path)
        repo.remotes.origin.pull()
    else:
        print(f"Cloning repository from {github_url} to {local_path}...")
        git.Repo.clone_from(github_url, local_path)
    print("Repository is ready locally.")

def is_test_file(filename):
    # Checks if a file is a test file based on the common formats
    return (
        filename.endswith(('.test', '-test', 'test', 'Test', '.spec', '-spec', 'spec', 'Spec', '.yml', '.yaml'))
        or filename.startswith(('test.', 'test-', 'test ', 'Test', 'spec.', 'spec-', 'spec ', 'Spec'))
    )

def collect_test_files(repo_path):
    #Collects test files
    test_files = []
    for root, dirs, files in os.walk(repo_path):
        print(f"Checking directory: {root}")

        # collects if a folder contains 'test' or 'spec'
        if 'test' in root.split(os.sep) or 'spec' in root.split(os.sep):
            for f in files:
                print(f"Found test file in test/spec folder: {f}")
                test_files.append(os.path.join(root, f))
        else:
            for f in files:
                if is_test_file(f):
                    print(f"Found test file by naming pattern: {f}")
                    test_files.append(os.path.join(root, f))

    return test_files

GITHUB_URL = "https://github.com/ruby/ruby"
LOCAL_PATH = "clonedRepo"

# Clone the repo and find test files
repo_clone(GITHUB_URL, LOCAL_PATH)
test_files = collect_test_files(LOCAL_PATH)

# Print results
if test_files:
    print("\n Test files found:")
    for file in test_files:
        print(file)
else:
    print("\n No test files found.")
# Out:
# Streaming output truncated to the last 5000 lines.
# clonedRepo/spec/ruby/core/env/member_spec.rb
# clonedRepo/spec/ruby/core/env/delete_if_spec.rb
# clonedRepo/spec/ruby/core/env/assoc_spec.rb
# clonedRepo/spec/ruby/core/env/include_spec.rb
# clonedRepo/spec/ruby/core/env/shift_spec.rb
# clonedRepo/spec/ruby/core/env/each_value_spec.rb
# clonedRepo/spec/ruby/core/env/size_spec.rb
# clonedRepo/spec/ruby/core/env/to_a_spec.rb
# clonedRepo/spec/ruby/core/env/empty_spec.rb
# clonedRepo/spec/ruby/core/env/reject_spec.rb
# clonedRepo/spec/ruby/core/env/to_h_spec.rb
# clonedRepo/spec/ruby/core/env/each_spec.rb
# clonedRepo/spec/ruby/core/env/rehash_spec.rb
# clonedRepo/spec/ruby/core/env/fetch_spec.rb
# clonedRepo/spec/ruby/core/env/has_value_spec.rb
# clonedRepo/spec/ruby/core/env/invert_spec.rb
# clonedRepo/spec/ruby/core/env/slice_spec.rb
# clonedRepo/spec/ruby/core/env/to_s_spec.rb
# clonedRepo/spec/ruby/core/env/key_spec.rb
# clonedRepo/spec/ruby/core/env/filter_spec.rb
# clonedRepo/spec/ruby/core/env/values_spec.rb
# clonedRepo/spec/ruby/core/env/to_hash_spec.rb
# clonedRepo/spec/ruby/core/env/each_key_spec.rb
# clonedRepo/spec/ruby/core/env/replace_spec.rb
# clonedRepo/spec/ruby/core/env/delete_spec.rb
# clonedRepo/spec/ruby/core/env/has_key_spec.rb
# clonedRepo/spec/ruby/core/env/value_spec.rb
# clonedRepo/spec/ruby/core/env/dup_spec.rb
# clonedRepo/spec/ruby/core/env/merge_spec.rb
# clonedRepo/spec/ruby/core/env/spec_helper.rb
# clonedRepo/spec/ruby/core/env/length_spec.rb
# clonedRepo/spec/ruby/core/env/store_spec.rb
# clonedRepo/spec/ruby/core/env/keep_if_spec.rb
# clonedRepo/spec/ruby/core/env/element_set_spec.rb
# clonedRepo/spec/ruby/core/env/clone_spec.rb
# clonedRepo/spec/ruby/core/env/inspect_spec.rb
# clonedRepo/spec/ruby/core/env/clear_spec.rb
# clonedRepo/spec/ruby/core/env/element_reference_spec.rb
# clonedRepo/spec/ruby/core/env/except_spec.rb
# clonedRepo/spec/ruby/core/env/select_spec.rb
# clonedRepo/spec/ruby/core/env/rassoc_spec.rb
# clonedRepo/spec/ruby/core/env/keys_spec.rb
# clonedRepo/spec/ruby/core/env/each_pair_spec.rb
# clonedRepo/spec/ruby/core/env/update_spec.rb
# clonedRepo/spec/ruby/core/env/fixtures/common.rb
# clonedRepo/spec/ruby/core/env/shared/store.rb
# clonedRepo/spec/ruby/core/env/shared/include.rb
# clonedRepo/spec/ruby/core/env/shared/each.rb
# clonedRepo/spec/ruby/core/env/shared/length.rb
# clonedRepo/spec/ruby/core/env/shared/value.rb
# clonedRepo/spec/ruby/core/env/shared/select.rb
# clonedRepo/spec/ruby/core/env/shared/update.rb
# clonedRepo/spec/ruby/core/env/shared/to_hash.rb
# clonedRepo/spec/ruby/core/basicobject/equal_value_spec.rb
# clonedRepo/spec/ruby/core/basicobject/singleton_method_added_spec.rb
# clonedRepo/spec/ruby/core/basicobject/initialize_spec.rb
# clonedRepo/spec/ruby/core/basicobject/singleton_method_undefined_spec.rb
# clonedRepo/spec/ruby/core/basicobject/__id__spec.rb
# clonedRepo/spec/ruby/core/basicobject/method_missing_spec.rb
# clonedRepo/spec/ruby/core/basicobject/instance_eval_spec.rb
# clonedRepo/spec/ruby/core/basicobject/instance_exec_spec.rb
# clonedRepo/spec/ruby/core/basicobject/equal_spec.rb
# clonedRepo/spec/ruby/core/basicobject/__send___spec.rb
# clonedRepo/spec/ruby/core/basicobject/singleton_method_removed_spec.rb
# clonedRepo/spec/ruby/core/basicobject/not_spec.rb
# clonedRepo/spec/ruby/core/basicobject/basicobject_spec.rb
# clonedRepo/spec/ruby/core/basicobject/not_equal_spec.rb
# clonedRepo/spec/ruby/core/basicobject/fixtures/classes.rb
# clonedRepo/spec/ruby/core/basicobject/fixtures/common.rb
# clonedRepo/spec/ruby/core/basicobject/fixtures/singleton_method.rb
# clonedRepo/spec/ruby/core/basicobject/fixtures/remove_method_missing.rb
# clonedRepo/spec/ruby/language/return_spec.rb
# clonedRepo/spec/ruby/language/assignments_spec.rb
# clonedRepo/spec/ruby/language/if_spec.rb
# clonedRepo/spec/ruby/language/symbol_spec.rb
# clonedRepo/spec/ruby/language/constants_spec.rb
# clonedRepo/spec/ruby/language/file_spec.rb
# clonedRepo/spec/ruby/language/variables_spec.rb
# clonedRepo/spec/ruby/language/proc_spec.rb
# clonedRepo/spec/ruby/language/comment_spec.rb
# clonedRepo/spec/ruby/language/optional_assignments_spec.rb
# clonedRepo/spec/ruby/language/encoding_spec.rb
# clonedRepo/spec/ruby/language/throw_spec.rb
# clonedRepo/spec/ruby/language/line_spec.rb
# clonedRepo/spec/ruby/language/README
# clonedRepo/spec/ruby/language/singleton_class_spec.rb
# clonedRepo/spec/ruby/language/rescue_spec.rb
# clonedRepo/spec/ruby/language/while_spec.rb
# clonedRepo/spec/ruby/language/regexp_spec.rb
# clonedRepo/spec/ruby/language/case_spec.rb
# clonedRepo/spec/ruby/language/range_spec.rb
# clonedRepo/spec/ruby/language/def_spec.rb
# clonedRepo/spec/ruby/language/module_spec.rb
# clonedRepo/spec/ruby/language/hash_spec.rb
# clonedRepo/spec/ruby/language/loop_spec.rb
# clonedRepo/spec/ruby/language/or_spec.rb
# clonedRepo/spec/ruby/language/numbered_parameters_spec.rb
# clonedRepo/spec/ruby/language/block_spec.rb
# clonedRepo/spec/ruby/language/not_spec.rb
# clonedRepo/spec/ruby/language/string_spec.rb
# clonedRepo/spec/ruby/language/and_spec.rb
# clonedRepo/spec/ruby/language/execution_spec.rb
# clonedRepo/spec/ruby/language/lambda_spec.rb
# clonedRepo/spec/ruby/language/send_spec.rb
# clonedRepo/spec/ruby/language/defined_spec.rb
# clonedRepo/spec/ruby/language/unless_spec.rb
# clonedRepo/spec/ruby/language/for_spec.rb
# clonedRepo/spec/ruby/language/redo_spec.rb
# clonedRepo/spec/ruby/language/safe_spec.rb
# clonedRepo/spec/ruby/language/metaclass_spec.rb
# clonedRepo/spec/ruby/language/heredoc_spec.rb
# clonedRepo/spec/ruby/language/keyword_arguments_spec.rb
# clonedRepo/spec/ruby/language/array_spec.rb
# clonedRepo/spec/ruby/language/END_spec.rb
# clonedRepo/spec/ruby/language/until_spec.rb
# clonedRepo/spec/ruby/language/match_spec.rb
# clonedRepo/spec/ruby/language/delegation_spec.rb
# clonedRepo/spec/ruby/language/alias_spec.rb
# clonedRepo/spec/ruby/language/source_encoding_spec.rb
# clonedRepo/spec/ruby/language/BEGIN_spec.rb
# clonedRepo/spec/ruby/language/method_spec.rb
# clonedRepo/spec/ruby/language/predefined_spec.rb
# clonedRepo/spec/ruby/language/class_spec.rb
# clonedRepo/spec/ruby/language/magic_comment_spec.rb
# clonedRepo/spec/ruby/language/ensure_spec.rb
# clonedRepo/spec/ruby/language/precedence_spec.rb
# clonedRepo/spec/ruby/language/private_spec.rb
# clonedRepo/spec/ruby/language/retry_spec.rb
# clonedRepo/spec/ruby/language/numbers_spec.rb
# clonedRepo/spec/ruby/language/yield_spec.rb
# clonedRepo/spec/ruby/language/undef_spec.rb
# clonedRepo/spec/ruby/language/class_variable_spec.rb
# clonedRepo/spec/ruby/language/safe_navigator_spec.rb
# clonedRepo/spec/ruby/language/pattern_matching_spec.rb
# clonedRepo/spec/ruby/language/break_spec.rb
# clonedRepo/spec/ruby/language/order_spec.rb
# clonedRepo/spec/ruby/language/next_spec.rb
# clonedRepo/spec/ruby/language/super_spec.rb
# clonedRepo/spec/ruby/language/regexp/escapes_spec.rb
# clonedRepo/spec/ruby/language/regexp/modifiers_spec.rb
# clonedRepo/spec/ruby/language/regexp/repetition_spec.rb
# clonedRepo/spec/ruby/language/regexp/empty_checks_spec.rb
# clonedRepo/spec/ruby/language/regexp/encoding_spec.rb
# clonedRepo/spec/ruby/language/regexp/anchors_spec.rb
# clonedRepo/spec/ruby/language/regexp/grouping_spec.rb
# clonedRepo/spec/ruby/language/regexp/subexpression_call_spec.rb
# clonedRepo/spec/ruby/language/regexp/back-references_spec.rb
# clonedRepo/spec/ruby/language/regexp/character_classes_spec.rb
# clonedRepo/spec/ruby/language/regexp/interpolation_spec.rb
# clonedRepo/spec/ruby/language/predefined/toplevel_binding_spec.rb
# clonedRepo/spec/ruby/language/predefined/data_spec.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/data1.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_variables.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/data4.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/print_data.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_values.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/data3.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/data5.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/data_offset.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/empty_data.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/data2.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_dynamic.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_variables_required.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/data_only.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_required_before.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_dynamic_required.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_id.rb
# clonedRepo/spec/ruby/language/predefined/fixtures/toplevel_binding_id_required.rb
# clonedRepo/spec/ruby/language/pattern_matching/3.1.rb
# clonedRepo/spec/ruby/language/fixtures/utf8-nobom.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_required_diff_enc.rb
# clonedRepo/spec/ruby/language/fixtures/for_scope.rb
# clonedRepo/spec/ruby/language/fixtures/defined.rb
# clonedRepo/spec/ruby/language/fixtures/second_line_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/rescue_captures.rb
# clonedRepo/spec/ruby/language/fixtures/break_lambda_toplevel.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_across_files_diff_enc.rb
# clonedRepo/spec/ruby/language/fixtures/dollar_zero.rb
# clonedRepo/spec/ruby/language/fixtures/bytes_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/send.rb
# clonedRepo/spec/ruby/language/fixtures/def.rb
# clonedRepo/spec/ruby/language/fixtures/argv_encoding.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_across_files.rb
# clonedRepo/spec/ruby/language/fixtures/begin_file.rb
# clonedRepo/spec/ruby/language/fixtures/no_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/delegation.rb
# clonedRepo/spec/ruby/language/fixtures/vim_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/rescue.rb
# clonedRepo/spec/ruby/language/fixtures/hash_strings_binary.rb
# clonedRepo/spec/ruby/language/fixtures/array.rb
# clonedRepo/spec/ruby/language/fixtures/utf16-be-nobom.rb
# clonedRepo/spec/ruby/language/fixtures/print_magic_comment_result_at_exit.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_required_no_comment.rb
# clonedRepo/spec/ruby/language/fixtures/module.rb
# clonedRepo/spec/ruby/language/fixtures/metaclass.rb
# clonedRepo/spec/ruby/language/fixtures/ensure.rb
# clonedRepo/spec/ruby/language/fixtures/hash_strings_usascii.rb
# clonedRepo/spec/ruby/language/fixtures/coding_us_ascii.rb
# clonedRepo/spec/ruby/language/fixtures/coding_utf_8.rb
# clonedRepo/spec/ruby/language/fixtures/yield.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_across_files_no_comment.rb
# clonedRepo/spec/ruby/language/fixtures/binary_symbol.rb
# clonedRepo/spec/ruby/language/fixtures/file.rb
# clonedRepo/spec/ruby/language/fixtures/classes.rb
# clonedRepo/spec/ruby/language/fixtures/utf16-le-nobom.rb
# clonedRepo/spec/ruby/language/fixtures/break_lambda_toplevel_block.rb
# clonedRepo/spec/ruby/language/fixtures/break.rb
# clonedRepo/spec/ruby/language/fixtures/constants_sclass.rb
# clonedRepo/spec/ruby/language/fixtures/match_operators.rb
# clonedRepo/spec/ruby/language/fixtures/next.rb
# clonedRepo/spec/ruby/language/fixtures/shebang_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/private.rb
# clonedRepo/spec/ruby/language/fixtures/break_lambda_toplevel_method.rb
# clonedRepo/spec/ruby/language/fixtures/precedence.rb
# clonedRepo/spec/ruby/language/fixtures/super.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_two_literals.rb
# clonedRepo/spec/ruby/language/fixtures/second_token_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/case_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_one_literal.rb
# clonedRepo/spec/ruby/language/fixtures/variables.rb
# clonedRepo/spec/ruby/language/fixtures/utf8-bom.rb
# clonedRepo/spec/ruby/language/fixtures/emacs_magic_comment.rb
# clonedRepo/spec/ruby/language/fixtures/return.rb
# clonedRepo/spec/ruby/language/fixtures/hash_strings_utf8.rb
# clonedRepo/spec/ruby/language/fixtures/constant_visibility.rb
# clonedRepo/spec/ruby/language/fixtures/squiggly_heredoc.rb
# clonedRepo/spec/ruby/language/fixtures/freeze_magic_comment_required.rb
# clonedRepo/spec/ruby/language/fixtures/block.rb
# clonedRepo/spec/ruby/language/fixtures/rescue/top_level.rb
# clonedRepo/spec/ruby/language/shared/__FILE__.rb
# clonedRepo/spec/ruby/language/shared/__LINE__.rb
# clonedRepo/spec/ruby/security/cve_2019_8323_spec.rb
# clonedRepo/spec/ruby/security/cve_2011_4815_spec.rb
# clonedRepo/spec/ruby/security/cve_2013_4164_spec.rb
# clonedRepo/spec/ruby/security/cve_2018_8778_spec.rb
# clonedRepo/spec/ruby/security/cve_2024_49761_spec.rb
# clonedRepo/spec/ruby/security/cve_2020_10663_spec.rb
# clonedRepo/spec/ruby/security/cve_2010_1330_spec.rb
# clonedRepo/spec/ruby/security/cve_2018_6914_spec.rb
# clonedRepo/spec/ruby/security/cve_2019_8322_spec.rb
# clonedRepo/spec/ruby/security/cve_2018_8779_spec.rb
# clonedRepo/spec/ruby/security/cve_2018_16396_spec.rb
# clonedRepo/spec/ruby/security/cve_2019_8325_spec.rb
# clonedRepo/spec/ruby/security/cve_2018_8780_spec.rb
# clonedRepo/spec/ruby/security/cve_2019_8321_spec.rb
# clonedRepo/spec/ruby/command_line/dash_v_spec.rb
# clonedRepo/spec/ruby/command_line/dash_a_spec.rb
# clonedRepo/spec/ruby/command_line/frozen_strings_spec.rb
# clonedRepo/spec/ruby/command_line/dash_l_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_e_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_u_spec.rb
# clonedRepo/spec/ruby/command_line/dash_internal_encoding_spec.rb
# clonedRepo/spec/ruby/command_line/dash_encoding_spec.rb
# clonedRepo/spec/ruby/command_line/dash_external_encoding_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_i_spec.rb
# clonedRepo/spec/ruby/command_line/syntax_error_spec.rb
# clonedRepo/spec/ruby/command_line/dash_p_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_s_spec.rb
# clonedRepo/spec/ruby/command_line/error_message_spec.rb
# clonedRepo/spec/ruby/command_line/backtrace_limit_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_k_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_f_spec.rb
# clonedRepo/spec/ruby/command_line/dash_x_spec.rb
# clonedRepo/spec/ruby/command_line/dash_w_spec.rb
# clonedRepo/spec/ruby/command_line/dash_d_spec.rb
# clonedRepo/spec/ruby/command_line/feature_spec.rb
# clonedRepo/spec/ruby/command_line/rubyopt_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_c_spec.rb
# clonedRepo/spec/ruby/command_line/dash_n_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_x_spec.rb
# clonedRepo/spec/ruby/command_line/dash_r_spec.rb
# clonedRepo/spec/ruby/command_line/dash_s_spec.rb
# clonedRepo/spec/ruby/command_line/dash_upper_w_spec.rb
# clonedRepo/spec/ruby/command_line/dash_e_spec.rb
# clonedRepo/spec/ruby/command_line/rubylib_spec.rb
# clonedRepo/spec/ruby/command_line/dash_c_spec.rb
# clonedRepo/spec/ruby/command_line/fixtures/debug.rb
# clonedRepo/spec/ruby/command_line/fixtures/test_file.rb
# clonedRepo/spec/ruby/command_line/fixtures/loadpath.rb
# clonedRepo/spec/ruby/command_line/fixtures/conditional_range.txt
# clonedRepo/spec/ruby/command_line/fixtures/full_names.txt
# clonedRepo/spec/ruby/command_line/fixtures/rubyopt.rb
# clonedRepo/spec/ruby/command_line/fixtures/freeze_flag_across_files.rb
# clonedRepo/spec/ruby/command_line/fixtures/string_literal_raw.rb
# clonedRepo/spec/ruby/command_line/fixtures/names.txt
# clonedRepo/spec/ruby/command_line/fixtures/require.rb
# clonedRepo/spec/ruby/command_line/fixtures/bad_syntax.rb
# clonedRepo/spec/ruby/command_line/fixtures/change_directory_script.rb
# clonedRepo/spec/ruby/command_line/fixtures/string_literal_frozen_comment.rb
# clonedRepo/spec/ruby/command_line/fixtures/debug_info.rb
# clonedRepo/spec/ruby/command_line/fixtures/backtrace.rb
# clonedRepo/spec/ruby/command_line/fixtures/freeze_flag_required.rb
# clonedRepo/spec/ruby/command_line/fixtures/string_literal_mutable_comment.rb
# clonedRepo/spec/ruby/command_line/fixtures/freeze_flag_two_literals.rb
# clonedRepo/spec/ruby/command_line/fixtures/freeze_flag_one_literal.rb
# clonedRepo/spec/ruby/command_line/fixtures/freeze_flag_across_files_diff_enc.rb
# clonedRepo/spec/ruby/command_line/fixtures/dash_s_script.rb
# clonedRepo/spec/ruby/command_line/fixtures/passwd_file.txt
# clonedRepo/spec/ruby/command_line/fixtures/freeze_flag_required_diff_enc.rb
# clonedRepo/spec/ruby/command_line/fixtures/verbose.rb
# clonedRepo/spec/ruby/command_line/fixtures/bin/bad_embedded_ruby.txt
# clonedRepo/spec/ruby/command_line/fixtures/bin/embedded_ruby.txt
# clonedRepo/spec/ruby/command_line/fixtures/bin/dash_s_fail
# clonedRepo/spec/ruby/command_line/fixtures/bin/hybrid_launcher.sh
# clonedRepo/spec/ruby/command_line/fixtures/bin/launcher.rb
# clonedRepo/spec/ruby/command_line/shared/change_directory.rb
# clonedRepo/spec/ruby/command_line/shared/verbose.rb
# clonedRepo/spec/ruby/bin/rubocop
# clonedRepo/spec/ruby/library/tempfile/initialize_spec.rb
# clonedRepo/spec/ruby/library/tempfile/size_spec.rb
# clonedRepo/spec/ruby/library/tempfile/path_spec.rb
# clonedRepo/spec/ruby/library/tempfile/close_spec.rb
# clonedRepo/spec/ruby/library/tempfile/_close_spec.rb
# clonedRepo/spec/ruby/library/tempfile/open_spec.rb
# clonedRepo/spec/ruby/library/tempfile/delete_spec.rb
# clonedRepo/spec/ruby/library/tempfile/length_spec.rb
# clonedRepo/spec/ruby/library/tempfile/callback_spec.rb
# clonedRepo/spec/ruby/library/tempfile/unlink_spec.rb
# clonedRepo/spec/ruby/library/tempfile/shared/unlink.rb
# clonedRepo/spec/ruby/library/tempfile/shared/length.rb
# clonedRepo/spec/ruby/library/pathname/equal_value_spec.rb
# clonedRepo/spec/ruby/library/pathname/parent_spec.rb
# clonedRepo/spec/ruby/library/pathname/pathname_spec.rb
# clonedRepo/spec/ruby/library/pathname/empty_spec.rb
# clonedRepo/spec/ruby/library/pathname/join_spec.rb
# clonedRepo/spec/ruby/library/pathname/new_spec.rb
# clonedRepo/spec/ruby/library/pathname/realdirpath_spec.rb
# clonedRepo/spec/ruby/library/pathname/realpath_spec.rb
# clonedRepo/spec/ruby/library/pathname/hash_spec.rb
# clonedRepo/spec/ruby/library/pathname/glob_spec.rb
# clonedRepo/spec/ruby/library/pathname/birthtime_spec.rb
# clonedRepo/spec/ruby/library/pathname/divide_spec.rb
# clonedRepo/spec/ruby/library/pathname/relative_spec.rb
# clonedRepo/spec/ruby/library/pathname/absolute_spec.rb
# clonedRepo/spec/ruby/library/pathname/plus_spec.rb
# clonedRepo/spec/ruby/library/pathname/inspect_spec.rb
# clonedRepo/spec/ruby/library/pathname/sub_spec.rb
# clonedRepo/spec/ruby/library/pathname/relative_path_from_spec.rb
# clonedRepo/spec/ruby/library/pathname/root_spec.rb
# clonedRepo/spec/ruby/library/pathname/shared/plus.rb
# clonedRepo/spec/ruby/library/rubygems/gem/load_path_insert_index_spec.rb
# clonedRepo/spec/ruby/library/rubygems/gem/bin_path_spec.rb
# clonedRepo/spec/ruby/library/csv/parse_spec.rb
# clonedRepo/spec/ruby/library/csv/generate_line_spec.rb
# clonedRepo/spec/ruby/library/csv/foreach_spec.rb
# clonedRepo/spec/ruby/library/csv/generate_spec.rb
# clonedRepo/spec/ruby/library/csv/open_spec.rb
# clonedRepo/spec/ruby/library/csv/readlines_spec.rb
# clonedRepo/spec/ruby/library/csv/liberal_parsing_spec.rb
# clonedRepo/spec/ruby/library/csv/generate_row_spec.rb
# clonedRepo/spec/ruby/library/csv/read_spec.rb
# clonedRepo/spec/ruby/library/csv/basicwriter/initialize_spec.rb
# clonedRepo/spec/ruby/library/csv/basicwriter/close_on_terminate_spec.rb
# clonedRepo/spec/ruby/library/csv/basicwriter/terminate_spec.rb
# clonedRepo/spec/ruby/library/csv/ioreader/initialize_spec.rb
# clonedRepo/spec/ruby/library/csv/ioreader/close_on_terminate_spec.rb
# clonedRepo/spec/ruby/library/csv/ioreader/terminate_spec.rb
# clonedRepo/spec/ruby/library/csv/ioreader/get_row_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/buf_size_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/initialize_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/drop_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/get_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/rel_buf_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/idx_is_eos_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/is_eos_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/element_reference_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/terminate_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/add_buf_spec.rb
# clonedRepo/spec/ruby/library/csv/streambuf/read_spec.rb
# clonedRepo/spec/ruby/library/csv/writer/initialize_spec.rb
# clonedRepo/spec/ruby/library/csv/writer/create_spec.rb
# clonedRepo/spec/ruby/library/csv/writer/close_spec.rb
# clonedRepo/spec/ruby/library/csv/writer/generate_spec.rb
# clonedRepo/spec/ruby/library/csv/writer/append_spec.rb
# clonedRepo/spec/ruby/library/csv/writer/add_row_spec.rb
# clonedRepo/spec/ruby/library/csv/writer/terminate_spec.rb
# clonedRepo/spec/ruby/library/csv/fixtures/one_line.csv
# clonedRepo/spec/ruby/library/csv/stringreader/initialize_spec.rb
# clonedRepo/spec/ruby/library/csv/stringreader/get_row_spec.rb
# clonedRepo/spec/ruby/library/csv/iobuf/initialize_spec.rb
# clonedRepo/spec/ruby/library/csv/iobuf/close_spec.rb
# clonedRepo/spec/ruby/library/csv/iobuf/terminate_spec.rb
# clonedRepo/spec/ruby/library/csv/iobuf/read_spec.rb
# clonedRepo/spec/ruby/library/csv/cell/initialize_spec.rb
# clonedRepo/spec/ruby/library/csv/cell/data_spec.rb
# clonedRepo/spec/ruby/library/yaml/parse_spec.rb
# clonedRepo/spec/ruby/library/yaml/load_spec.rb
# clonedRepo/spec/ruby/library/yaml/load_stream_spec.rb
# clonedRepo/spec/ruby/library/yaml/dump_stream_spec.rb
# clonedRepo/spec/ruby/library/yaml/unsafe_load_spec.rb
# clonedRepo/spec/ruby/library/yaml/dump_spec.rb
# clonedRepo/spec/ruby/library/yaml/parse_file_spec.rb
# clonedRepo/spec/ruby/library/yaml/to_yaml_spec.rb
# clonedRepo/spec/ruby/library/yaml/load_file_spec.rb
# clonedRepo/spec/ruby/library/yaml/fixtures/test_yaml.yml
# clonedRepo/spec/ruby/library/yaml/fixtures/example_class.rb
# clonedRepo/spec/ruby/library/yaml/fixtures/strings.rb
# clonedRepo/spec/ruby/library/yaml/shared/each_document.rb
# clonedRepo/spec/ruby/library/yaml/shared/load.rb
# clonedRepo/spec/ruby/library/syslog/constants_spec.rb
# clonedRepo/spec/ruby/library/syslog/err_spec.rb
# clonedRepo/spec/ruby/library/syslog/reopen_spec.rb
# clonedRepo/spec/ruby/library/syslog/crit_spec.rb
# clonedRepo/spec/ruby/library/syslog/notice_spec.rb
# clonedRepo/spec/ruby/library/syslog/options_spec.rb
# clonedRepo/spec/ruby/library/syslog/close_spec.rb
# clonedRepo/spec/ruby/library/syslog/facility_spec.rb
# clonedRepo/spec/ruby/library/syslog/ident_spec.rb
# clonedRepo/spec/ruby/library/syslog/instance_spec.rb
# clonedRepo/spec/ruby/library/syslog/info_spec.rb
# clonedRepo/spec/ruby/library/syslog/mask_spec.rb
# clonedRepo/spec/ruby/library/syslog/open_spec.rb
# clonedRepo/spec/ruby/library/syslog/log_spec.rb
# clonedRepo/spec/ruby/library/syslog/emerg_spec.rb
# clonedRepo/spec/ruby/library/syslog/warning_spec.rb
# clonedRepo/spec/ruby/library/syslog/debug_spec.rb
# clonedRepo/spec/ruby/library/syslog/inspect_spec.rb
# clonedRepo/spec/ruby/library/syslog/alert_spec.rb
# clonedRepo/spec/ruby/library/syslog/opened_spec.rb
# clonedRepo/spec/ruby/library/syslog/shared/reopen.rb
# clonedRepo/spec/ruby/library/syslog/shared/log.rb
# clonedRepo/spec/ruby/library/observer/delete_observer_spec.rb
# clonedRepo/spec/ruby/library/observer/notify_observers_spec.rb
# clonedRepo/spec/ruby/library/observer/count_observers_spec.rb
# clonedRepo/spec/ruby/library/observer/add_observer_spec.rb
# clonedRepo/spec/ruby/library/observer/delete_observers_spec.rb
# clonedRepo/spec/ruby/library/observer/fixtures/classes.rb
# clonedRepo/spec/ruby/library/open3/capture2e_spec.rb
# clonedRepo/spec/ruby/library/open3/pipeline_rw_spec.rb
# clonedRepo/spec/ruby/library/open3/popen2e_spec.rb
# clonedRepo/spec/ruby/library/open3/capture3_spec.rb
# clonedRepo/spec/ruby/library/open3/popen3_spec.rb
# clonedRepo/spec/ruby/library/open3/capture2_spec.rb
# clonedRepo/spec/ruby/library/open3/pipeline_spec.rb
# clonedRepo/spec/ruby/library/open3/popen2_spec.rb
# clonedRepo/spec/ruby/library/open3/pipeline_r_spec.rb
# clonedRepo/spec/ruby/library/open3/pipeline_start_spec.rb
# clonedRepo/spec/ruby/library/open3/pipeline_w_spec.rb
# clonedRepo/spec/ruby/library/net-http/HTTPServerException_spec.rb
# clonedRepo/spec/ruby/library/net-http/HTTPHeaderSyntaxError_spec.rb
# clonedRepo/spec/ruby/library/net-http/HTTPRetriableError_spec.rb
# clonedRepo/spec/ruby/library/net-http/HTTPBadResponse_spec.rb
# clonedRepo/spec/ruby/library/net-http/HTTPClientExcepton_spec.rb
# clonedRepo/spec/ruby/library/net-http/HTTPError_spec.rb
# clonedRepo/spec/ruby/library/net-http/HTTPFatalError_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpexceptions/initialize_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpexceptions/response_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpexceptions/fixtures/classes.rb
# clonedRepo/spec/ruby/library/net-http/httprequest/initialize_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/post_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/is_version_1_2_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/initialize_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/put2_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/Proxy_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/active_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/newobj_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/https_default_port_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/proxy_address_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/trace_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/move_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/get_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/options_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/address_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/request_post_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/new_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/request_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/request_get_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/proxy_user_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/close_on_empty_response_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/read_timeout_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/proxy_class_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/delete_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/request_types_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/lock_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/start_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/version_1_1_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/set_debug_output_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/unlock_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/send_request_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/port_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/finish_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/head2_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/is_version_1_1_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/get_print_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/proppatch_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/socket_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/inspect_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/get_response_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/request_head_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/get2_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/proxy_pass_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/default_port_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/use_ssl_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/version_1_2_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/put_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/copy_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/request_put_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/proxy_port_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/post_form_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/http_default_port_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/started_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/mkcol_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/propfind_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/open_timeout_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/head_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/post2_spec.rb
# clonedRepo/spec/ruby/library/net-http/http/fixtures/http_server.rb
# clonedRepo/spec/ruby/library/net-http/http/shared/version_1_2.rb
# clonedRepo/spec/ruby/library/net-http/http/shared/version_1_1.rb
# clonedRepo/spec/ruby/library/net-http/http/shared/request_put.rb
# clonedRepo/spec/ruby/library/net-http/http/shared/request_get.rb
# clonedRepo/spec/ruby/library/net-http/http/shared/request_head.rb
# clonedRepo/spec/ruby/library/net-http/http/shared/request_post.rb
# clonedRepo/spec/ruby/library/net-http/http/shared/started.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/each_name_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/sub_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/initialize_http_header_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/set_form_data_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/canonical_each_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/each_value_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/size_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/add_field_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/each_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/get_fields_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/fetch_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/each_capitalized_name_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/range_length_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/range_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/content_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/key_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/each_header_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/to_hash_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/each_key_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/form_data_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/chunked_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/delete_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/set_range_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/type_params_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/length_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/element_set_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/content_range_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/basic_auth_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/element_reference_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/each_capitalized_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/proxy_basic_auth_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/main_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/set_content_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/content_length_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/fixtures/classes.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/shared/each_capitalized.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/shared/size.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/shared/each_header.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/shared/set_content_type.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/shared/set_form_data.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/shared/each_name.rb
# clonedRepo/spec/ruby/library/net-http/httpheader/shared/set_range.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/initialize_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/code_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/reading_body_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/entity_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/header_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/read_new_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/response_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/error_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/error_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/http_version_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/body_permitted_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/value_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/code_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/read_body_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/exception_type_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/inspect_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/read_header_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/msg_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/message_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/body_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpresponse/shared/body.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/response_body_permitted_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/body_exist_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/path_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/set_body_internal_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/exec_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/request_body_permitted_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/body_stream_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/method_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/inspect_spec.rb
# clonedRepo/spec/ruby/library/net-http/httpgenericrequest/body_spec.rb
# clonedRepo/spec/ruby/library/expect/expect_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/check_until_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/skip_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/reset_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/initialize_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/check_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/post_match_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/exist_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/rest_size_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/rest_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/scan_full_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/size_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/empty_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/peek_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/getch_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/matched_size_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/get_byte_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/pos_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/eos_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/restsize_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/peep_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/pre_match_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/skip_until_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/concat_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/string_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/scan_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/bol_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/search_full_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/matched_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/pointer_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/append_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/dup_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/match_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/beginning_of_line_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/inspect_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/must_C_version_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/clear_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/element_reference_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/getbyte_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/scan_until_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/terminate_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/unscan_spec.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/get_byte.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/bol.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/extract_range.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/extract_range_matched.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/peek.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/concat.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/pos.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/eos.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/rest_size.rb
# clonedRepo/spec/ruby/library/stringscanner/shared/terminate.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/_invoke_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/constants_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/_getproperty_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/ole_put_methods_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/ole_get_methods_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/ole_func_methods_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/ole_method_help_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/invoke_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/new_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/const_load_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/ole_methods_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/connect_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/setproperty_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/codepage_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/create_guid_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/ole_obj_help_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/ole_method_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/locale_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/shared/ole_method.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole/shared/setproperty.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/major_version_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/variables_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/ole_type_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/helpfile_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/ole_classes_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/new_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/helpstring_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/name_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/progid_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/to_s_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/typekind_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/visible_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/ole_methods_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/src_type_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/minor_version_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/typelibs_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/guid_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/helpcontext_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/progids_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_type/shared/name.rb
# clonedRepo/spec/ruby/library/win32ole/fixtures/classes.rb
# clonedRepo/spec/ruby/library/win32ole/fixtures/event.xml
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/ole_type_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/default_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/name_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/to_s_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/optional_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/ole_type_detail_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/input_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/retval_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_param/shared/name.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/ole_type_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/name_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/to_s_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/visible_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/ole_type_detail_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/variable_kind_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/value_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/varkind_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_variable/shared/name.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_event/new_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_event/on_event_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/event_interface_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/return_type_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/helpfile_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/new_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/helpstring_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/name_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/return_type_detail_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/dispid_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/to_s_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/visible_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/return_vtype_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/invkind_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/size_opt_params_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/offset_vtbl_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/helpcontext_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/params_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/invoke_kind_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/size_params_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/event_spec.rb
# clonedRepo/spec/ruby/library/win32ole/win32ole_method/shared/name.rb
# clonedRepo/spec/ruby/library/bigdecimal/nonzero_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/quo_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/equal_value_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/to_f_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/coerce_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/lt_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/constants_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/infinite_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/mult_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/remainder_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/uplus_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/sqrt_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/floor_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/to_r_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/nan_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/limit_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/split_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/fix_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/to_s_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/BigDecimal_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/hash_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/mode_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/precs_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/div_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/zero_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/to_d_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/add_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/util_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/divmod_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/lte_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/uminus_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/divide_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/multiply_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/dup_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/finite_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/to_i_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/sign_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/frac_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/gte_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/clone_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/plus_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/case_compare_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/comparison_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/abs_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/round_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/inspect_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/ceil_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/core_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/minus_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/exponent_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/gt_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/sub_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/eql_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/double_fig_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/truncate_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/modulo_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/power_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/to_int_spec.rb
# clonedRepo/spec/ruby/library/bigdecimal/fixtures/classes.rb
# clonedRepo/spec/ruby/library/bigdecimal/shared/modulo.rb
# clonedRepo/spec/ruby/library/bigdecimal/shared/to_int.rb
# clonedRepo/spec/ruby/library/bigdecimal/shared/mult.rb
# clonedRepo/spec/ruby/library/bigdecimal/shared/power.rb
# clonedRepo/spec/ruby/library/bigdecimal/shared/quo.rb
# clonedRepo/spec/ruby/library/bigdecimal/shared/eql.rb
# clonedRepo/spec/ruby/library/bigdecimal/shared/clone.rb
# clonedRepo/spec/ruby/library/openssl/secure_compare_spec.rb
# clonedRepo/spec/ruby/library/openssl/cipher_spec.rb
# clonedRepo/spec/ruby/library/openssl/fixed_length_secure_compare_spec.rb
# clonedRepo/spec/ruby/library/openssl/hmac/digest_spec.rb
# clonedRepo/spec/ruby/library/openssl/hmac/hexdigest_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/reset_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/initialize_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/digest_length_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/digest_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/name_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/append_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/block_length_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/update_spec.rb
# clonedRepo/spec/ruby/library/openssl/digest/shared/update.rb
# clonedRepo/spec/ruby/library/openssl/x509/name/parse_spec.rb
# clonedRepo/spec/ruby/library/openssl/x509/store/verify_spec.rb
# clonedRepo/spec/ruby/library/openssl/random/pseudo_bytes_spec.rb
# clonedRepo/spec/ruby/library/openssl/random/random_bytes_spec.rb
# clonedRepo/spec/ruby/library/openssl/random/shared/random_bytes.rb
# clonedRepo/spec/ruby/library/openssl/kdf/pbkdf2_hmac_spec.rb
# clonedRepo/spec/ruby/library/openssl/kdf/scrypt_spec.rb
# clonedRepo/spec/ruby/library/openssl/shared/constants.rb
# clonedRepo/spec/ruby/library/readline/completion_append_character_spec.rb
# clonedRepo/spec/ruby/library/readline/constants_spec.rb
# clonedRepo/spec/ruby/library/readline/emacs_editing_mode_spec.rb
# clonedRepo/spec/ruby/library/readline/readline_spec.rb
# clonedRepo/spec/ruby/library/readline/completer_quote_characters_spec.rb
# clonedRepo/spec/ruby/library/readline/vi_editing_mode_spec.rb
# clonedRepo/spec/ruby/library/readline/completer_word_break_characters_spec.rb
# clonedRepo/spec/ruby/library/readline/basic_quote_characters_spec.rb
# clonedRepo/spec/ruby/library/readline/spec_helper.rb
# clonedRepo/spec/ruby/library/readline/completion_proc_spec.rb
# ...
# clonedRepo/test/prism/errors/missing_terminator_in_parentheses.txt
# clonedRepo/test/prism/errors/invalid_multi_target_15.txt
# clonedRepo/test/prism/errors/pre_execution_context.txt
# clonedRepo/test/prism/errors/symbol_in_hash.txt
# clonedRepo/test/prism/errors/command_calls_2.txt
# clonedRepo/test/prism/errors/invalid_number_underscores_9.txt
# clonedRepo/test/prism/errors/void_value_expression_in_modifier.txt
# clonedRepo/test/prism/errors/arguments_after_block.txt
# clonedRepo/test/prism/errors/bad_arguments.txt
# clonedRepo/test/prism/errors/do_not_allow_characters_other_than_0_9_a_f_and_A_F_in_u_Unicode_character_notation.txt
# clonedRepo/test/prism/errors/command_calls_4.txt
# clonedRepo/test/prism/errors/parameter_name_ending_with_bang_or_question_mark.txt
# clonedRepo/test/prism/errors/invalid_multi_target_16.txt
# clonedRepo/test/prism/errors/command_calls_15.txt
# clonedRepo/test/prism/errors/regexp_unicode_too_short.txt
# clonedRepo/test/prism/errors/command_calls_8.txt
# clonedRepo/test/prism/errors/duplicate_pattern_hash_key.txt
# clonedRepo/test/prism/errors/amperand_dot_after_endless_range.txt
# clonedRepo/test/prism/errors/unterminated_W_list.txt
# clonedRepo/test/prism/errors/command_calls.txt
# clonedRepo/test/prism/errors/alnum_delimiters_2.txt
# clonedRepo/test/prism/errors/label_in_parentheses.txt
# clonedRepo/test/prism/errors/command_calls_18.txt
# clonedRepo/test/prism/errors/method_parameters_after_arguments_forwarding.txt
# clonedRepo/test/prism/errors/invalid_multi_target_19.txt
# clonedRepo/test/prism/errors/module_name_recoverable.txt
# clonedRepo/test/prism/errors/shadow_args_in_lambda.txt
# clonedRepo/test/prism/errors/void_value_expression_in_statement.txt
# clonedRepo/test/prism/errors/for_loop_delimiter.txt
# clonedRepo/test/prism/errors/do_not_allow_trailing_commas_in_method_parameters.txt
# clonedRepo/test/prism/errors/numbered_operator_write.txt
# clonedRepo/test/prism/errors/invalid_multi_target_4.txt
# clonedRepo/test/prism/errors/invalid_number_underscores_12.txt
# clonedRepo/test/prism/errors/range_and_bin_op_2.txt
# clonedRepo/test/prism/errors/top_level_constant_starting_with_downcased_identifier.txt
# clonedRepo/test/prism/errors/command_calls_14.txt
# clonedRepo/test/prism/errors/match_predicate_after_or_with_opreator.txt
# clonedRepo/test/prism/errors/aliasing_non_global_variable_with_global_variable.txt
# clonedRepo/test/prism/errors/command_calls_6.txt
# clonedRepo/test/prism/errors/match_predicate_after_rescue_with_opreator.txt
# clonedRepo/test/prism/errors/invalid_number_underscores_3.txt
# clonedRepo/test/prism/errors/invalid_number_underscores_8.txt
# clonedRepo/test/prism/errors/invalid_multi_target_20.txt
# clonedRepo/test/prism/errors/method_with_arguments_after_anonymous_block.txt
# clonedRepo/test/prism/errors/trailing_comma_in_calls.txt
# clonedRepo/test/prism/errors/array_with_double_commas.txt
# clonedRepo/test/prism/errors/do_not_allow_forward_arguments_in_lambda_literals.txt
# clonedRepo/test/prism/errors/match_required_after_and_with_dot_method_call.txt
# clonedRepo/test/prism/errors/trailing_comma_after_block.txt
# clonedRepo/test/prism/errors/check_value_expression.txt
# clonedRepo/test/prism/errors/alnum_delimiters_4.txt
# clonedRepo/test/prism/errors/void_value_expression_in_assignment.txt
# clonedRepo/test/prism/errors/command_calls_27.txt
# clonedRepo/test/prism/errors/statement_at_non_statement.txt
# clonedRepo/test/prism/errors/returning_to_optional_parameters_multiple_times.txt
# clonedRepo/test/prism/errors/unterminated_parenthesized_expression.txt
# clonedRepo/test/prism/errors/command_calls_22.txt
# clonedRepo/test/prism/errors/it_with_ordinary_parameter.txt
# clonedRepo/test/prism/errors/def_with_multiple_statements_receiver.txt
# clonedRepo/test/prism/errors/return_1_2_3.txt
# clonedRepo/test/prism/errors/binary_range_with_left_unary_range.txt
# clonedRepo/test/prism/errors/range_and_bin_op_8.txt
# clonedRepo/test/prism/errors/command_calls_29.txt
# clonedRepo/test/prism/errors/void_value_expression_in_array.txt
# clonedRepo/test/prism/errors/command_calls_7.txt
# clonedRepo/test/prism/errors/optional_block_parameters_with_unary_operator.txt
# clonedRepo/test/prism/errors/invalid_splat.txt
# clonedRepo/test/prism/errors/duplicated_parameter_names.txt
# clonedRepo/test/prism/errors/unterminated_method_parameters.txt
# clonedRepo/test/prism/errors/match_predicate_after_or_with_dot_method_call.txt
# clonedRepo/test/prism/errors/top_level_constant_with_downcased_identifier.txt
# clonedRepo/test/prism/errors/arguments_splat_after_star_star.txt
# clonedRepo/test/prism/errors/double_splat_followed_by_splat_argument.txt
# clonedRepo/test/prism/errors/for_loops_index_missing.txt
# clonedRepo/test/prism/errors/alnum_delimiters_9.txt
# clonedRepo/test/prism/errors/multi_target_star.txt
# clonedRepo/test/prism/errors/unterminated_unicode_brackets_should_be_a_syntax_error.txt
# clonedRepo/test/prism/errors/double_scope_repeated_numbered_parameters.txt
# clonedRepo/test/prism/errors/defs_endless_method.txt
# clonedRepo/test/prism/errors/optional_block_parameters_with_unary_operator_2.txt
# clonedRepo/test/prism/errors/argument_after_ellipsis.txt
# clonedRepo/test/prism/errors/block_args_in_array_assignment.txt
# clonedRepo/test/prism/errors/invalid_multi_target.txt
# clonedRepo/test/prism/errors/heredoc_unterminated.txt
# clonedRepo/test/prism/errors/invalid_number_underscores_7.txt
# clonedRepo/test/prism/errors/case_without_clauses.txt
# clonedRepo/test/prism/errors/command_calls_19.txt
# clonedRepo/test/prism/errors/forwarding_arg_and_block.txt
# clonedRepo/test/prism/errors/call_with_block_operator_write.txt
# clonedRepo/test/prism/errors/invalid_multi_target_14.txt
# clonedRepo/test/prism/errors/command_calls_28.txt
# clonedRepo/test/prism/errors/dont_allow_return_inside_class_body.txt
# clonedRepo/test/prism/errors/class_definition_in_method_body.txt
# clonedRepo/test/prism/errors/constant_assignment_in_method.txt
# clonedRepo/test/prism/errors/void_value_expression_in_begin_statement.txt
# clonedRepo/test/prism/errors/alnum_delimiters.txt
# clonedRepo/test/prism/errors/numbered_or_write.txt
# clonedRepo/test/prism/errors/invalid_number_underscores_5.txt
# clonedRepo/sample/test.rb
# clonedRepo/sample/trick2022/03-mame/test.txt
# clonedRepo/basictest/test.rb
# clonedRepo/benchmark/string_slice.yml
# clonedRepo/benchmark/vm_fiber_count.yml
# clonedRepo/benchmark/vm_struct_small_hset.yml
# clonedRepo/benchmark/marshal_dump_load_integer.yml
# clonedRepo/benchmark/vm_ivar_of_class_set.yml
# clonedRepo/benchmark/vm_send_cfunc.yml
# clonedRepo/benchmark/enum_sort_by.yml
# clonedRepo/benchmark/vm_yield.yml
# clonedRepo/benchmark/fiber_chain.yml
# clonedRepo/benchmark/time_strptime.yml
# clonedRepo/benchmark/hash_dup.yml
# clonedRepo/benchmark/vm_super_splat_calls.yml
# clonedRepo/benchmark/vm_method_missing.yml
# clonedRepo/benchmark/vm_ivar_set_on_instance.yml
# clonedRepo/benchmark/vm_iclass_super.yml
# clonedRepo/benchmark/vm_simplereturn.yml
# clonedRepo/benchmark/vm_lvar_cond_set.yml
# clonedRepo/benchmark/time_parse.yml
# clonedRepo/benchmark/vm_call_method_missing.yml
# clonedRepo/benchmark/hash_first.yml
# clonedRepo/benchmark/enum_tally.yml
# clonedRepo/benchmark/time_new.yml
# clonedRepo/benchmark/kernel_float.yml
# clonedRepo/benchmark/scan.yaml
# clonedRepo/benchmark/string_casecmp.yml
# clonedRepo/benchmark/vm_call_kw_and_kw_splat.yml
# clonedRepo/benchmark/masgn.yml
# clonedRepo/benchmark/vm_zsuper_splat_calls.yml
# clonedRepo/benchmark/enum_sort.yml
# clonedRepo/benchmark/vm_gc_short_with_symbol.yml
# clonedRepo/benchmark/vm_blockparam.yml
# clonedRepo/benchmark/vm_ensure.yml
# clonedRepo/benchmark/vm_call_bmethod.yml
# clonedRepo/benchmark/vm_gc_wb_ary.yml
# clonedRepo/benchmark/iseq_load_from_binary.yml
# clonedRepo/benchmark/vm_gc_short_with_long.yml
# clonedRepo/benchmark/string_downcase.yml
# clonedRepo/benchmark/string_gsub.yml
# clonedRepo/benchmark/time_at.yml
# clonedRepo/benchmark/array_flatten.yml
# clonedRepo/benchmark/time_now.yml
# clonedRepo/benchmark/vm_ivar_ic_miss.yml
# clonedRepo/benchmark/vm_ivar_set.yml
# clonedRepo/benchmark/vm_attr_ivar_set.yml
# clonedRepo/benchmark/vm_struct_big_aref_hi.yml
# clonedRepo/benchmark/vm_rescue.yml
# clonedRepo/benchmark/array_min.yml
# clonedRepo/benchmark/vm_struct_big_href_lo.yml
# clonedRepo/benchmark/vm_const.yml
# clonedRepo/benchmark/vm_case.yml
# clonedRepo/benchmark/vm_gc_wb_obj.yml
# clonedRepo/benchmark/vm_fiber_reuse_gc.yml
# clonedRepo/benchmark/vm_zsuper.yml
# clonedRepo/benchmark/vm_freezestring.yml
# clonedRepo/benchmark/vm_poly_method_ov.yml
# clonedRepo/benchmark/vm_struct_big_aset.yml
# clonedRepo/benchmark/range_reverse_each.yml
# clonedRepo/benchmark/numeric_methods.yml
# clonedRepo/benchmark/loop_each.yml
# clonedRepo/benchmark/ivar_extend.yml
# clonedRepo/benchmark/method_bind_call.yml
# clonedRepo/benchmark/complex_float_power.yml
# clonedRepo/benchmark/vm_blockparam_yield.yml
# clonedRepo/benchmark/float_to_s.yml
# clonedRepo/benchmark/vm_method_splat_calls.yml
# clonedRepo/benchmark/vm_ivar_get_unintialized.yml
# clonedRepo/benchmark/vm_bighash.yml
# clonedRepo/benchmark/nilclass.yml
# clonedRepo/benchmark/erb_escape_html.yml
# clonedRepo/benchmark/vm_eval.yml
# clonedRepo/benchmark/vm_cvar.yml
# clonedRepo/benchmark/vm_fiber_switch.yml
# clonedRepo/benchmark/vm_defined_method.yml
# clonedRepo/benchmark/vm_swap.yml
# clonedRepo/benchmark/vm_ivar_generic_set.yml
# clonedRepo/benchmark/realpath.yml
# clonedRepo/benchmark/vm_regexp.yml
# clonedRepo/benchmark/kernel_clone.yml
# clonedRepo/benchmark/kernel_tap.yml
# clonedRepo/benchmark/string_upcase.yml
# clonedRepo/benchmark/vm_attr_ivar.yml
# clonedRepo/benchmark/enum_minmax.yml
# clonedRepo/benchmark/vm_proc.yml
# clonedRepo/benchmark/vm_struct_big_aref_lo.yml
# clonedRepo/benchmark/vm_poly_singleton.yml
# clonedRepo/benchmark/module_eqq.yml
# clonedRepo/benchmark/require_thread.yml
# clonedRepo/benchmark/search.yaml
# clonedRepo/benchmark/vm_thread_alive_check.yml
# clonedRepo/benchmark/vm_ivar_lazy_set.yml
# clonedRepo/benchmark/vm_struct_big_href_hi.yml
# clonedRepo/benchmark/range_overlap.yml
# clonedRepo/benchmark/object_allocate.yml
# clonedRepo/benchmark/vm_module_const_set.yml
# clonedRepo/benchmark/vm_gc_wb_ary_promoted.yml
# clonedRepo/benchmark/vm_newlambda.yml
# clonedRepo/benchmark/enum_lazy_zip.yml
# clonedRepo/benchmark/keyword_arguments.yml
# clonedRepo/benchmark/vm_blockparam_call.yml
# clonedRepo/benchmark/vm_send.yml
# clonedRepo/benchmark/range_bsearch_endpointless.yml
# clonedRepo/benchmark/so_reverse_complement.yml
# clonedRepo/benchmark/attr_accessor.yml
# clonedRepo/benchmark/buffer_each.yml
# clonedRepo/benchmark/vm_bigarray.yml
# clonedRepo/benchmark/ractor_float_to_s.yml
# clonedRepo/benchmark/time_xmlschema.yml
# clonedRepo/benchmark/vm_method_splat_calls2.yml
# clonedRepo/benchmark/float_neg_posi.yml
# clonedRepo/benchmark/vm_raise1.yml
# clonedRepo/benchmark/hash_defaults.yml
# clonedRepo/benchmark/regexp_dup.yml
# clonedRepo/benchmark/enum_lazy_flat_map.yml
# clonedRepo/benchmark/array_max_float.yml
# clonedRepo/benchmark/array_max_int.yml
# clonedRepo/benchmark/array_large_literal.yml
# clonedRepo/benchmark/vm_struct_small_aset.yml
# clonedRepo/benchmark/complex_float_sub.yml
# clonedRepo/benchmark/vm_ivar_embedded_obj_init.yml
# clonedRepo/benchmark/string_split.yml
# clonedRepo/benchmark/vm_mutex.yml
# clonedRepo/benchmark/vm_dstr.yml
# clonedRepo/benchmark/vm_string_literal.yml
# clonedRepo/benchmark/vm_ivar_of_class.yml
# clonedRepo/benchmark/app_erb.yml
# clonedRepo/benchmark/vm_fiber_reuse.yml
# clonedRepo/benchmark/vm_fiber_allocate.yml
# clonedRepo/benchmark/vm_ivar_generic_get.yml
# clonedRepo/benchmark/vm_blockparam_pass.yml
# clonedRepo/benchmark/complex_float_div.yml
# clonedRepo/benchmark/vm_method_with_block.yml
# clonedRepo/benchmark/range_last.yml
# clonedRepo/benchmark/regexp_new.yml
# clonedRepo/benchmark/so_count_words.yml
# clonedRepo/benchmark/string_concat.yml
# clonedRepo/benchmark/vm_module_ann_const_set.yml
# clonedRepo/benchmark/vm_unif1.yml
# clonedRepo/benchmark/vm_not.yml
# clonedRepo/benchmark/vm_gc_short_with_complex_long.yml
# clonedRepo/benchmark/range_min.yml
# clonedRepo/benchmark/vm_call_symproc.yml
# clonedRepo/benchmark/irb_color.yml
# clonedRepo/benchmark/loop_times_megamorphic.yml
# clonedRepo/benchmark/string_dup.yml
# clonedRepo/benchmark/vm_case_classes.yml
# clonedRepo/benchmark/string_capitalize.yml
# clonedRepo/benchmark/vm_array.yml
# clonedRepo/benchmark/range_count.yml
# clonedRepo/benchmark/vm_gc_wb_obj_promoted.yml
# clonedRepo/benchmark/vm_ivar_set_subclass.yml
# clonedRepo/benchmark/vm_struct_big_hset.yml
# clonedRepo/benchmark/objspace_dump_all.yml
# clonedRepo/benchmark/vm_struct_small_href.yml
# clonedRepo/benchmark/string_rpartition.yml
# clonedRepo/benchmark/vm_lvar_set.yml
# clonedRepo/benchmark/range_bsearch_fixnum.yml
# clonedRepo/benchmark/num_zero_p.yml
# clonedRepo/benchmark/array_sample.yml
# clonedRepo/benchmark/fiber_locals.yml
# clonedRepo/benchmark/vm_ivar_extended_obj_init.yml
# clonedRepo/benchmark/string_casecmp_p.yml
# clonedRepo/benchmark/hash_aref_str_lit.yml
# clonedRepo/benchmark/string_swapcase.yml
# clonedRepo/benchmark/erb_render.yml
# clonedRepo/benchmark/vm_super.yml
# clonedRepo/benchmark/array_max_str.yml
# clonedRepo/benchmark/time_strftime.yml
# clonedRepo/benchmark/pm_array.yml
# clonedRepo/benchmark/hash_key.yml
# clonedRepo/benchmark/vm_method.yml
# clonedRepo/benchmark/require.yml
# clonedRepo/benchmark/range_bsearch_bignum.yml
# clonedRepo/benchmark/array_intersection.yml
# clonedRepo/benchmark/ractor_const.yml
# clonedRepo/benchmark/vm_float_simple.yml
# clonedRepo/benchmark/kernel_then.yml
# clonedRepo/benchmark/vm_block.yml
# clonedRepo/benchmark/vm_freezeobj.yml
# clonedRepo/benchmark/nil_p.yml
# clonedRepo/benchmark/vm_length.yml
# clonedRepo/benchmark/complex_float_new.yml
# clonedRepo/benchmark/buffer_get.yml
# clonedRepo/benchmark/vm_poly_method.yml
# clonedRepo/benchmark/vm_case_lit.yml
# clonedRepo/benchmark/vm_neq.yml
# clonedRepo/benchmark/vm_thread_sleep.yml
# clonedRepo/benchmark/struct_accessor.yml
# clonedRepo/benchmark/vm_lvar_init.yml
# clonedRepo/benchmark/so_k_nucleotide.yml
# clonedRepo/benchmark/complex_float_mul.yml
# clonedRepo/benchmark/vm_gc_short_lived.yml
# clonedRepo/benchmark/vm_ivar_get.yml
# clonedRepo/benchmark/irb_exec.yml
# clonedRepo/benchmark/vm_raise2.yml
# clonedRepo/benchmark/vm_struct_small_aref.yml
# clonedRepo/benchmark/vm_poly_same_method.yml
# clonedRepo/benchmark/hash_new.yml
# clonedRepo/benchmark/complex_float_add.yml
# clonedRepo/benchmark/vm_ivar_memoize.yml
# clonedRepo/benchmark/vm_ivar.yml
# clonedRepo/benchmark/vm_block_handler.yml
# clonedRepo/benchmark/vm_call_send_iseq.yml
# clonedRepo/benchmark/cgi_escape_html.yml
# clonedRepo/benchmark/array_sort_int.yml
# clonedRepo/benchmark/float_methods.yml
# clonedRepo/.github/labeler.yml
# clonedRepo/.github/auto_request_review.yml
# clonedRepo/.github/dependabot.yml
# clonedRepo/.github/workflows/modgc.yml
# clonedRepo/.github/workflows/baseruby.yml
# clonedRepo/.github/workflows/default_gems.yml
# clonedRepo/.github/workflows/check_dependencies.yml
# clonedRepo/.github/workflows/labeler.yml
# clonedRepo/.github/workflows/dependabot_automerge.yml
# clonedRepo/.github/workflows/macos.yml
# clonedRepo/.github/workflows/bundled_gems.yml
# clonedRepo/.github/workflows/auto_request_review.yml
# clonedRepo/.github/workflows/wsl.yml
# clonedRepo/.github/workflows/compilers.yml
# clonedRepo/.github/workflows/yjit-ubuntu.yml
# clonedRepo/.github/workflows/check_misc.yml
# clonedRepo/.github/workflows/mingw.yml
# clonedRepo/.github/workflows/pr-playground.yml
# clonedRepo/.github/workflows/windows.yml
# clonedRepo/.github/workflows/cygwin.yml
# clonedRepo/.github/workflows/publish.yml
# clonedRepo/.github/workflows/ubuntu.yml
# clonedRepo/.github/workflows/annocheck.yml
# clonedRepo/.github/workflows/wasm.yml
# clonedRepo/.github/workflows/parsey.yml
# clonedRepo/.github/workflows/codeql-analysis.yml
# clonedRepo/.github/workflows/spec_guards.yml
# clonedRepo/.github/workflows/release.yml
# clonedRepo/.github/workflows/scorecards.yml
# clonedRepo/.github/workflows/yjit-macos.yml
# clonedRepo/.github/actions/slack/action.yml
# clonedRepo/.github/actions/setup/directories/action.yml
# clonedRepo/.github/actions/setup/macos/action.yml
# clonedRepo/.github/actions/setup/ubuntu/action.yml
# clonedRepo/.github/actions/compilers/action.yml
# clonedRepo/.github/actions/launchable/setup/action.yml
# clonedRepo/prism/config.yml

# %%
import subprocess
import re

def totalCommits(repo_path):
    #Returns the total number of commits in the repository
    result = subprocess.run(["git", "rev-list", "--count", "HEAD"], cwd=repo_path, capture_output=True, text=True)
    return int(result.stdout.strip()) if result.returncode == 0 else None

def test_lines_changed(repo_path):
    #Returns the total number of lines changed in test files including the travis CI files
    test_file_patterns = re.compile(r'(\btest\b|\.test|_test|-test|Test|\.spec|_spec|-spec|Spec|\.ya?ml)$', re.IGNORECASE)
    total_lines_changed = 0

    result = subprocess.run(["git", "log", "--numstat", "--pretty=format:"], cwd=repo_path, capture_output=True, text=True)

    if result.returncode == 0:
        lines = result.stdout.split("\n")
        for line in lines:
            parts = line.split("\t")
            if len(parts) == 3:
                added, removed, filename = parts
                if test_file_patterns.search(filename):
                    try:
                        added_lines = int(added) if added.isdigit() else 0
                        removed_lines = int(removed) if removed.isdigit() else 0
                        total_lines_changed += added_lines + removed_lines
                    except ValueError:
                        continue

    return total_lines_changed

def calculate_tcpc(repo_path):
    # Calculating test changes per commit
    total_commits = totalCommits(repo_path)
    total_test_lines_changed = test_lines_changed(repo_path)

    if total_commits and total_test_lines_changed:
        return total_test_lines_changed / total_commits
    return None
repo_path = "clonedRepo"

test_changes_per_commit = calculate_tcpc(repo_path)
if test_changes_per_commit is not None:
    print(f"Test Changes per Commit: {test_changes_per_commit:.2f}")
else:
    print("Error calculating metric.")
# Out:
# Test Changes per Commit: 0.73

# %%
def count_test_commits(repo_path):
    # Counts commits that changed at least one test file
    repo = git.Repo(repo_path)
    test_commits = set()
    for commit in repo.iter_commits():
        for file in commit.stats.files.keys():
            if is_test_file(os.path.basename(file)):
                test_commits.add(commit.hexsha)
                break

    return len(test_commits)


test_commit_count = count_test_commits(LOCAL_PATH)
print(f"\nTotal commits that changed at least one test file: {test_commit_count}")
# Out:
# Total commits that changed at least one test file: 4205

# %%
import subprocess
import os
from datetime import datetime

def get_commit_dates(repo_path):
    # pulls the commit start and end date for the entire project
    #handling exceptions
    try:
        if not os.path.isdir(os.path.join(repo_path, ".git")):
            print("Error: Not a valid Git repository.")
            return None, None

        # Get the first commit date
        first_commit = subprocess.check_output(
            ["git", "log", "--reverse", "--format=%cd", "--date=short"],
            cwd=repo_path,
            text=True
        ).splitlines()[0]

        # Get the last commit date
        last_commit = subprocess.check_output(
            ["git", "log", "-1", "--format=%cd", "--date=short"],
            cwd=repo_path,
            text=True
        ).strip()

        return first_commit, last_commit
    except Exception as e:
        print("Error fetching commit dates:", e)
        return None, None

def calculate_total_active_days(repo_path):
    """Calculate the total number of days a Git repository has been active."""
    first_commit, last_commit = get_commit_dates(repo_path)

    if first_commit and last_commit:
        date_format = "%Y-%m-%d"
        start_date = datetime.strptime(first_commit, date_format)
        end_date = datetime.strptime(last_commit, date_format)
        active_days = (end_date - start_date).days
        print(f"Total active days: {active_days}")
    else:
        print("Error")

if __name__ == "__main__":
    repo_path = input("Enter the local path of the cloned repository: ").strip()
    calculate_total_active_days("/content/clonedRepo")
# Out:
# Enter the local path of the cloned repository: /content/clonedRepo
# Total active days: 9922

# %%
import subprocess

def get_total_loc(repo_path):
    # to get the total LOC for the entire project for comparison
    # handling exceptions
    try:
        result = subprocess.run(["git", "ls-files"], cwd=repo_path, capture_output=True, text=True, check=True)
        files = result.stdout.strip().split("\n")

        total_loc = 0
        for file in files:
            line_count = subprocess.run(["wc", "-l", file], cwd=repo_path, capture_output=True, text=True)
            if line_count.returncode == 0:
                total_loc += int(line_count.stdout.strip().split()[0])

        return total_loc

    except Exception as e:
        print(f"Error: {e}")
        return None

repo_path = "clonedRepo"

total_loc = get_total_loc(repo_path)
if total_loc is not None:
    print(f"Total Lines of Code (LoC): {total_loc}")
else:
    print("Error calculating LoC.")
# Out:
# Total Lines of Code (LoC): 2629679

# %%
#Deleting the local directory to reuse it for every root repo
import shutil

def delete_local_repo(local_path):
    if os.path.exists(local_path):
        print(f"Deleting existing repository folder: {local_path}")
        shutil.rmtree(local_path)
        print("Folder deleted successfully.")
    else:
        print("No existing repository folder found.")


delete_local_repo('/content/clonedRepo')
# Out:
# Deleting existing repository folder: /content/clonedRepo
# Folder deleted successfully.
